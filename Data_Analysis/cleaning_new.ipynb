# %%
import pandas as pd
import warnings
from src.utils import *
import openai
import src.gpt_siemens as siemens
warnings.filterwarnings('ignore')

# %% [markdown]
# ### 1) Data

# %%
df=pd.read_pickle('data/df_Mahle_full.pkl')

# %% [markdown]
# ### 2) Duplicates

# %%
df['pair'] = df.apply(lambda row: tuple(sorted([row['Product Id'], row['matched_Product Id']])), axis=1)

no_duplicates = df[~df.duplicated(subset=['pair'], keep=False)]  # Rows with no duplicates
duplicates = df[df.duplicated(subset=['pair'], keep=False)]     # Rows with duplicates

score_same = duplicates.groupby('pair').filter(lambda x: len(x['score'].unique()) == 1)    # Duplicates with same values in the score column
score_diff_tot = duplicates.groupby('pair').filter(lambda x: len(x['score'].unique()) > 1) # Duplicates with different score values
score_diff_uniq = score_diff_tot.drop_duplicates(subset=['pair', 'score'], keep='first')   # Unique different score values

# %%
df.shape
# Out:
# (931744, 19)

# %% [markdown]
# Differences based on the duplicates and their scores

# %%
a = no_duplicates.shape[0]
b = score_same.shape[0]
c = score_diff_tot.shape[0]
total = a + b + c
print(f"No duplicates: {a}, Same scores: {b}, Different scores: {c}, Total: {total}")
# Out:
# No duplicates: 86492, Same scores: 734099, Different scores: 111153, Total: 931744

# %% [markdown]
# #### 2.1) For the rows with the same scores leave those ones with longer pid values

# %%
score_same.head(2)
# Out:
#    Product Id Manufacturer Name Manufacturer PID         model  \
# 0    61085983         CARR-LANE       CL-40-BP-1    CL-40-BP-1
# 3    61068377              Yudo     NZTPIC162150  NZTPIC162150
#
#                  Short Description Long Description Additional description  \
# 0  PLUNGER, 1/4 X 20 PN CL-40-BP-1              NaN                    NaN
# 3                     THERMOCOUPLE              NaN                    NaN
#
#    score matched_pid_left matched_pid_right matched_brand_left  \
# 0  85.71          cl40bp1           cl70bp1           carrlane
# 3  91.67     nztpic162150      nztpic162850               yudo
#
#   matched_brand_right  matched_Product Id matched_model  \
# 0            carrlane            61085352       CL70BP1
# 3                yudo            61072581  NZTPIC162850
#
#   matched_Manufacturer PID matched_Supplier PID matched_Manufacturer Name  \
# 0                  CL70BP1                  NaN                 CARR LANE
# 3             NZTPIC162850                  NaN                      Yudo
#
#   matched_Supplier Name                  pair
# 0                   NaN  (61085352, 61085983)
# 3                   NaN  (61068377, 61072581)

# %%
score_same[score_same['pair']==(61085352, 61085983)]
# Out:
#         Product Id Manufacturer Name Manufacturer PID       model  \
# 0         61085983         CARR-LANE       CL-40-BP-1  CL-40-BP-1
# 701395    61085352         CARR LANE          CL70BP1     CL70BP1
#
#                               Short Description Long Description  \
# 0               PLUNGER, 1/4 X 20 PN CL-40-BP-1              NaN
# 701395  PLUNGER, CARR LANE CL-70-BP-1 BALL NOSE              NaN
#
#        Additional description  score matched_pid_left matched_pid_right  \
# 0                         NaN  85.71          cl40bp1           cl70bp1
# 701395                    NaN  85.71          cl70bp1           cl40bp1
#
#        matched_brand_left matched_brand_right  matched_Product Id  \
# 0                carrlane            carrlane            61085352
# 701395           carrlane            carrlane            61085983
#
#        matched_model matched_Manufacturer PID matched_Supplier PID  \
# 0            CL70BP1                  CL70BP1                  NaN
# 701395    CL-40-BP-1               CL-40-BP-1                  NaN
#
#        matched_Manufacturer Name matched_Supplier Name                  pair
# 0                      CARR LANE                   NaN  (61085352, 61085983)
# 701395                 CARR-LANE                   NaN  (61085352, 61085983)

# %% [markdown]
# The lowest length value is 5

# %%
length_below_6 = score_same[(score_same['length_left'] < 6) | (score_same['length_right'] < 6)]
length_below_6.shape
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\RodrigoMartínezAlons\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'length_left'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 length_below_6 = score_same[(score_same['length_left'] < 6) | (score_same['length_right'] < 6)]
#       2 length_below_6.shape
#
# File c:\Users\RodrigoMartínezAlons\anaconda3\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\RodrigoMartínezAlons\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'length_left'

# %%
length_below_6.length_left.value_counts()
# Out:
# length_left
# 5    38118
# 6     2128
# 7      509
# Name: count, dtype: int64

# %%
length_below_6.length_right.value_counts()
# Out:
# length_right
# 5    37039
# 6     1791
# 4     1597
# 7      328
# Name: count, dtype: int64

# %% [markdown]
# We keep the longest pid values

# %%
score_same['length_left'] = score_same['matched_pid_left'].astype(str).str.len()
score_same['length_right'] = score_same['matched_pid_right'].astype(str).str.len()

score_same['total_length'] = score_same['length_left'] + score_same['length_right']   # Calculate total length
no_duplic_same_score = score_same.loc[score_same.groupby('pair')['total_length'].idxmax()]

# %%
no_duplic_same_score[no_duplic_same_score['pair']==(61085352, 61085983)]
# Out:
#    Product Id Manufacturer Name Manufacturer PID       model  \
# 0    61085983         CARR-LANE       CL-40-BP-1  CL-40-BP-1
#
#                  Short Description Long Description Additional description  \
# 0  PLUNGER, 1/4 X 20 PN CL-40-BP-1              NaN                    NaN
#
#    score matched_pid_left matched_pid_right  ... matched_Product Id  \
# 0  85.71          cl40bp1           cl70bp1  ...           61085352
#
#   matched_model  matched_Manufacturer PID matched_Supplier PID  \
# 0       CL70BP1                   CL70BP1                  NaN
#
#   matched_Manufacturer Name matched_Supplier Name                  pair  \
# 0                 CARR LANE                   NaN  (61085352, 61085983)
#
#   length_left length_right  total_length
# 0           7            7            14
#
# [1 rows x 22 columns]

# %% [markdown]
# No duplicates

# %%
duplicates_in_filtered = no_duplic_same_score[no_duplic_same_score.duplicated(subset=['pair'], keep=False)]
print(duplicates_in_filtered.shape[0])
# Out:
# 0

# %% [markdown]
# #### 2.2) For rows with different score values. Keep the highest and then check the lenght of the pids.

# %%
score_diff_tot.head()
# Out:
#     Product Id Manufacturer Name Manufacturer PID                  model  \
# 1     61085983         CARR-LANE       CL-40-BP-1             CL-40-BP-1
# 2     61085983         CARR-LANE       CL-40-BP-1             CL-40-BP-1
# 6     61085951            Banner         Q23SP6RQ               Q23SP6RQ
# 13    61068180             Bosch       R165111320                    NaN
# 55    61068137             FESTO           163302  DNC-32-100-PPV-A-Q-52
#
#                           Short Description Long Description  \
# 1           PLUNGER, 1/4 X 20 PN CL-40-BP-1              NaN
# 2           PLUNGER, 1/4 X 20 PN CL-40-BP-1              NaN
# 6                          BANNER, Q23SP6RQ              NaN
# 13  BOSCH REXROTH LINEAR R165111320 SIZE 15              NaN
# 55                            Normzylinder               NaN
#
#    Additional description   score matched_pid_left matched_pid_right  \
# 1                     NaN   71.43          cl40bp1          cl40sbp2
# 2                     NaN   58.93          cl40bp1          clm10bp1
# 6                     NaN   75.00         q23sp6rq           q23sp6d
# 13                    NaN   90.00       r165111320         165111320
# 55                    NaN  100.00           163302            163302
#
#    matched_brand_left matched_brand_right  matched_Product Id  \
# 1            carrlane            carrlane            61085952
# 2            carrlane            carrline            61069715
# 6              banner              banner            61098160
# 13              bosch               bosch            60993267
# 55              festo               festo            61003496
#
#            matched_model matched_Manufacturer PID matched_Supplier PID  \
# 1            CL-40-SBP-2              CL-40-SBP-2                  NaN
# 2                    NaN               CLM-10-BP1                  NaN
# 6                Q23SP6D                  Q23SP6D                  NaN
# 13                   NaN              1651-113-20                  NaN
# 55  DNC-32-10-PPV-A-Q-S2                   163302                  NaN
#
#    matched_Manufacturer Name matched_Supplier Name                  pair
# 1                  CARR LANE                   NaN  (61085952, 61085983)
# 2                  CARR LINE                   NaN  (61069715, 61085983)
# 6                     Banner                   NaN  (61085951, 61098160)
# 13             BOSCH REXROTH                   NaN  (60993267, 61068180)
# 55                     FESTO                   NaN  (61003496, 61068137)

# %%
score_diff_tot[score_diff_tot['pair']==(61085952, 61085983)]
# Out:
#         Product Id Manufacturer Name Manufacturer PID        model  \
# 1         61085983         CARR-LANE       CL-40-BP-1   CL-40-BP-1
# 584546    61085952         CARR LANE      CL-40-SBP-2  CL-40-SBP-2
#
#                             Short Description Long Description  \
# 1             PLUNGER, 1/4 X 20 PN CL-40-BP-1              NaN
# 584546  BALL PLUNGER, CARR-LANE # CL-40-SBP-2              NaN
#
#        Additional description  score matched_pid_left matched_pid_right  \
# 1                         NaN  71.43          cl40bp1          cl40sbp2
# 584546                    NaN  75.00         cl40sbp2           cl40bp1
#
#        matched_brand_left matched_brand_right  matched_Product Id  \
# 1                carrlane            carrlane            61085952
# 584546           carrlane            carrlane            61085983
#
#        matched_model matched_Manufacturer PID matched_Supplier PID  \
# 1        CL-40-SBP-2              CL-40-SBP-2                  NaN
# 584546    CL-40-BP-1               CL-40-BP-1                  NaN
#
#        matched_Manufacturer Name matched_Supplier Name                  pair
# 1                      CARR LANE                   NaN  (61085952, 61085983)
# 584546                 CARR-LANE                   NaN  (61085952, 61085983)

# %%
no_duplic_dif_score = score_diff_tot.loc[score_diff_tot.groupby('pair')['score'].idxmax()]

# %%
no_duplic_dif_score.score.describe()
# Out:
# count    26325.000000
# mean        86.433161
# std          8.057110
# min         52.380000
# 25%         81.820000
# 50%         87.500000
# 75%         91.670000
# max        100.000000
# Name: score, dtype: float64

# %%
no_duplic_dif_score[no_duplic_dif_score['pair']==(61085952, 61085983)]
# Out:
#         Product Id Manufacturer Name Manufacturer PID        model  \
# 584546    61085952         CARR LANE      CL-40-SBP-2  CL-40-SBP-2
#
#                             Short Description Long Description  \
# 584546  BALL PLUNGER, CARR-LANE # CL-40-SBP-2              NaN
#
#        Additional description  score matched_pid_left matched_pid_right  \
# 584546                    NaN   75.0         cl40sbp2           cl40bp1
#
#        matched_brand_left matched_brand_right  matched_Product Id  \
# 584546           carrlane            carrlane            61085983
#
#        matched_model matched_Manufacturer PID matched_Supplier PID  \
# 584546    CL-40-BP-1               CL-40-BP-1                  NaN
#
#        matched_Manufacturer Name matched_Supplier Name                  pair
# 584546                 CARR-LANE                   NaN  (61085952, 61085983)

# %%
no_duplic_dif_score['length_left'] = no_duplic_dif_score['matched_pid_left'].astype(str).str.len()
no_duplic_dif_score['length_right'] = no_duplic_dif_score['matched_pid_right'].astype(str).str.len()
length_below_6_dif_score = no_duplic_dif_score[(no_duplic_dif_score['length_left'] < 6) | (no_duplic_dif_score['length_right'] < 6)]

# %%
length_below_6_dif_score.length_left.value_counts()
# Out:
# length_left
# 6    1237
# 7     215
# 5     134
# Name: count, dtype: int64

# %%
length_below_6_dif_score.length_right.value_counts()
# Out:
# length_right
# 5    1583
# 4       3
# Name: count, dtype: int64

# %%
length_below_6_dif_score[length_below_6_dif_score['length_right']==4]
# Out:
#         Product Id Manufacturer Name Manufacturer PID    model  \
# 307639    61024281             FESTO           130610  QSY-8-4
# 307638    61024281             FESTO           130610  QSY-8-4
# 307637    61024281             FESTO           130610  QSY-8-4
#
#         Short Description Long Description Additional description  score  \
# 307639  Y-Steckverbindung              NaN                    NaN   80.0
# 307638  Y-Steckverbindung              NaN                    NaN   80.0
# 307637  Y-Steckverbindung              NaN                    NaN   80.0
#
#        matched_pid_left matched_pid_right  ... matched_brand_right  \
# 307639            qsy84              qs84  ...               festo
# 307638            qsy84              qs84  ...               festo
# 307637            qsy84              qs84  ...               festo
#
#        matched_Product Id  matched_model matched_Manufacturer PID  \
# 307639           61012216         QS-8-4                   130606
# 307638           77140099         QS-8-4                   130606
# 307637           77140301         QS-8-4                   130606
#
#        matched_Supplier PID matched_Manufacturer Name matched_Supplier Name  \
# 307639                  NaN                     FESTO                   NaN
# 307638                  NaN                     FESTO                   NaN
# 307637                  NaN                     FESTO                   NaN
#
#                         pair length_left  length_right
# 307639  (61012216, 61024281)           5             4
# 307638  (61024281, 77140099)           5             4
# 307637  (61024281, 77140301)           5             4
#
# [3 rows x 21 columns]

# %% [markdown]
# #### 2.3) All together without dupilcates

# %%
no_duplic_same_score=no_duplic_same_score.drop(columns=['length_left', 'length_right', 'total_length'])
no_duplic_dif_score=no_duplic_dif_score.drop(columns=['length_left', 'length_right'])

# %%
df_final = pd.concat([no_duplicates, no_duplic_same_score, no_duplic_dif_score], ignore_index=True)

# %%
df_final.head()
# Out:
#    Product Id     Manufacturer Name Manufacturer PID         model  \
# 0    61068240   ROCKWELL AUTOMATION              NaN  140M-C2E-A63
# 1    61068240   ROCKWELL AUTOMATION              NaN  140M-C2E-A63
# 2    61068240   ROCKWELL AUTOMATION              NaN  140M-C2E-A63
# 3    61068385                  Yudo     CYVPTY104500  CYVPTY104500
# 4    61068637  SCHAEFFLER (INA/FAG)    0055453740000       KR16-PP
#
#           Short Description Long Description Additional description  score  \
# 0  140M Motorschutzschalter              NaN                    NaN  70.00
# 1  140M Motorschutzschalter              NaN                    NaN  70.00
# 2  140M Motorschutzschalter              NaN                    NaN  70.00
# 3                 VALVE PIN              NaN                    NaN  75.00
# 4         Nadel-Kurvenrolle              NaN                    NaN  83.33
#
#   matched_pid_left matched_pid_right  matched_brand_left matched_brand_right  \
# 0       140mc2ea63        140mc2eb16  rockwellautomation  rockwellautomation
# 1       140mc2ea63        140mc2eb16  rockwellautomation  rockwellautomation
# 2       140mc2ea63        140mc2eb16  rockwellautomation  rockwellautomation
# 3     cyvpty104500      cyvpty064501                yudo                yudo
# 4           kr16pp           kr16ppa    schaefflerinafag    schaefflerinafag
#
#    matched_Product Id matched_model matched_Manufacturer PID  \
# 0            61093882  140M-C2E-B16                      NaN
# 1            61069420  140M-C2E-B16                      NaN
# 2            61062366           NaN             140M-C2E-B16
# 3            61072643  CYVPTY064501             CYVPTY064501
# 4            61011925           NaN                KR16-PP-A
#
#   matched_Supplier PID matched_Manufacturer Name matched_Supplier Name  \
# 0                  NaN       ROCKWELL AUTOMATION                   NaN
# 1                  NaN       ROCKWELL AUTOMATION                   NaN
# 2                  NaN       ROCKWELL AUTOMATION                   NaN
# 3                  NaN                      Yudo                   NaN
# 4                  NaN      SCHAEFFLER (INA/FAG)                   NaN
#
#                    pair
# 0  (61068240, 61093882)
# 1  (61068240, 61069420)
# 2  (61062366, 61068240)
# 3  (61068385, 61072643)
# 4  (61011925, 61068637)

# %%
df_final.score.describe()
# Out:
# count    240944.000000
# mean         85.199746
# std          10.977235
# min          51.050000
# 25%          79.170000
# 50%          85.710000
# 75%          93.330000
# max         100.000000
# Name: score, dtype: float64

# %%
df_final[df_final['pair']==(60979151, 101023204)]
# Out:
#         Product Id Manufacturer Name Manufacturer PID  \
# 219451   101023204           BALLUFF          BCC02MM
#
#                                   model   Short Description Long Description  \
# 219451  BCC M323-0000-10-001-PX0334-050  Anschlussleitungen              NaN
#
#                                    Additional description  score  \
# 219451  BKS-S49-1-PU-05; replaced by #BCC M323-0000-10...  100.0
#
#        matched_pid_left matched_pid_right matched_brand_left  \
# 219451          bcc02mm           bcc02mm            balluff
#
#        matched_brand_right  matched_Product Id  \
# 219451             balluff            60979151
#
#                          matched_model matched_Manufacturer PID  \
# 219451  BCC M323-0000-10-001-PX0334-05                  BCC02MM
#
#        matched_Supplier PID matched_Manufacturer Name matched_Supplier Name  \
# 219451                  NaN                   BALLUFF                   NaN
#
#                          pair
# 219451  (60979151, 101023204)

# %% [markdown]
# ### 3) Intervals for analysis

# %% [markdown]
# Analyze values in every interval

# %%
intervals = [(i, i + 1) for i in range(90, 100)]
intervals.append((100, 100))

# Count the number of records in each interval
counts = {}
for start, end in intervals:
    if start == end:  # For the last interval (100)
        count = df_final[df_final['score'] == start].shape[0]
    else:
        count = df_final[(df_final['score'] >= start) & (df_final['score'] < end)].shape[0]
    counts[f'{start}-{end}'] = count

for interval, count in counts.items():
    print(f'{interval}: {count}')
# Out:
# 90-91: 14897
# 91-92: 9593
# 92-93: 4165
# 93-94: 8411
# 94-95: 1928
# 95-96: 690
# 96-97: 257
# 97-98: 1
# 98-99: 0
# 99-100: 0
# 100-100: 49615

# %%
intervals = [(i, i + 1) for i in range(90, 100)]
intervals.append((100, 100))  # Add the last interval for 100
sampled_data = []

for start, end in intervals:
    if start == end:
        filtered = df_final[df_final['score'] == start]  # Exact match for 100
    else:
        filtered = df_final[(df_final['score'] >= start) & (df_final['score'] < end)]
    
    # Only sample if there is data available
    if not filtered.empty:
        # Sample 100 values (with replacement if needed)
        sampled = filtered.sample(n=100, replace=True) if len(filtered) < 100 else filtered.sample(n=100, replace=False)
        
        # Add the interval as a new column
        sampled['interval'] = f'{start}-{end}'
        sampled_data.append(sampled)

if sampled_data: 
    df_intervals = pd.concat(sampled_data, ignore_index=True)
else:
    df_intervals = pd.DataFrame()

# %%
df_intervals.interval.value_counts()
# Out:
# interval
# 90-91      100
# 91-92      100
# 92-93      100
# 93-94      100
# 94-95      100
# 95-96      100
# 96-97      100
# 97-98      100
# 100-100    100
# Name: count, dtype: int64

# %%
df_intervals[df_intervals['interval'] == '97-98'].head(2)
# Out:
#      Product Id    Manufacturer Name Manufacturer PID  \
# 700    61249767  Airtree Europe GmbH              NaN
# 701    61249767  Airtree Europe GmbH              NaN
#
#                                                  model Short Description  \
# 700  Airtree MX-24 | Schalldämpfer -  38  Typ AirTr...               NaN
# 701  Airtree MX-24 | Schalldämpfer -  38  Typ AirTr...               NaN
#
#     Long Description Additional description  score  \
# 700              NaN                    NaN  97.56
# 701              NaN                    NaN  97.56
#
#                               matched_pid_left  \
# 700  airtreemx24schalldaempfer38typairtreemx24
# 701  airtreemx24schalldaempfer38typairtreemx24
#
#                              matched_pid_right matched_brand_left  \
# 700  airtreemx24schalldaempfer34typairtreemx24  airtreeeuropegmbh
# 701  airtreemx24schalldaempfer34typairtreemx24  airtreeeuropegmbh
#
#     matched_brand_right  matched_Product Id  \
# 700   airtreeeuropegmbh            61249768
# 701   airtreeeuropegmbh            61249768
#
#                                          matched_model  \
# 700  Airtree MX-24 | Schalldämpfer-34 Typ Air Tree ...
# 701  Airtree MX-24 | Schalldämpfer-34 Typ Air Tree ...
#
#     matched_Manufacturer PID matched_Supplier PID matched_Manufacturer Name  \
# 700                      NaN                  NaN       Airtree Europe GmbH
# 701                      NaN                  NaN       Airtree Europe GmbH
#
#     matched_Supplier Name                  pair interval
# 700                   NaN  (61249767, 61249768)    97-98
# 701                   NaN  (61249767, 61249768)    97-98

# %% [markdown]
# Similar most common values

# %%
df_final.matched_brand_left.value_counts().head(15)
# Out:
# matched_brand_left
# festo                 90453
# siemens               20857
# balluff               13589
# smc                   11206
# bosch                  5165
# keyence                5082
# rockwellautomation     4287
# schneiderelectric      3898
# fanuc                  3836
# ifm                    3717
# builttoprint           3476
# mahlegmbh              3225
# sick                   3169
# eaton                  2847
# harting                2728
# Name: count, dtype: int64

# %%
df_intervals.matched_brand_left.value_counts().head(15)
# Out:
# matched_brand_left
# festo                 180
# balluff               150
# siemens               110
# airtreeeuropegmbh     100
# smc                    31
# bosch                  22
# ifm                    20
# builttoprint           19
# fanuc                  17
# pilz                   16
# rockwellautomation     11
# ferramentaria          11
# kdac                   11
# sick                   10
# murrelektronik          9
# Name: count, dtype: int64

# %%
df_intervals.to_excel('intervals_review.xlsx')
