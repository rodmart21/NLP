# %%
import joblib
import spacy
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from tqdm import tqdm
import pandas as pd
from sklearn.metrics import accuracy_score
import re
from src.utils import *
from sklearn.preprocessing import LabelEncoder
from sentence_transformers import SentenceTransformer
from sklearn.ensemble import RandomForestClassifier
from sklearn.utils.class_weight import compute_class_weight
import json

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Data

# %%
# Full Bayer catalog
pickle_file_path = 'data/results/matched_values.pkl'
filtered_df_noun = pd.read_pickle(pickle_file_path)
filtered_df_noun.head(2)
# Out:
#   cleaned_noun               category_noun
# 0     cylinder  Valves, Actuator, Fittings
# 1     cylinder  Valves, Actuator, Fittings

# %%
# 1k parts Adam reviewed
df_mil=pd.read_csv('data/1k_Parts/BAYER_mat_group_flags_20241206_1k‑verified_20241210.csv')
df_mil = df_mil.dropna(subset=['noun'])  # Some NaN values at the end
df_mil['cleaned_noun'] = df_mil['noun'].apply(clean_category_text)

# %%
# Non matched dataset
df_non_matched=pd.read_pickle('data/results/non_matched_nouns.pkl')

# %% [markdown]
# ### Embeddings. New model

# %%
import numpy as np
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.metrics import classification_report, accuracy_score
from sklearn.preprocessing import LabelEncoder
from sentence_transformers import SentenceTransformer

# %%
X_train_embeddings = pd.read_csv('models/embeddings/sbert_multilingual_train_embeddings.csv').values
X_test_embeddings = pd.read_csv('models/embeddings/sbert_multilingual_test_embeddings.csv').values

encoder = joblib.load('models/embeddings/label_encoder.pkl')

# %%
X = filtered_df_noun['cleaned_noun'].astype(str)  # Ensure input is string
y = filtered_df_noun['category_noun']
encoder = LabelEncoder()
y_encoded = encoder.fit_transform(y)
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.15, random_state=42)

# %%
X_train
# Out:
# 326985                          elbow
# 182828                           disc
# 367195    lager und getriebeanordnung
# 131705                           ball
# 206907                        bushing
#                      ...
# 205626                         spring
# 447800                         nipple
# 228221                       retainer
# 255454                       tornillo
# 209042                        adapter
# Name: cleaned_noun, Length: 233539, dtype: object

# %%
# Compute class weights
class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(y_train),
    y=y_train
)

# Convert class weights to a dictionary
class_weights_dict = {i: weight for i, weight in enumerate(class_weights)}

# Train a Random Forest model with class weights
rf = RandomForestClassifier(
    n_estimators=100,
    max_depth=10,
    random_state=42,
    class_weight=class_weights_dict  # Apply computed weights
)
rf.fit(X_train_embeddings, y_train)

# Evaluate the model
rf_pred = rf.predict(X_test_embeddings)
print("Random Forest Results:")
print(classification_report(y_test, rf_pred, target_names=encoder.classes_))
# Out:
# Random Forest Results:
#                                            precision    recall  f1-score   support
#
# Electrical Installation Materials, device       0.94      0.94      0.94      6834
#                 Equipment OEM Spare Parts       0.77      0.93      0.84       765
#                      Facility consumables       0.93      0.91      0.92      1677
#                                 Fasteners       0.95      0.98      0.96     19434
#        Gas, water and sewage installation       0.96      0.96      0.96      3893
#                          Piping Materials       1.00      0.94      0.97      3033
#                Valves, Actuator, Fittings       0.99      0.92      0.95      5577
#
#                                  accuracy                           0.95     41213
#                                 macro avg       0.94      0.94      0.94     41213
#                              weighted avg       0.96      0.95      0.95     41213

# %%
sbert_model = SentenceTransformer('paraphrase-multilingual-MiniLM-L12-v2')  # Optimized version
new_embeddings = sbert_model.encode(df_mil['cleaned_noun'].tolist(), batch_size=16, show_progress_bar=True)
probabilities = rf.predict_proba(new_embeddings)
probabilities_df = pd.DataFrame(probabilities, columns=encoder.classes_)
probabilities_df = probabilities_df.round(2)  # Round for readability
df_mil['max_probability'] = probabilities_df.max(axis=1)
df_mil['predicted_category'] = probabilities_df.idxmax(axis=1)

# Check why the value retrieved in the last case is zero
df_mil=df_mil.dropna(subset=['max_probability'])

# Compute the metrics
df_mil['qa_label'] = df_mil['qa_label'].astype(str)
df_mil['predicted_category'] = df_mil['predicted_category'].astype(str)
accuracy = accuracy_score(df_mil['qa_label'], df_mil['predicted_category'])
report = classification_report(df_mil['qa_label'], df_mil['predicted_category'])
print(f"Accuracy: {accuracy:.2f}")
print("\nClassification Report:")
print(report)
# Out:
# Batches:   0%|          | 0/62 [00:00<?, ?it/s]
# Accuracy: 0.60
#
# Classification Report:
#                                            precision    recall  f1-score   support
#
# Electrical Installation Materials, device       0.59      0.59      0.59       190
#                 Equipment OEM Spare Parts       0.43      0.07      0.13       121
#                      Facility consumables       0.33      0.41      0.37        27
#                                 Fasteners       0.64      0.89      0.74       329
#        Gas, water and sewage installation       0.48      0.53      0.50        96
#                          Piping Materials       0.69      0.54      0.61        67
#                Valves, Actuator, Fittings       0.68      0.54      0.60       157
#
#                                  accuracy                           0.60       987
#                                 macro avg       0.55      0.51      0.51       987
#                              weighted avg       0.59      0.60      0.57       987

# %%
# For the unmatched nouns
# new_embeddings = pd.read_csv('models/embeddings/sbert_multilingual_train_embeddings_non_matched.csv').values
sbert_model = SentenceTransformer('paraphrase-multilingual-MiniLM-L12-v2')  # Optimized version
new_embeddings = sbert_model.encode(df_non_matched['cleaned_noun'].tolist(), batch_size=16, show_progress_bar=True)

# Apply for the non-matched dataframe
probabilities = rf.predict_proba(new_embeddings)
probabilities_df = pd.DataFrame(probabilities, columns=encoder.classes_)
probabilities_df = probabilities_df.round(2)  # Round for readability
df_non_matched['max_probability'] = probabilities_df.max(axis=1)
df_non_matched['predicted_category'] = probabilities_df.idxmax(axis=1)
df_non_matched.max_probability.describe()
# Out:
# Batches:   0%|          | 0/6755 [00:00<?, ?it/s]
# count    21938.000000
# mean         0.274659
# std          0.088121
# min          0.160000
# 25%          0.220000
# 50%          0.250000
# 75%          0.290000
# max          0.910000
# Name: max_probability, dtype: float64

# %%
# cleaned_noun=df_non_matched['cleaned_noun'].tolist()
# probabilities = rf.predict_proba(new_embeddings)
# probabilities_df = pd.DataFrame(probabilities, columns=encoder.classes_)
# probabilities_df = probabilities_df.round(2)
# probabilities_df['max_probability'] = probabilities_df.max(axis=1)
# probabilities_df['predicted_category'] = probabilities_df.idxmax(axis=1)
# probabilities_df['cleaned_noun'] = cleaned_noun
# probabilities_df.head

# %% [markdown]
# Including Grid Search

# %%
# # Define parameters for Grid Search (Reduced Options)
# rf_params = {
#     'n_estimators': [100, 200],       # Reduced options for number of trees
#     'max_depth': [10, None],          # Simplified depth options
#     'min_samples_split': [2, 5],      # Fewer split options
#     'min_samples_leaf': [1, 2]        # Fewer leaf options
# }

# # Create the Random Forest model
# rf = RandomForestClassifier(random_state=42)

# # Perform Grid Search with 3-fold cross-validation (faster)
# rf_grid = GridSearchCV(rf, rf_params, cv=3, scoring='accuracy', n_jobs=-1, verbose=1)
# rf_grid.fit(X_train_embeddings, y_train)

# # Retrieve the best model
# best_rf = rf_grid.best_estimator_

# # Evaluate the best model
# rf_pred = best_rf.predict(X_test_embeddings)
# print("Random Forest Results:")
# print(classification_report(y_test, rf_pred, target_names=encoder.classes_))

# %% [markdown]
# ### Analyze previous df_mil

# %%
df_mil_review=pd.read_pickle('df_mil_embeddings.pkl')

# %%
df_mil.head()
# Out:
#    Product Id      Quality Status    Manufacturer Name       Manufacturer PID  \
# 0    61959169  SPARROW_PROCESSING                  NaN                  00886
# 1    61999316  SPARROW_PROCESSING                  NaN        BCH16HF07330A5C
# 2    61768659  SPARROW_PROCESSING                  NaN  BREITNER-ABFÜLLANLAGE
# 3    61757206  SPARROW_PROCESSING                  NaN                    NaN
# 4    62069531  SPARROW_PROCESSING  API Schmidt-Bretten               XZ-50114
#
#              model                         Short Description  \
# 0              NaN                 Agitator disc Polyurethan
# 1  BCH16HF07330A5C       Canesten/Servo MotorBCH16HF07330A5C
# 2              NaN                        Motor Antriebsband
# 3              NaN                   TOOL RING SPANNER 8X9MM
# 4         XZ-50114  Dichtung SIGMA M 19 NBR  f.Anfangsplatte
#
#                                     Long Description  \
# 0  Agitator disc Polyurethan; ; Agitator disc Pol...
# 1  Canesten/Servo MotorBCH16HF07330A5C; BCH16HF07...
# 2        Motor Antriebsband; BREITNER-ABFÜLLANLAGE;
# 3                        TOOL RING SPANNER 8X9MM; ;
# 4  Dichtung SIGMA M 19 NBR  f.Anfangsplatte; API ...
#
#                               Additional description score Product family  \
# 0  Agitator disc Polyurethan ( 2 Nos.); Machnine ...   NaN            NaN
# 1                               Canesten Bottel line   NaN            NaN
# 2                                                NaN   NaN            NaN
# 3                                                NaN   NaN            NaN
# 4  Benennung: Dichtung; Typ: SIGMA M 19; Art/Ausf...   NaN            NaN
#
#    ... script_helper mfr_helper noun_helper  mfr noun result match  qa_group  \
# 0  ...         False        NaN       False    Null result present  22104400
# 1  ...         False        NaN       False    Null result present  27140000
# 2  ...         False        NaN       False    Null result present  23070100
# 3  ...         False        NaN       False    Null result present  99501430
# 4  ...         False      False         NaN    Null result present  23070100
#
#                                     qa_label  \
# 0         Gas, water and sewage installation
# 1  Electrical Installation Materials, device
# 2                                  Fasteners
# 3                       Facility consumables
# 4                                  Fasteners
#
#                                          review   cleaned_noun  \
# 0  agitator? Stirring maybe? A kind of turbine?  agitator disc
# 1                                bad extraction          motor
# 2                                bad extraction          motor
# 3                                bad extraction           ring
# 4                              bad string match       dichtung
#
#    max_probability          predicted_category
# 0             0.25                   Fasteners
# 1             0.98  Valves, Actuator, Fittings
# 2             0.98  Valves, Actuator, Fittings
# 3             0.83                   Fasteners
# 4             0.62                   Fasteners
#
# [5 rows x 31 columns]

# %% [markdown]
# Matching for the dictionaries

# %%
with open('data/dict/term_dict_de.json', 'r') as f:
    dict_de = json.load(f)

with open('data/dict/term_dict_en.json', 'r') as f:
    dict_en = json.load(f)

with open('data/dict/term_dict_es.json', 'r') as f:
    dict_es = json.load(f)

dict = dict_de.copy()  # Make a copy to avoid modifying the original
dict.update(dict_en)
dict.update(dict_es)

# %%
dict_en
# Out:
# {'accumulator': 'Electrical Installation Materials, device',
#  'acoustic detector': 'Electrical Installation Materials, device',
#  'ai': 'Electrical Installation Materials, device',
#  'air duct sensor': 'Electrical Installation Materials, device',
#  'alternating current motors': 'Electrical Installation Materials, device',
#  'alternating current switch': 'Electrical Installation Materials, device',
#  'alternator': 'Electrical Installation Materials, device',
#  'ampli': 'Electrical Installation Materials, device',
#  'amplif': 'Electrical Installation Materials, device',
#  'amplificateur': 'Electrical Installation Materials, device',
#  'amplifier': 'Electrical Installation Materials, device',
#  'analog': 'Electrical Installation Materials, device',
#  'analog input': 'Electrical Installation Materials, device',
#  'analog input module': 'Electrical Installation Materials, device',
#  'analog module': 'Electrical Installation Materials, device',
#  'analog output': 'Electrical Installation Materials, device',
#  'analog output module': 'Electrical Installation Materials, device',
#  'analyzer': 'Electrical Installation Materials, device',
#  'antenna': 'Electrical Installation Materials, device',
#  'anturivahvistin': 'Electrical Installation Materials, device',
#  'aparelho': 'Electrical Installation Materials, device',
#  'assembly bridge': 'Electrical Installation Materials, device',
#  'automatic alternating current machine': 'Electrical Installation Materials, device',
#  'automation': 'Electrical Installation Materials, device',
#  'automaton': 'Electrical Installation Materials, device',
#  'auxiliary contacts': 'Electrical Installation Materials, device',
#  'auxiliary current switch': 'Electrical Installation Materials, device',
#  'auxiliary module': 'Electrical Installation Materials, device',
#  'auxiliary supply module': 'Electrical Installation Materials, device',
#  'auxiliary switch': 'Electrical Installation Materials, device',
#  'auxiliary switch block': 'Electrical Installation Materials, device',
#  'auxiliary switch mounted horizontally on the front side': 'Electrical Installation Materials, device',
#  'auxiliary switch side': 'Electrical Installation Materials, device',
#  'auxillary contactor': 'Electrical Installation Materials, device',
#  'background light': 'Electrical Installation Materials, device',
#  'barcode': 'Electrical Installation Materials, device',
#  'barrier': 'Electrical Installation Materials, device',
#  'barriers': 'Electrical Installation Materials, device',
#  'baseunit': 'Electrical Installation Materials, device',
#  'basic switch': 'Electrical Installation Materials, device',
#  'battery': 'Electrical Installation Materials, device',
#  'binary': 'Electrical Installation Materials, device',
#  'binary input': 'Electrical Installation Materials, device',
#  'binary output': 'Electrical Installation Materials, device',
#  'blinker': 'Electrical Installation Materials, device',
#  'blinking': 'Electrical Installation Materials, device',
#  'booster': 'Electrical Installation Materials, device',
#  'brakecontrolmodul': 'Electrical Installation Materials, device',
#  'braking module': 'Electrical Installation Materials, device',
#  'breaker': 'Electrical Installation Materials, device',
#  'bridge': 'Electrical Installation Materials, device',
#  'buffer battery': 'Electrical Installation Materials, device',
#  'bulb': 'Electrical Installation Materials, device',
#  'bus adapter': 'Electrical Installation Materials, device',
#  'bus bar': 'Electrical Installation Materials, device',
#  'bus base': 'Electrical Installation Materials, device',
#  'bus cable': 'Electrical Installation Materials, device',
#  'bus connection': 'Electrical Installation Materials, device',
#  'bus connection module': 'Electrical Installation Materials, device',
#  'bus connector': 'Electrical Installation Materials, device',
#  'bus controller': 'Electrical Installation Materials, device',
#  'bus coupling': 'Electrical Installation Materials, device',
#  'bus link': 'Electrical Installation Materials, device',
#  'bus module': 'Electrical Installation Materials, device',
#  'bus node': 'Electrical Installation Materials, device',
#  'bus plug': 'Electrical Installation Materials, device',
#  'bus receiver': 'Electrical Installation Materials, device',
#  'busbar': 'Electrical Installation Materials, device',
#  'busbar systems': 'Electrical Installation Materials, device',
#  'button': 'Electrical Installation Materials, device',
#  'button switch': 'Electrical Installation Materials, device',
#  'buzzer': 'Electrical Installation Materials, device',
#  'cabinet': 'Electrical Installation Materials, device',
#  'cable': 'Electrical Installation Materials, device',
#  'câble': 'Electrical Installation Materials, device',
#  'cable box': 'Electrical Installation Materials, device',
#  'cable gland': 'Electrical Installation Materials, device',
#  'cable plug': 'Electrical Installation Materials, device',
#  'cable separation': 'Electrical Installation Materials, device',
#  'cabo': 'Electrical Installation Materials, device',
#  'cam ring': 'Electrical Installation Materials, device',
#  'cam switch': 'Electrical Installation Materials, device',
#  'camera': 'Electrical Installation Materials, device',
#  'camshaft control unit': 'Electrical Installation Materials, device',
#  'capacitive proximity sensors': 'Electrical Installation Materials, device',
#  'capacitive sensor': 'Electrical Installation Materials, device',
#  'capacitor': 'Electrical Installation Materials, device',
#  'capacity sensors': 'Electrical Installation Materials, device',
#  'capteur': 'Electrical Installation Materials, device',
#  'card': 'Electrical Installation Materials, device',
#  'carrier module': 'Electrical Installation Materials, device',
#  'carte': 'Electrical Installation Materials, device',
#  'cassette': 'Electrical Installation Materials, device',
#  'cd rom': 'Electrical Installation Materials, device',
#  'cel': 'Electrical Installation Materials, device',
#  'cell': 'Electrical Installation Materials, device',
#  'cellule': 'Electrical Installation Materials, device',
#  'central module': 'Electrical Installation Materials, device',
#  'central processor': 'Electrical Installation Materials, device',
#  'central unit': 'Electrical Installation Materials, device',
#  'charger': 'Electrical Installation Materials, device',
#  'charging station': 'Electrical Installation Materials, device',
#  'chip': 'Electrical Installation Materials, device',
#  'chipcarten': 'Electrical Installation Materials, device',
#  'circuit': 'Electrical Installation Materials, device',
#  'circuit board': 'Electrical Installation Materials, device',
#  'circuit breaker': 'Electrical Installation Materials, device',
#  'closed switch': 'Electrical Installation Materials, device',
#  'coaxial cable': 'Electrical Installation Materials, device',
#  'coaxial connector': 'Electrical Installation Materials, device',
#  'cold appliance cable': 'Electrical Installation Materials, device',
#  'cold conductor release device': 'Electrical Installation Materials, device',
#  'combination reflector': 'Electrical Installation Materials, device',
#  'comm processor': 'Electrical Installation Materials, device',
#  'communication': 'Electrical Installation Materials, device',
#  'communication module': 'Electrical Installation Materials, device',
#  'communication processor': 'Electrical Installation Materials, device',
#  'compact circuit breaker': 'Electrical Installation Materials, device',
#  'compact controller': 'Electrical Installation Materials, device',
#  'compact cpu': 'Electrical Installation Materials, device',
#  'compact module': 'Electrical Installation Materials, device',
#  'complete device': 'Electrical Installation Materials, device',
#  'conductivity sensor': 'Electrical Installation Materials, device',
#  'conductor': 'Electrical Installation Materials, device',
#  'connecting plug': 'Electrical Installation Materials, device',
#  'connection': 'Electrical Installation Materials, device',
#  'connection box': 'Electrical Installation Materials, device',
#  'connection cable': 'Electrical Installation Materials, device',
#  'connection cover': 'Electrical Installation Materials, device',
#  'connection element': 'Electrical Installation Materials, device',
#  'connection housing': 'Electrical Installation Materials, device',
#  'connection line': 'Electrical Installation Materials, device',
#  'connection module': 'Electrical Installation Materials, device',
#  'connection technology': 'Electrical Installation Materials, device',
#  'connectors and cables': 'Electrical Installation Materials, device',
#  'contacor': 'Electrical Installation Materials, device',
#  'contact': 'Electrical Installation Materials, device',
#  'contact device': 'Electrical Installation Materials, device',
#  'contact kit': 'Electrical Installation Materials, device',
#  'contact module': 'Electrical Installation Materials, device',
#  'contacteur': 'Electrical Installation Materials, device',
#  'contactor': 'Electrical Installation Materials, device',
#  'contacts': 'Electrical Installation Materials, device',
#  'contrast sensor': 'Electrical Installation Materials, device',
#  'contrast sensors': 'Electrical Installation Materials, device',
#  'control': 'Electrical Installation Materials, device',
#  'control assembly': 'Electrical Installation Materials, device',
#  'control board': 'Electrical Installation Materials, device',
#  'control box': 'Electrical Installation Materials, device',
#  'control card': 'Electrical Installation Materials, device',
#  'control circuit': 'Electrical Installation Materials, device',
#  'control device': 'Electrical Installation Materials, device',
#  'control disc': 'Electrical Installation Materials, device',
#  'control line kit': 'Electrical Installation Materials, device',
#  'control panel': 'Electrical Installation Materials, device',
#  'control unit': 'Electrical Installation Materials, device',
#  'controler': 'Electrical Installation Materials, device',
#  'controller': 'Electrical Installation Materials, device',
#  'convert': 'Electrical Installation Materials, device',
#  'converter': 'Electrical Installation Materials, device',
#  'cooling fan': 'Electrical Installation Materials, device',
#  'coordinate switch': 'Electrical Installation Materials, device',
#  'coordination processor': 'Electrical Installation Materials, device',
#  'cordset': 'Electrical Installation Materials, device',
#  'counter': 'Electrical Installation Materials, device',
#  'counter assembly': 'Electrical Installation Materials, device',
#  'coupling auxiliary switch': 'Electrical Installation Materials, device',
#  'coupling construction': 'Electrical Installation Materials, device',
#  'coupling guard': 'Electrical Installation Materials, device',
#  'coupling link': 'Electrical Installation Materials, device',
#  'coupling module': 'Electrical Installation Materials, device',
#  'coupling relay': 'Electrical Installation Materials, device',
#  'cpu': 'Electrical Installation Materials, device',
#  'crimp': 'Electrical Installation Materials, device',
#  'current collector': 'Electrical Installation Materials, device',
#  'current sensing module': 'Electrical Installation Materials, device',
#  'current transformer': 'Electrical Installation Materials, device',
#  'current voltage sensing module': 'Electrical Installation Materials, device',
#  'data storage': 'Electrical Installation Materials, device',
#  'detector': 'Electrical Installation Materials, device',
#  'detector cartridge': 'Electrical Installation Materials, device',
#  'device': 'Electrical Installation Materials, device',
#  'device adapter': 'Electrical Installation Materials, device',
#  'diagnosis': 'Electrical Installation Materials, device',
#  'digital': 'Electrical Installation Materials, device',
#  'digital input': 'Electrical Installation Materials, device',
#  'digital input module': 'Electrical Installation Materials, device',
#  'digital output': 'Electrical Installation Materials, device',
#  'digital output module': 'Electrical Installation Materials, device',
#  'diode': 'Electrical Installation Materials, device',
#  'direct current supply': 'Electrical Installation Materials, device',
#  'directional antenna': 'Electrical Installation Materials, device',
#  'discharge': 'Electrical Installation Materials, device',
#  'display': 'Electrical Installation Materials, device',
#  'distance sensors': 'Electrical Installation Materials, device',
#  'door locking mechanism': 'Electrical Installation Materials, device',
#  'e stop': 'Electrical Installation Materials, device',
#  'elecregulator': 'Electrical Installation Materials, device',
#  'electric adapter': 'Electrical Installation Materials, device',
#  'electric connection': 'Electrical Installation Materials, device',
#  'electrical device': 'Electrical Installation Materials, device',
#  'electrical distributor': 'Electrical Installation Materials, device',
#  'electrical plug': 'Electrical Installation Materials, device',
#  'electro distributor': 'Electrical Installation Materials, device',
#  'electrode': 'Electrical Installation Materials, device',
#  'electrodistributeur': 'Electrical Installation Materials, device',
#  'electrodistributor': 'Electrical Installation Materials, device',
#  'electronic': 'Electrical Installation Materials, device',
#  'electronics': 'Electrical Installation Materials, device',
#  'emergency stop': 'Electrical Installation Materials, device',
#  'emitter': 'Electrical Installation Materials, device',
#  'emmitter': 'Electrical Installation Materials, device',
#  'encoder': 'Electrical Installation Materials, device',
#  'end tester': 'Electrical Installation Materials, device',
#  'ethernet': 'Electrical Installation Materials, device',
#  'extension cable': 'Electrical Installation Materials, device',
#  'extension lead': 'Electrical Installation Materials, device',
#  'external relay': 'Electrical Installation Materials, device',
#  'feedback': 'Electrical Installation Materials, device',
#  'fiber': 'Electrical Installation Materials, device',
#  'fiber optic': 'Electrical Installation Materials, device',
#  'fiber optic cable': 'Electrical Installation Materials, device',
#  'fiber optic sensor': 'Electrical Installation Materials, device',
#  'firewall': 'Electrical Installation Materials, device',
#  'flame fuse': 'Electrical Installation Materials, device',
#  'flash': 'Electrical Installation Materials, device',
#  'floppy disc': 'Electrical Installation Materials, device',
#  'floppy disk': 'Electrical Installation Materials, device',
#  'flopy disk': 'Electrical Installation Materials, device',
#  'force measuring device': 'Electrical Installation Materials, device',
#  'fork light barrier': 'Electrical Installation Materials, device',
#  'frequency': 'Electrical Installation Materials, device',
#  'frequency converter': 'Electrical Installation Materials, device',
#  'frequency counter input': 'Electrical Installation Materials, device',
#  'frequency measurement converter': 'Electrical Installation Materials, device',
#  'frequency transducer': 'Electrical Installation Materials, device',
#  'front connector': 'Electrical Installation Materials, device',
#  'front panel': 'Electrical Installation Materials, device',
#  'fuse': 'Electrical Installation Materials, device',
#  'fuse holder': 'Electrical Installation Materials, device',
#  'fuse insert': 'Electrical Installation Materials, device',
#  'fuse puller': 'Electrical Installation Materials, device',
#  'fuses': 'Electrical Installation Materials, device',
#  'gateway': 'Electrical Installation Materials, device',
#  'generator': 'Electrical Installation Materials, device',
#  'graphics card': 'Electrical Installation Materials, device',
#  'grinding detector': 'Electrical Installation Materials, device',
#  'ground': 'Electrical Installation Materials, device',
#  'ground bar kit': 'Electrical Installation Materials, device',
#  'hand fire alarm': 'Electrical Installation Materials, device',
#  'hand fire alarm housing': 'Electrical Installation Materials, device',
#  'hand scanner': 'Electrical Installation Materials, device',
#  'hard drive': 'Electrical Installation Materials, device',
#  'harmonic power': 'Electrical Installation Materials, device',
#  'hdd': 'Electrical Installation Materials, device',
#  'head transmitter': 'Electrical Installation Materials, device',
#  'high load resistance': 'Electrical Installation Materials, device',
#  'high load resistor': 'Electrical Installation Materials, device',
#  'hmi': 'Electrical Installation Materials, device',
#  'hmi display': 'Electrical Installation Materials, device',
#  'i o card': 'Electrical Installation Materials, device',
#  'i o module': 'Electrical Installation Materials, device',
#  'i o subsystem': 'Electrical Installation Materials, device',
#  'io': 'Electrical Installation Materials, device',
#  'id key': 'Electrical Installation Materials, device',
#  'illuminated push button': 'Electrical Installation Materials, device',
#  'impulse response unit': 'Electrical Installation Materials, device',
#  'incremental encoder': 'Electrical Installation Materials, device',
#  'indicator': 'Electrical Installation Materials, device',
#  'indicator light': 'Electrical Installation Materials, device',
#  'indsensor': 'Electrical Installation Materials, device',
#  'inductive': 'Electrical Installation Materials, device',
#  'inductive proximity sensors': 'Electrical Installation Materials, device',
#  'inductive sensor': 'Electrical Installation Materials, device',
#  'industrial ethernet': 'Electrical Installation Materials, device',
#  'industrial ethernet cable': 'Electrical Installation Materials, device',
#  'industrial ethernet kabel': 'Electrical Installation Materials, device',
#  'industrial pc': 'Electrical Installation Materials, device',
#  'industrial switch': 'Electrical Installation Materials, device',
#  'industrial workstation': 'Electrical Installation Materials, device',
#  'industry monitor': 'Electrical Installation Materials, device',
#  'inkremental encoder': 'Electrical Installation Materials, device',
#  'input': 'Electrical Installation Materials, device',
#  'input and output module': 'Electrical Installation Materials, device',
#  'input card': 'Electrical Installation Materials, device',
#  'input module': 'Electrical Installation Materials, device',
#  'input terminal': 'Electrical Installation Materials, device',
#  'input unit': 'Electrical Installation Materials, device',
#  'input yksikkö': 'Electrical Installation Materials, device',
#  'insert module': 'Electrical Installation Materials, device',
#  'inspection cameras': 'Electrical Installation Materials, device',
#  'inspector': 'Electrical Installation Materials, device',
#  'insta protection': 'Electrical Installation Materials, device',
#  'insulation layer': 'Electrical Installation Materials, device',
#  'interface': 'Electrical Installation Materials, device',
#  'interface modul': 'Electrical Installation Materials, device',
#  'interface module': 'Electrical Installation Materials, device',
#  'interfacemodul': 'Electrical Installation Materials, device',
#  'interfacemodule': 'Electrical Installation Materials, device',
#  'interfase': 'Electrical Installation Materials, device',
#  'interrupteur': 'Electrical Installation Materials, device',
#  'inverter': 'Electrical Installation Materials, device',
#  'inverter module': 'Electrical Installation Materials, device',
#  'io yksikkö': 'Electrical Installation Materials, device',
#  'isolation amplifier': 'Electrical Installation Materials, device',
#  'isolator': 'Electrical Installation Materials, device',
#  'jatkokaapeli': 'Electrical Installation Materials, device',
#  'kaapeli': 'Electrical Installation Materials, device',
#  'käyttöpaneeli': 'Electrical Installation Materials, device',
#  'key plug': 'Electrical Installation Materials, device',
#  'key switch': 'Electrical Installation Materials, device',
#  'keyboard': 'Electrical Installation Materials, device',
#  'keyboard shelf': 'Electrical Installation Materials, device',
#  'keyswitch': 'Electrical Installation Materials, device',
#  'kickstart': 'Electrical Installation Materials, device',
#  'kohdevalokenno': 'Electrical Installation Materials, device',
#  'kosketusnäyttö': 'Electrical Installation Materials, device',
#  'kosketusnäyttöpaneeli': 'Electrical Installation Materials, device',
#  'kytkin': 'Electrical Installation Materials, device',
#  'lähtöyksikkö': 'Electrical Installation Materials, device',
#  'lamp': 'Electrical Installation Materials, device',
#  'lämpötila säädin': 'Electrical Installation Materials, device',
#  'lamps': 'Electrical Installation Materials, device',
#  'laser': 'Electrical Installation Materials, device',
#  'laser distance sensor': 'Electrical Installation Materials, device',
#  'laser scanner': 'Electrical Installation Materials, device',
#  'laser sensor head': 'Electrical Installation Materials, device',
#  'lead switch': 'Electrical Installation Materials, device',
#  'led': 'Electrical Installation Materials, device',
#  'led lamp': 'Electrical Installation Materials, device',
#  'led module': 'Electrical Installation Materials, device',
#  'lens': 'Electrical Installation Materials, device',
#  'light': 'Electrical Installation Materials, device',
#  'light barrier': 'Electrical Installation Materials, device',
#  'light barrier test device': 'Electrical Installation Materials, device',
#  'light barrier tester': 'Electrical Installation Materials, device',
#  'light controller': 'Electrical Installation Materials, device',
#  'light curtain': 'Electrical Installation Materials, device',
#  'light element': 'Electrical Installation Materials, device',
#  'light grid': 'Electrical Installation Materials, device',
#  'light guide': 'Electrical Installation Materials, device',
#  'light guide amplifier': 'Electrical Installation Materials, device',
#  'light guide device': 'Electrical Installation Materials, device',
#  'light guide sensor': 'Electrical Installation Materials, device',
#  'light guide sensors': 'Electrical Installation Materials, device',
#  'light sensor': 'Electrical Installation Materials, device',
#  'light switch': 'Electrical Installation Materials, device',
#  'limit signaller': 'Electrical Installation Materials, device',
#  'limit switch': 'Electrical Installation Materials, device',
#  'line contactor': 'Electrical Installation Materials, device',
#  'line tester': 'Electrical Installation Materials, device',
#  'linear mass sensors': 'Electrical Installation Materials, device',
#  'link': 'Electrical Installation Materials, device',
#  'link module': 'Electrical Installation Materials, device',
#  'load cell': 'Electrical Installation Materials, device',
#  'load disconnect switch': 'Electrical Installation Materials, device',
#  'load power supply': 'Electrical Installation Materials, device',
#  'load protection': 'Electrical Installation Materials, device',
#  'load shut off switch': 'Electrical Installation Materials, device',
#  'logic': 'Electrical Installation Materials, device',
#  'logic card': 'Electrical Installation Materials, device',
#  'logic cpu': 'Electrical Installation Materials, device',
#  'logic module': 'Electrical Installation Materials, device',
#  'logiikka': 'Electrical Installation Materials, device',
#  'loudspeaker box': 'Electrical Installation Materials, device',
#  'luminescence sensors': 'Electrical Installation Materials, device',
#  'magnetic field sensor': 'Electrical Installation Materials, device',
#  'magnetic switch': 'Electrical Installation Materials, device',
#  'main contact': 'Electrical Installation Materials, device',
#  'main emergency switch': 'Electrical Installation Materials, device',
#  'main switch': 'Electrical Installation Materials, device',
#  'main switch element': 'Electrical Installation Materials, device',
#  'measurement probe rod': 'Electrical Installation Materials, device',
#  'measurement transmitter': 'Electrical Installation Materials, device',
#  'measuring transformer supply device': 'Electrical Installation Materials, device',
#  'mechanical safety switch': 'Electrical Installation Materials, device',
#  'media conv': 'Electrical Installation Materials, device',
#  'media converter': 'Electrical Installation Materials, device',
#  'media modul': 'Electrical Installation Materials, device',
#  'media module': 'Electrical Installation Materials, device',
#  'meld switch': 'Electrical Installation Materials, device',
#  'memory': 'Electrical Installation Materials, device',
#  'memory backup': 'Electrical Installation Materials, device',
#  'memory backup battery': 'Electrical Installation Materials, device',
#  'memory card': 'Electrical Installation Materials, device',
#  'memory unit': 'Electrical Installation Materials, device',
#  'memorycard': 'Electrical Installation Materials, device',
#  'meter': 'Electrical Installation Materials, device',
#  'meter entry': 'Electrical Installation Materials, device',
#  'meter module': 'Electrical Installation Materials, device',
#  'microsd': 'Electrical Installation Materials, device',
#  'microsd memory card': 'Electrical Installation Materials, device',
#  'microswitch': 'Electrical Installation Materials, device',
#  'mini light barriers': 'Electrical Installation Materials, device',
#  'mobile panel': 'Electrical Installation Materials, device',
#  'modular': 'Electrical Installation Materials, device',
#  'module': 'Electrical Installation Materials, device',
#  'monitor': 'Electrical Installation Materials, device',
#  'monitor module': 'Electrical Installation Materials, device',
#  'monitoring module': 'Electrical Installation Materials, device',
#  'monitoring relay': 'Electrical Installation Materials, device',
#  'moottorikaapeli': 'Electrical Installation Materials, device',
#  'motor cable': 'Electrical Installation Materials, device',
#  'motor controls': 'Electrical Installation Materials, device',
#  'motor protection relay': 'Electrical Installation Materials, device',
#  'motor protection switch': 'Electrical Installation Materials, device',
#  'motor starter': 'Electrical Installation Materials, device',
#  'motorcontroller': 'Electrical Installation Materials, device',
#  'mouse': 'Electrical Installation Materials, device',
#  'muistikortti': 'Electrical Installation Materials, device',
#  'muistinvarmennus': 'Electrical Installation Materials, device',
#  'muistinvarmennusparisto': 'Electrical Installation Materials, device',
#  'multi media card': 'Electrical Installation Materials, device',
#  'multi paneel': 'Electrical Installation Materials, device',
#  'multi panel': 'Electrical Installation Materials, device',
#  'multi vga': 'Electrical Installation Materials, device',
#  'multifunction terminal': 'Electrical Installation Materials, device',
#  'multiplier': 'Electrical Installation Materials, device',
#  'multisocket outlet': 'Electrical Installation Materials, device',
#  'mushroom button': 'Electrical Installation Materials, device',
#  'mushroom push button': 'Electrical Installation Materials, device',
#  'net device': 'Electrical Installation Materials, device',
#  'network choke': 'Electrical Installation Materials, device',
#  'network transition': 'Electrical Installation Materials, device',
#  'operating panel': 'Electrical Installation Materials, device',
#  'operator panel': 'Electrical Installation Materials, device',
#  'operatorpanel': 'Electrical Installation Materials, device',
#  'optic fiber': 'Electrical Installation Materials, device',
#  'optical fiber': 'Electrical Installation Materials, device',
#  'optical proximity switch': 'Electrical Installation Materials, device',
#  'optical sensor': 'Electrical Installation Materials, device',
#  'outlet': 'Electrical Installation Materials, device',
#  'output': 'Electrical Installation Materials, device',
#  'output card': 'Electrical Installation Materials, device',
#  'output coupler': 'Electrical Installation Materials, device',
#  'output extension': 'Electrical Installation Materials, device',
#  'output isolator': 'Electrical Installation Materials, device',
#  'output module': 'Electrical Installation Materials, device',
#  'output repeater': 'Electrical Installation Materials, device',
#  'output seperator': 'Electrical Installation Materials, device',
#  'output unit': 'Electrical Installation Materials, device',
#  'overcurrent relay': 'Electrical Installation Materials, device',
#  'overload': 'Electrical Installation Materials, device',
#  'overload relay': 'Electrical Installation Materials, device',
#  'overvoltage protection': 'Electrical Installation Materials, device',
#  'partition converter': 'Electrical Installation Materials, device',
#  'patch cable': 'Electrical Installation Materials, device',
#  'performance relay': 'Electrical Installation Materials, device',
#  'periphery adapter': 'Electrical Installation Materials, device',
#  'phase busbar': 'Electrical Installation Materials, device',
#  'phase collection rail': 'Electrical Installation Materials, device',
#  'phase feed terminal': 'Electrical Installation Materials, device',
#  'phase motors': 'Electrical Installation Materials, device',
#  'photo sensor': 'Electrical Installation Materials, device',
#  'photo switch': 'Electrical Installation Materials, device',
#  'photocell': 'Electrical Installation Materials, device',
#  'photocells': 'Electrical Installation Materials, device',
#  'photoelectric cell': 'Electrical Installation Materials, device',
#  'photoelectric sensor': 'Electrical Installation Materials, device',
#  'photoelectric switch': 'Electrical Installation Materials, device',
#  'photosensor': 'Electrical Installation Materials, device',
#  'plc': 'Electrical Installation Materials, device',
#  'plug connection': 'Electrical Installation Materials, device',
#  'plug in relay': 'Electrical Installation Materials, device',
#  'plug relay': 'Electrical Installation Materials, device',
#  'plug socket': 'Electrical Installation Materials, device',
#  'plug socket connection': 'Electrical Installation Materials, device',
#  'plug socket slot': 'Electrical Installation Materials, device',
#  'plug transceiver': 'Electrical Installation Materials, device',
#  'plugin': 'Electrical Installation Materials, device',
#  'plugin power supply': 'Electrical Installation Materials, device',
#  'pneumatic actuator': 'Electrical Installation Materials, device',
#  'polarizer': 'Electrical Installation Materials, device',
#  'ports': 'Electrical Installation Materials, device',
#  'position feedback': 'Electrical Installation Materials, device',
#  'position sensors': 'Electrical Installation Materials, device',
#  'position switch': 'Electrical Installation Materials, device',
#  'position switch accessories': 'Electrical Installation Materials, device',
#  'potentiometer': 'Electrical Installation Materials, device',
#  'potentiometer measuring transducer': 'Electrical Installation Materials, device',
#  'power': 'Electrical Installation Materials, device',
#  'power assly': 'Electrical Installation Materials, device',
#  'power cable': 'Electrical Installation Materials, device',
#  'power connector': 'Electrical Installation Materials, device',
#  'power consumption': 'Electrical Installation Materials, device',
#  'power contactor': 'Electrical Installation Materials, device',
#  'power disturbance': 'Electrical Installation Materials, device',
#  'power feed': 'Electrical Installation Materials, device',
#  'power feed block': 'Electrical Installation Materials, device',
#  'power feed module': 'Electrical Installation Materials, device',
#  'power feed terminal': 'Electrical Installation Materials, device',
#  'power feed unit': 'Electrical Installation Materials, device',
#  'power hub': 'Electrical Installation Materials, device',
#  'power modul': 'Electrical Installation Materials, device',
#  'power module': 'Electrical Installation Materials, device',
#  'power modulo': 'Electrical Installation Materials, device',
#  'power output driver': 'Electrical Installation Materials, device',
#  'power pack': 'Electrical Installation Materials, device',
#  'power panel': 'Electrical Installation Materials, device',
#  'power protection': 'Electrical Installation Materials, device',
#  'power rail': 'Electrical Installation Materials, device',
#  'power source': 'Electrical Installation Materials, device',
#  'power supply': 'Electrical Installation Materials, device',
#  'power supply assembly': 'Electrical Installation Materials, device',
#  'power supply construction group': 'Electrical Installation Materials, device',
#  'power supply module': 'Electrical Installation Materials, device',
#  'power supply panelboard': 'Electrical Installation Materials, device',
#  'power supply unit': 'Electrical Installation Materials, device',
#  'power switch': 'Electrical Installation Materials, device',
#  'powerlink cable': 'Electrical Installation Materials, device',
#  'powermodul': 'Electrical Installation Materials, device',
#  'powersupply': 'Electrical Installation Materials, device',
#  'presostato': 'Electrical Installation Materials, device',
#  'press': 'Electrical Installation Materials, device',
#  'pressure switch': 'Electrical Installation Materials, device',
#  'pressure switches': 'Electrical Installation Materials, device',
#  'print head': 'Electrical Installation Materials, device',
#  'print paper': 'Electrical Installation Materials, device',
#  'probe': 'Electrical Installation Materials, device',
#  'probe insert': 'Electrical Installation Materials, device',
#  'probe rod': 'Electrical Installation Materials, device',
#  'processor': 'Electrical Installation Materials, device',
#  'profibus connection': 'Electrical Installation Materials, device',
#  'profibus connector': 'Electrical Installation Materials, device',
#  'profibus dp as interface link': 'Electrical Installation Materials, device',
#  'profibus interface': 'Electrical Installation Materials, device',
#  'profinet connector': 'Electrical Installation Materials, device',
#  'programmable controller': 'Electrical Installation Materials, device',
#  'programmer': 'Electrical Installation Materials, device',
#  'programming device': 'Electrical Installation Materials, device',
#  'programming line': 'Electrical Installation Materials, device',
#  'protection degree': 'Electrical Installation Materials, device',
#  'protection module': 'Electrical Installation Materials, device',
#  'prox sensor': 'Electrical Installation Materials, device',
#  'proximity': 'Electrical Installation Materials, device',
#  'proximity limit switch': 'Electrical Installation Materials, device',
#  'proximity sensor': 'Electrical Installation Materials, device',
#  'proximity switch': 'Electrical Installation Materials, device',
#  'psu': 'Electrical Installation Materials, device',
#  'pulse sensor': 'Electrical Installation Materials, device',
#  'pulssianturi': 'Electrical Installation Materials, device',
#  'puolijohderele': 'Electrical Installation Materials, device',
#  'push button': 'Electrical Installation Materials, device',
#  'pwr sply': 'Electrical Installation Materials, device',
#  'ram': 'Electrical Installation Materials, device',
#  'rangefinder': 'Electrical Installation Materials, device',
#  'rated power': 'Electrical Installation Materials, device',
#  'read write head': 'Electrical Installation Materials, device',
#  'reader': 'Electrical Installation Materials, device',
#  'readout': 'Electrical Installation Materials, device',
#  'realy': 'Electrical Installation Materials, device',
#  'receiver': 'Electrical Installation Materials, device',
#  'recipient': 'Electrical Installation Materials, device',
#  'recorder': 'Electrical Installation Materials, device',
#  'recording': 'Electrical Installation Materials, device',
#  'rectifier': 'Electrical Installation Materials, device',
#  'rectifier device': 'Electrical Installation Materials, device',
#  'redresseur': 'Electrical Installation Materials, device',
#  'redundancy bundl': 'Electrical Installation Materials, device',
#  'redundancy bundle': 'Electrical Installation Materials, device',
#  'redundancy module': 'Electrical Installation Materials, device',
#  'reed contact': 'Electrical Installation Materials, device',
#  'reed switch': 'Electrical Installation Materials, device',
#  'réflecteur': 'Electrical Installation Materials, device',
#  'reflection barrier': 'Electrical Installation Materials, device',
#  'reflection light barrier': 'Electrical Installation Materials, device',
#  'reflection light sensor': 'Electrical Installation Materials, device',
#  'reflection light switch': 'Electrical Installation Materials, device',
#  'reflections light barrier': 'Electrical Installation Materials, device',
#  'reflections light barriers': 'Electrical Installation Materials, device',
#  'reflective film': 'Electrical Installation Materials, device',
#  'reflective foil': 'Electrical Installation Materials, device',
#  'reflective light barrier': 'Electrical Installation Materials, device',
#  'reflector': 'Electrical Installation Materials, device',
#  'reflector holder': 'Electrical Installation Materials, device',
#  'reflector switch': 'Electrical Installation Materials, device',
#  'reflex light switch': 'Electrical Installation Materials, device',
#  'reflex light tester': 'Electrical Installation Materials, device',
#  'relat': 'Electrical Installation Materials, device',
#  'relationship module': 'Electrical Installation Materials, device',
#  'relay': 'Electrical Installation Materials, device',
#  'relay card': 'Electrical Installation Materials, device',
#  'relay coupler': 'Electrical Installation Materials, device',
#  'relay module': 'Electrical Installation Materials, device',
#  'relay output link': 'Electrical Installation Materials, device',
#  'relay socket': 'Electrical Installation Materials, device',
#  'release output': 'Electrical Installation Materials, device',
#  'repeater': 'Electrical Installation Materials, device',
#  'report checker': 'Electrical Installation Materials, device',
#  'reserve module': 'Electrical Installation Materials, device',
#  'resettable e stop': 'Electrical Installation Materials, device',
#  'resistor': 'Electrical Installation Materials, device',
#  'rfid safety switch': 'Electrical Installation Materials, device',
#  'rfid transponder': 'Electrical Installation Materials, device',
#  'rfid writeread device': 'Electrical Installation Materials, device',
#  'ring sensor': 'Electrical Installation Materials, device',
#  'room sensor': 'Electrical Installation Materials, device',
#  'round light element': 'Electrical Installation Materials, device',
#  'router': 'Electrical Installation Materials, device',
#  'rupture disc monitor': 'Electrical Installation Materials, device',
#  'safe series connection': 'Electrical Installation Materials, device',
#  'safety command devices': 'Electrical Installation Materials, device',
#  'safety control unit': 'Electrical Installation Materials, device',
#  'safety controls': 'Electrical Installation Materials, device',
#  'safety digital input module': 'Electrical Installation Materials, device',
#  'safety discharge field': 'Electrical Installation Materials, device',
#  'safety input controller': 'Electrical Installation Materials, device',
#  'safety isolation switch': 'Electrical Installation Materials, device',
#  'safety light barrier': 'Electrical Installation Materials, device',
#  'safety lock': 'Electrical Installation Materials, device',
#  'safety locks': 'Electrical Installation Materials, device',
#  'safety module': 'Electrical Installation Materials, device',
#  'safety position switch': 'Electrical Installation Materials, device',
#  'safety relay': 'Electrical Installation Materials, device',
#  'safety socket': 'Electrical Installation Materials, device',
#  'safety switch': 'Electrical Installation Materials, device',
#  'safety switch device': 'Electrical Installation Materials, device',
#  'safety switch devices': 'Electrical Installation Materials, device',
#  'safety systems': 'Electrical Installation Materials, device',
#  'sähköimilaite': 'Electrical Installation Materials, device',
#  'scanner': 'Electrical Installation Materials, device',
#  'scanner shell': 'Electrical Installation Materials, device',
#  'screen': 'Electrical Installation Materials, device',
#  'selectivity module': 'Electrical Installation Materials, device',
#  'semiconductor fuse': 'Electrical Installation Materials, device',
#  'semiconductor protection': 'Electrical Installation Materials, device',
#  'semiconductor relay': 'Electrical Installation Materials, device',
#  'sensor': 'Electrical Installation Materials, device',
#  'sensor accessories': 'Electrical Installation Materials, device',
#  'sensor box': 'Electrical Installation Materials, device',
#  'sensor cable': 'Electrical Installation Materials, device',
#  'sensor controller': 'Electrical Installation Materials, device',
#  'sensor holder': 'Electrical Installation Materials, device',
#  'sensor light': 'Electrical Installation Materials, device',
#  'sensor measuring transducer': 'Electrical Installation Materials, device',
#  'sensor module': 'Electrical Installation Materials, device',
#  'sensor reflector': 'Electrical Installation Materials, device',
#  'sensors': 'Electrical Installation Materials, device',
#  'separating amplifier': 'Electrical Installation Materials, device',
#  'separation barrier': 'Electrical Installation Materials, device',
#  'separation switch amplifier': 'Electrical Installation Materials, device',
#  'separator card': 'Electrical Installation Materials, device',
#  'separator switch': 'Electrical Installation Materials, device',
#  'serial': 'Electrical Installation Materials, device',
#  'server': 'Electrical Installation Materials, device',
#  'server module': 'Electrical Installation Materials, device',
#  'service cable': 'Electrical Installation Materials, device',
#  'servo': 'Electrical Installation Materials, device',
#  'servo amplifier': 'Electrical Installation Materials, device',
#  'servo controller': 'Electrical Installation Materials, device',
#  'servo drive': 'Electrical Installation Materials, device',
#  'servo inverter': 'Electrical Installation Materials, device',
#  'servo motor': 'Electrical Installation Materials, device',
#  'servo ohjain': 'Electrical Installation Materials, device',
#  'servo pack': 'Electrical Installation Materials, device',
#  'servo regulator': 'Electrical Installation Materials, device',
#  'servokaapeli': 'Electrical Installation Materials, device',
#  'servomoootor': 'Electrical Installation Materials, device',
#  'servomoottoro': 'Electrical Installation Materials, device',
#  'servomoteur': 'Electrical Installation Materials, device',
#  'servomotor': 'Electrical Installation Materials, device',
#  'setpoint module': 'Electrical Installation Materials, device',
#  'shaft switch': 'Electrical Installation Materials, device',
#  'shutdown': 'Electrical Installation Materials, device',
#  'signal': 'Electrical Installation Materials, device',
#  'signal generator': 'Electrical Installation Materials, device',
#  'signal lamp': 'Electrical Installation Materials, device',
#  'signal separator': 'Electrical Installation Materials, device',
#  'signal technology': 'Electrical Installation Materials, device',
#  'signal transformer': 'Electrical Installation Materials, device',
#  'simulater': 'Electrical Installation Materials, device',
#  'simulator': 'Electrical Installation Materials, device',
#  'siren element': 'Electrical Installation Materials, device',
#  'slave': 'Electrical Installation Materials, device',
#  'slave unit': 'Electrical Installation Materials, device',
#  'slave yksikkö': 'Electrical Installation Materials, device',
#  'soft starter': 'Electrical Installation Materials, device',
#  'solid state relay': 'Electrical Installation Materials, device',
#  'solid state relays': 'Electrical Installation Materials, device',
#  'special reflector': 'Electrical Installation Materials, device',
#  'stabilized power': 'Electrical Installation Materials, device',
#  'stabilized power supply': 'Electrical Installation Materials, device',
#  'standon probe': 'Electrical Installation Materials, device',
#  'starter': 'Electrical Installation Materials, device',
#  'starter combination': 'Electrical Installation Materials, device',
#  'starterkombi': 'Electrical Installation Materials, device',
#  'static relay': 'Electrical Installation Materials, device',
#  'station': 'Electrical Installation Materials, device',
#  'stator': 'Electrical Installation Materials, device',
#  'storage': 'Electrical Installation Materials, device',
#  'sub module': 'Electrical Installation Materials, device',
#  'submodule': 'Electrical Installation Materials, device',
#  'subsystem': 'Electrical Installation Materials, device',
#  'supply module': 'Electrical Installation Materials, device',
#  'suppressor surge': 'Electrical Installation Materials, device',
#  'surge arrester': 'Electrical Installation Materials, device',
#  'surge protection device': 'Electrical Installation Materials, device',
#  'surge protector': 'Electrical Installation Materials, device',
#  'surge suppressor': 'Electrical Installation Materials, device',
#  'surge supressor': 'Electrical Installation Materials, device',
#  'switch': 'Electrical Installation Materials, device',
#  'switch amplifier': 'Electrical Installation Materials, device',
#  'switch block': 'Electrical Installation Materials, device',
#  'switch element': 'Electrical Installation Materials, device',
#  'switch module': 'Electrical Installation Materials, device',
#  'switchbox': 'Electrical Installation Materials, device',
#  'switching amplifier': 'Electrical Installation Materials, device',
#  'switching power supply': 'Electrical Installation Materials, device',
#  'switching relay': 'Electrical Installation Materials, device',
#  'switching unit': 'Electrical Installation Materials, device',
#  'swtch': 'Electrical Installation Materials, device',
#  'synchronization module': 'Electrical Installation Materials, device',
#  'synchronous motor': 'Electrical Installation Materials, device',
#  'synchronous servomotor': 'Electrical Installation Materials, device',
#  'taajuusmuuttaja': 'Electrical Installation Materials, device',
#  'tachogenerator': 'Electrical Installation Materials, device',
#  'tachometer': 'Electrical Installation Materials, device',
#  'télémètre': 'Electrical Installation Materials, device',
#  'temp control': 'Electrical Installation Materials, device',
#  'tempcontroller': 'Electrical Installation Materials, device',
#  'temperature bag': 'Electrical Installation Materials, device',
#  'temperature controller': 'Electrical Installation Materials, device',
#  'temperature display': 'Electrical Installation Materials, device',
#  'temperature indicator': 'Electrical Installation Materials, device',
#  'temperature limit switch': 'Electrical Installation Materials, device',
#  'terminal': 'Electrical Installation Materials, device',
#  'terminal amplifier': 'Electrical Installation Materials, device',
#  'terminal block': 'Electrical Installation Materials, device',
#  'terminal box': 'Electrical Installation Materials, device',
#  'terminal cover': 'Electrical Installation Materials, device',
#  'terminal fitting': 'Electrical Installation Materials, device',
#  'terminal modul': 'Electrical Installation Materials, device',
#  'terminal module': 'Electrical Installation Materials, device',
#  'terminal socket': 'Electrical Installation Materials, device',
#  'terminal support': 'Electrical Installation Materials, device',
#  'terminalblock': 'Electrical Installation Materials, device',
#  'terminalmodule': 'Electrical Installation Materials, device',
#  'terminals': 'Electrical Installation Materials, device',
#  'termination': 'Electrical Installation Materials, device',
#  'termination board': 'Electrical Installation Materials, device',
#  'terminator': 'Electrical Installation Materials, device',
#  'test attachment': 'Electrical Installation Materials, device',
#  'text display': 'Electrical Installation Materials, device',
#  'textdisplay': 'Electrical Installation Materials, device',
#  'thermistor relay': 'Electrical Installation Materials, device',
#  'thermomagnetic': 'Electrical Installation Materials, device',
#  'thermoresistance': 'Electrical Installation Materials, device',
#  'thermostat': 'Electrical Installation Materials, device',
#  'threaded junction box': 'Electrical Installation Materials, device',
#  'threaded plug connector': 'Electrical Installation Materials, device',
#  'time': 'Electrical Installation Materials, device',
#  'time relay': 'Electrical Installation Materials, device',
#  'timer': 'Electrical Installation Materials, device',
#  'timers': 'Electrical Installation Materials, device',
#  'toggle switch': 'Electrical Installation Materials, device',
#  'touch display': 'Electrical Installation Materials, device',
#  'touch finder': 'Electrical Installation Materials, device',
#  'touch multipanel': 'Electrical Installation Materials, device',
#  'touch operation': 'Electrical Installation Materials, device',
#  'touch panel': 'Electrical Installation Materials, device',
#  'touch screen': 'Electrical Installation Materials, device',
#  'touch terminal': 'Electrical Installation Materials, device',
#  'touchpanel': 'Electrical Installation Materials, device',
#  'touchscreen': 'Electrical Installation Materials, device',
#  'touchscreen panel': 'Electrical Installation Materials, device',
#  'transformer': 'Electrical Installation Materials, device',
#  'transmitter': 'Electrical Installation Materials, device',
#  'transmitter feed unit': 'Electrical Installation Materials, device',
#  'transmitter power supplies': 'Electrical Installation Materials, device',
#  'transmitter power supply unit': 'Electrical Installation Materials, device',
#  'transmitters': 'Electrical Installation Materials, device',
#  'triangulation sensor': 'Electrical Installation Materials, device',
#  'trip switch': 'Electrical Installation Materials, device',
#  'turvatuloyksikkö': 'Electrical Installation Materials, device',
#  'ultrasonic probe': 'Electrical Installation Materials, device',
#  'ultrasonic sensor': 'Electrical Installation Materials, device',
#  'ultrasonic sensors': 'Electrical Installation Materials, device',
#  'ultrasound': 'Electrical Installation Materials, device',
#  'ultrathinning': 'Electrical Installation Materials, device',
#  'undervoltage release': 'Electrical Installation Materials, device',
#  'unitary controller': 'Electrical Installation Materials, device',
#  'universal module': 'Electrical Installation Materials, device',
#  'universal terminal module': 'Electrical Installation Materials, device',
#  'ups': 'Electrical Installation Materials, device',
#  'ups battery module': 'Electrical Installation Materials, device',
#  'ups module': 'Electrical Installation Materials, device',
#  'usb': 'Electrical Installation Materials, device',
#  'usb cable': 'Electrical Installation Materials, device',
#  'usb pc cable': 'Electrical Installation Materials, device',
#  'user interface': 'Electrical Installation Materials, device',
#  'vacuum switch': 'Electrical Installation Materials, device',
#  'välirele': 'Electrical Installation Materials, device',
#  'välirelekanta': 'Electrical Installation Materials, device',
#  'valo ohjain': 'Electrical Installation Materials, device',
#  'valokuitu': 'Electrical Installation Materials, device',
#  'valokuituanturi': 'Electrical Installation Materials, device',
#  'vibration limit switch': 'Electrical Installation Materials, device',
#  'viewer': 'Electrical Installation Materials, device',
#  'virransyöttöyksikkö': 'Electrical Installation Materials, device',
#  'vision sensors': 'Electrical Installation Materials, device',
#  'voltage converter': 'Electrical Installation Materials, device',
#  'watchdog': 'Electrical Installation Materials, device',
#  'watchdog plug': 'Electrical Installation Materials, device',
#  'weighing electronics': 'Electrical Installation Materials, device',
#  'whole device': 'Electrical Installation Materials, device',
#  'writing reader': 'Electrical Installation Materials, device',
#  'accessories': 'Equipment OEM Spare Parts',
#  'conversion': 'Equipment OEM Spare Parts',
#  'emergency stop housing': 'Electrical Installation Materials, device',
#  'fan replacement package': 'Equipment OEM Spare Parts',
#  'adapter kit': 'Equipment OEM Spare Parts',
#  'assembly kit': 'Equipment OEM Spare Parts',
#  'kit': 'Equipment OEM Spare Parts',
#  'joint set': 'Equipment OEM Spare Parts',
#  'seal kit': 'Equipment OEM Spare Parts',
#  'seal set': 'Equipment OEM Spare Parts',
#  'end stop set': 'Equipment OEM Spare Parts',
#  'hand lever set': 'Equipment OEM Spare Parts',
#  'assembly set': 'Equipment OEM Spare Parts',
#  'motor assembly kit': 'Equipment OEM Spare Parts',
#  'parallel assembly kit': 'Equipment OEM Spare Parts',
#  'rope kit': 'Equipment OEM Spare Parts',
#  'motor accessories': 'Equipment OEM Spare Parts',
#  'mounting set': 'Equipment OEM Spare Parts',
#  'mounting': 'Equipment OEM Spare Parts',
#  'mounting kit': 'Equipment OEM Spare Parts',
#  'mounting parts': 'Equipment OEM Spare Parts',
#  'o ring kit': 'Equipment OEM Spare Parts',
#  'o ring set': 'Equipment OEM Spare Parts',
#  'palletizer': 'Equipment OEM Spare Parts',
#  'parts': 'Equipment OEM Spare Parts',
#  'bush kit': 'Equipment OEM Spare Parts',
#  'bush set': 'Equipment OEM Spare Parts',
#  'sealed gasket set': 'Equipment OEM Spare Parts',
#  'gasket kit': 'Equipment OEM Spare Parts',
#  'membrane seal kit': 'Equipment OEM Spare Parts',
#  'set': 'Equipment OEM Spare Parts',
#  'spare set': 'Equipment OEM Spare Parts',
#  'spare kit': 'Equipment OEM Spare Parts',
#  'sparekit': 'Equipment OEM Spare Parts',
#  'spare parts': 'Equipment OEM Spare Parts',
#  'spare part set': 'Equipment OEM Spare Parts',
#  'spare': 'Equipment OEM Spare Parts',
#  'spare part': 'Equipment OEM Spare Parts',
#  'spares': 'Equipment OEM Spare Parts',
#  'switch mounting kit': 'Equipment OEM Spare Parts',
#  'wear parts set': 'Equipment OEM Spare Parts',
#  '3 jaw chuck': 'Facility consumables',
#  'air gun': 'Facility consumables',
#  'air sparking gun': 'Facility consumables',
#  'angle cutter': 'Facility consumables',
#  'anorak': 'Facility consumables',
#  'apron': 'Facility consumables',
#  'assembly paste': 'Facility consumables',
#  'assembly platform': 'Facility consumables',
#  'automatic door motor': 'Facility consumables',
#  'bags': 'Facility consumables',
#  'basket': 'Facility consumables',
#  'bearing grease': 'Facility consumables',
#  'blade': 'Facility consumables',
#  'boot': 'Facility consumables',
#  'boots': 'Facility consumables',
#  'bottle': 'Facility consumables',
#  'braiding': 'Facility consumables',
#  'brush': 'Facility consumables',
#  'bucket': 'Facility consumables',
#  'canvas': 'Facility consumables',
#  'cardboard': 'Facility consumables',
#  'catch bottle': 'Facility consumables',
#  'center shaft': 'Facility consumables',
#  'centre punch': 'Facility consumables',
#  'chuck': 'Facility consumables',
#  'clamp lever': 'Facility consumables',
#  'cleaner': 'Facility consumables',
#  'cloth': 'Facility consumables',
#  'coat': 'Facility consumables',
#  'cordless phone': 'Facility consumables',
#  'cushion pad': 'Facility consumables',
#  'hose cutter': 'Facility consumables',
#  'deburrer': 'Facility consumables',
#  'dirt scraper': 'Facility consumables',
#  'dispenser': 'Facility consumables',
#  'door lock': 'Facility consumables',
#  'dowel': 'Facility consumables',
#  'drill': 'Facility consumables',
#  'drip tray': 'Facility consumables',
#  'elastic band': 'Facility consumables',
#  'fabric': 'Facility consumables',
#  'fat': 'Facility consumables',
#  'feeler gauge': 'Facility consumables',
#  'feeler guage': 'Facility consumables',
#  'flame protection': 'Facility consumables',
#  'gaiters': 'Facility consumables',
#  'gaiter': 'Facility consumables',
#  'glove': 'Facility consumables',
#  'gloves': 'Facility consumables',
#  'grease': 'Facility consumables',
#  'griff': 'Facility consumables',
#  'grip': 'Facility consumables',
#  'guns': 'Facility consumables',
#  'hair net': 'Facility consumables',
#  'hairnet': 'Facility consumables',
#  'harness': 'Facility consumables',
#  'heat sealing': 'Facility consumables',
#  'ink': 'Facility consumables',
#  'ink cartridge': 'Facility consumables',
#  'inkjet printer': 'Facility consumables',
#  'insole': 'Facility consumables',
#  'installation software': 'Facility consumables',
#  'jacket': 'Facility consumables',
#  'jeans': 'Facility consumables',
#  'knife': 'Facility consumables',
#  'cutter': 'Facility consumables',
#  'craft tape': 'Facility consumables',
#  'label': 'Facility consumables',
#  'label holder': 'Facility consumables',
#  'laminate': 'Facility consumables',
#  'lamp holder': 'Facility consumables',
#  'level': 'Facility consumables',
#  'licence': 'Facility consumables',
#  'license': 'Facility consumables',
#  'lifting fork': 'Facility consumables',
#  'lowtemperature grease': 'Facility consumables',
#  'mandrel': 'Facility consumables',
#  'mirror': 'Facility consumables',
#  'mixing card': 'Facility consumables',
#  'module labels': 'Facility consumables',
#  'oil': 'Facility consumables',
#  'overall': 'Facility consumables',
#  'overalls': 'Facility consumables',
#  'overshoe': 'Facility consumables',
#  'packaging cord': 'Facility consumables',
#  'packaging cords': 'Facility consumables',
#  'partition wall': 'Facility consumables',
#  'peeling knife': 'Facility consumables',
#  'pestle': 'Facility consumables',
#  'pliers': 'Facility consumables',
#  'polo': 'Facility consumables',
#  'pressing': 'Facility consumables',
#  'printer': 'Facility consumables',
#  'printing plate': 'Facility consumables',
#  'program': 'Facility consumables',
#  'protective cap': 'Facility consumables',
#  'protective film': 'Facility consumables',
#  'protective glove': 'Facility consumables',
#  'protector': 'Facility consumables',
#  'rack': 'Facility consumables',
#  'rebuid kit': 'Facility consumables',
#  'rebuild': 'Facility consumables',
#  'rebuild kit': 'Facility consumables',
#  'refrigerant': 'Facility consumables',
#  'repair': 'Facility consumables',
#  'repair set': 'Facility consumables',
#  'gauge repairer': 'Facility consumables',
#  'gauge repair kit': 'Facility consumables',
#  'gauge repair set': 'Facility consumables',
#  'repair sleeve': 'Facility consumables',
#  'rolling bearing grease': 'Facility consumables',
#  'rough grinding wheel': 'Facility consumables',
#  'rubber strip': 'Facility consumables',
#  'ruler': 'Facility consumables',
#  'safety barrier': 'Facility consumables',
#  'safety cabinet': 'Facility consumables',
#  'safety guard': 'Facility consumables',
#  'sample container': 'Facility consumables',
#  'sealant': 'Facility consumables',
#  'sheet': 'Facility consumables',
#  'shield': 'Facility consumables',
#  'shirt': 'Facility consumables',
#  'shoe': 'Facility consumables',
#  'sign carrier': 'Facility consumables',
#  'small protector': 'Facility consumables',
#  'smoke det': 'Facility consumables',
#  'smoke detector': 'Facility consumables',
#  'sock': 'Facility consumables',
#  'socket wrench': 'Facility consumables',
#  'socks': 'Facility consumables',
#  'sofa': 'Facility consumables',
#  'software': 'Facility consumables',
#  'software license': 'Facility consumables',
#  'stamp': 'Facility consumables',
#  'steel': 'Facility consumables',
#  'step ladder': 'Facility consumables',
#  'storage film roller': 'Facility consumables',
#  'storage lid': 'Facility consumables',
#  'strapping band': 'Facility consumables',
#  'sweatpants': 'Facility consumables',
#  'thermal printing paper': 'Facility consumables',
#  'tool': 'Facility consumables',
#  'towel': 'Facility consumables',
#  'tray': 'Facility consumables',
#  'trousers': 'Facility consumables',
#  'tweezers': 'Facility consumables',
#  'undershirt': 'Facility consumables',
#  'velcro pocket': 'Facility consumables',
#  'vest': 'Facility consumables',
#  'walk in guard': 'Facility consumables',
#  'welding bib pants': 'Facility consumables',
#  'wiper': 'Facility consumables',
#  'wiper blade': 'Facility consumables',
#  ...}

# %%
pattern_dict = {term: re.compile(r'\b' + re.escape(term) + r'\b', flags=re.IGNORECASE) for term in dict}

# Function to find the matching term and assign the category
def match_terms_vectorized(noun, pattern_dict):
    for term, pattern in pattern_dict.items():
        if pattern.search(str(noun)):  
            return dict[term], term
    return None, None 

# Apply the function to the whole column
df_mil_review[['matched_category', 'matched_noun']] = df_mil_review['cleaned_noun'].apply(lambda noun: pd.Series(match_terms_vectorized(noun, pattern_dict)))

# %%
df_mil_review.head()
# Out:
#    Product Id      Quality Status    Manufacturer Name       Manufacturer PID  \
# 0    61959169  SPARROW_PROCESSING                  NaN                  00886
# 1    61999316  SPARROW_PROCESSING                  NaN        BCH16HF07330A5C
# 2    61768659  SPARROW_PROCESSING                  NaN  BREITNER-ABFÜLLANLAGE
# 3    61757206  SPARROW_PROCESSING                  NaN                    NaN
# 4    62069531  SPARROW_PROCESSING  API Schmidt-Bretten               XZ-50114
#
#              model                         Short Description  \
# 0              NaN                 Agitator disc Polyurethan
# 1  BCH16HF07330A5C       Canesten/Servo MotorBCH16HF07330A5C
# 2              NaN                        Motor Antriebsband
# 3              NaN                   TOOL RING SPANNER 8X9MM
# 4         XZ-50114  Dichtung SIGMA M 19 NBR  f.Anfangsplatte
#
#                                     Long Description  \
# 0  Agitator disc Polyurethan; ; Agitator disc Pol...
# 1  Canesten/Servo MotorBCH16HF07330A5C; BCH16HF07...
# 2        Motor Antriebsband; BREITNER-ABFÜLLANLAGE;
# 3                        TOOL RING SPANNER 8X9MM; ;
# 4  Dichtung SIGMA M 19 NBR  f.Anfangsplatte; API ...
#
#                               Additional description score Product family  \
# 0  Agitator disc Polyurethan ( 2 Nos.); Machnine ...   NaN            NaN
# 1                               Canesten Bottel line   NaN            NaN
# 2                                                NaN   NaN            NaN
# 3                                                NaN   NaN            NaN
# 4  Benennung: Dichtung; Typ: SIGMA M 19; Art/Ausf...   NaN            NaN
#
#    ... noun_helper mfr noun result match  qa_group  \
# 0  ...       False   Null result present  22104400
# 1  ...       False   Null result present  27140000
# 2  ...       False   Null result present  23070100
# 3  ...       False   Null result present  99501430
# 4  ...         NaN   Null result present  23070100
#
#                                     qa_label  \
# 0         Gas, water and sewage installation
# 1  Electrical Installation Materials, device
# 2                                  Fasteners
# 3                       Facility consumables
# 4                                  Fasteners
#
#                                          review   cleaned_noun  \
# 0  agitator? Stirring maybe? A kind of turbine?  agitator disc
# 1                                bad extraction          motor
# 2                                bad extraction          motor
# 3                                bad extraction           ring
# 4                              bad string match       dichtung
#
#    max_probability          predicted_category            matched_category  \
# 0             0.94                   Fasteners                   Fasteners
# 1             1.00  Valves, Actuator, Fittings  Valves, Actuator, Fittings
# 2             1.00  Valves, Actuator, Fittings  Valves, Actuator, Fittings
# 3             1.00                   Fasteners                   Fasteners
# 4             0.98                   Fasteners                   Fasteners
#
#   matched_noun
# 0         disc
# 1        motor
# 2        motor
# 3         ring
# 4     dichtung
#
# [5 rows x 33 columns]

# %%
df_mil_review.shape
# Out:
# (987, 33)

# %%
df_mil_review.matched_category.value_counts()
# Out:
# matched_category
# Fasteners                                    404
# Electrical Installation Materials, device    172
# Valves, Actuator, Fittings                   141
# Gas, water and sewage installation           105
# Piping Materials                              58
# Facility consumables                          30
# Equipment OEM Spare Parts                      9
# Name: count, dtype: int64

# %%
# Number of NaN values
column_name = 'matched_category'  
nan_count = df_mil_review[column_name].isna().sum()
print(f"Number of NaN values in '{column_name}': {nan_count}")
# Out:
# Number of NaN values in 'matched_category': 68

# %% [markdown]
# Check comparing matched nouns and unmatched

# %%
predicted = df_mil_review['predicted_category']
matched = df_mil_review['matched_category']
qa_label = df_mil_review['qa_label']

valid_matched = ~matched.isna()

report = classification_report(matched[valid_matched], predicted[valid_matched])
print(f"Accuracy: {accuracy:.2f}")
print("\nClassification Report:")
print(report)
# Out:
# Accuracy: 0.60
#
# Classification Report:
#                                            precision    recall  f1-score   support
#
# Electrical Installation Materials, device       0.66      0.64      0.65       172
#                 Equipment OEM Spare Parts       0.38      0.33      0.35         9
#                      Facility consumables       0.50      0.43      0.46        30
#                                 Fasteners       0.78      0.84      0.81       404
#        Gas, water and sewage installation       0.63      0.58      0.60       105
#                          Piping Materials       0.72      0.62      0.67        58
#                Valves, Actuator, Fittings       0.66      0.65      0.65       141
#
#                                  accuracy                           0.71       919
#                                 macro avg       0.62      0.58      0.60       919
#                              weighted avg       0.71      0.71      0.71       919

# %%
df_mil_review[df_mil_review['matched_noun'] == 'anillo']
# Out:
#     Product Id      Quality Status Manufacturer Name Manufacturer PID model  \
# 15    61782339  SPARROW_PROCESSING            Kilian           213813   NaN
# 84    61935909  SPARROW_PROCESSING               NaN              NaN   NaN
#
#          Short Description                                   Long Description  \
# 15  ANILLO OPRESOR;;213813  ANILLO OPRESOR;;213813; KILIAN_213813; Anillo ...
# 84      ANILLO UNICONO 4MM                             ANILLO UNICONO 4MM; ;
#
#        Additional description score Product family  ... noun_helper  \
# 15  Anillo opresor para disco   NaN            NaN  ...       False
# 84                        NaN   NaN            NaN  ...       False
#
#    mfr noun result match  qa_group                   qa_label  \
# 15   Null result present  99501340  Equipment OEM Spare Parts
# 84   Null result present  23070100                  Fasteners
#
#                           review cleaned_noun  max_probability  \
# 15  Engine device - piston clamp       anillo             0.95
# 84                           NaN       anillo             0.72
#
#                            predicted_category  matched_category matched_noun
# 15                                  Fasteners         Fasteners       anillo
# 84  Electrical Installation Materials, device         Fasteners       anillo
#
# [2 rows x 33 columns]

# %%
df_mil_review.to_csv('df_mil_review_embeddings.csv')

# %%
df_mismatch = df_mil_review[df_mil_review['predicted_category'] != df_mil_review['matched_category']]
# df_mismatch = df_mismatch.dropna(subset=['predicted_category'])
# Remove rows where 'predicted_category' is None or NaN
df_mismatch = df_mismatch[df_mismatch['matched_category'].notna()]
df_mismatch.shape
# Out:
# (266, 33)

# %% [markdown]
# Check with Adams categories

# %%
report = classification_report(qa_label[valid_matched], predicted[valid_matched])
print(f"Accuracy: {accuracy:.2f}")
print("\nClassification Report:")
print(report)
# Out:
# Accuracy: 0.60
#
# Classification Report:
#                                            precision    recall  f1-score   support
#
# Electrical Installation Materials, device       0.62      0.59      0.60       174
#                 Equipment OEM Spare Parts       0.62      0.05      0.09        99
#                      Facility consumables       0.42      0.46      0.44        24
#                                 Fasteners       0.65      0.88      0.75       319
#        Gas, water and sewage installation       0.49      0.55      0.52        87
#                          Piping Materials       0.72      0.55      0.63        65
#                Valves, Actuator, Fittings       0.62      0.56      0.59       151
#
#                                  accuracy                           0.62       919
#                                 macro avg       0.59      0.52      0.52       919
#                              weighted avg       0.62      0.62      0.59       919

# %% [markdown]
# Check for the unmatched nouns

# %%
nan_matched = matched.isna()
report = classification_report(qa_label[nan_matched], predicted[nan_matched])
print(f"Accuracy: {accuracy:.2f}")
print("\nClassification Report:")
print(report)
# Out:
# Accuracy: 0.60
#
# Classification Report:
#                                            precision    recall  f1-score   support
#
# Electrical Installation Materials, device       0.31      0.31      0.31        16
#                 Equipment OEM Spare Parts       0.00      0.00      0.00        22
#                      Facility consumables       0.00      0.00      0.00         3
#                                 Fasteners       0.11      0.20      0.14        10
#        Gas, water and sewage installation       0.25      0.44      0.32         9
#                          Piping Materials       0.00      0.00      0.00         2
#                Valves, Actuator, Fittings       0.25      0.33      0.29         6
#
#                                  accuracy                           0.19        68
#                                 macro avg       0.13      0.18      0.15        68
#                              weighted avg       0.15      0.19      0.16        68

# %% [markdown]
# Adam reviews and matched

# %%
report = classification_report(qa_label[valid_matched], matched[valid_matched])
print(f"Accuracy: {accuracy:.2f}")
print("\nClassification Report:")
print(report)
# Out:
# Accuracy: 0.60
#
# Classification Report:
#                                            precision    recall  f1-score   support
#
# Electrical Installation Materials, device       0.88      0.87      0.88       174
#                 Equipment OEM Spare Parts       0.89      0.08      0.15        99
#                      Facility consumables       0.60      0.75      0.67        24
#                                 Fasteners       0.78      0.98      0.87       319
#        Gas, water and sewage installation       0.68      0.82      0.74        87
#                          Piping Materials       0.95      0.85      0.89        65
#                Valves, Actuator, Fittings       0.89      0.83      0.86       151
#
#                                  accuracy                           0.81       919
#                                 macro avg       0.81      0.74      0.72       919
#                              weighted avg       0.83      0.81      0.78       919

# %%
df_mil_review=pd.read_pickle('df_mil_embeddings.pkl')

# %%
df_mil.head()
# Out:
#    Product Id      Quality Status    Manufacturer Name       Manufacturer PID  \
# 0    61959169  SPARROW_PROCESSING                  NaN                  00886
# 1    61999316  SPARROW_PROCESSING                  NaN        BCH16HF07330A5C
# 2    61768659  SPARROW_PROCESSING                  NaN  BREITNER-ABFÜLLANLAGE
# 3    61757206  SPARROW_PROCESSING                  NaN                    NaN
# 4    62069531  SPARROW_PROCESSING  API Schmidt-Bretten               XZ-50114
#
#              model                         Short Description  \
# 0              NaN                 Agitator disc Polyurethan
# 1  BCH16HF07330A5C       Canesten/Servo MotorBCH16HF07330A5C
# 2              NaN                        Motor Antriebsband
# 3              NaN                   TOOL RING SPANNER 8X9MM
# 4         XZ-50114  Dichtung SIGMA M 19 NBR  f.Anfangsplatte
#
#                                     Long Description  \
# 0  Agitator disc Polyurethan; ; Agitator disc Pol...
# 1  Canesten/Servo MotorBCH16HF07330A5C; BCH16HF07...
# 2        Motor Antriebsband; BREITNER-ABFÜLLANLAGE;
# 3                        TOOL RING SPANNER 8X9MM; ;
# 4  Dichtung SIGMA M 19 NBR  f.Anfangsplatte; API ...
#
#                               Additional description score Product family  \
# 0  Agitator disc Polyurethan ( 2 Nos.); Machnine ...   NaN            NaN
# 1                               Canesten Bottel line   NaN            NaN
# 2                                                NaN   NaN            NaN
# 3                                                NaN   NaN            NaN
# 4  Benennung: Dichtung; Typ: SIGMA M 19; Art/Ausf...   NaN            NaN
#
#    ... script_helper mfr_helper noun_helper  mfr noun result match  qa_group  \
# 0  ...         False        NaN       False    Null result present  22104400
# 1  ...         False        NaN       False    Null result present  27140000
# 2  ...         False        NaN       False    Null result present  23070100
# 3  ...         False        NaN       False    Null result present  99501430
# 4  ...         False      False         NaN    Null result present  23070100
#
#                                     qa_label  \
# 0         Gas, water and sewage installation
# 1  Electrical Installation Materials, device
# 2                                  Fasteners
# 3                       Facility consumables
# 4                                  Fasteners
#
#                                          review   cleaned_noun  \
# 0  agitator? Stirring maybe? A kind of turbine?  agitator disc
# 1                                bad extraction          motor
# 2                                bad extraction          motor
# 3                                bad extraction           ring
# 4                              bad string match       dichtung
#
#    max_probability          predicted_category
# 0             0.25                   Fasteners
# 1             0.98  Valves, Actuator, Fittings
# 2             0.98  Valves, Actuator, Fittings
# 3             0.83                   Fasteners
# 4             0.62                   Fasteners
#
# [5 rows x 31 columns]

# %% [markdown]
# Matching for the dictionaries

# %%
with open('data/dict/term_dict_de.json', 'r') as f:
    dict_de = json.load(f)

with open('data/dict/term_dict_en.json', 'r') as f:
    dict_en = json.load(f)

with open('data/dict/term_dict_es.json', 'r') as f:
    dict_es = json.load(f)

dict = dict_de.copy()  # Make a copy to avoid modifying the original
dict.update(dict_en)
dict.update(dict_es)

# %%
dict_en
# Out:
# {'accumulator': 'Electrical Installation Materials, device',
#  'acoustic detector': 'Electrical Installation Materials, device',
#  'ai': 'Electrical Installation Materials, device',
#  'air duct sensor': 'Electrical Installation Materials, device',
#  'alternating current motors': 'Electrical Installation Materials, device',
#  'alternating current switch': 'Electrical Installation Materials, device',
#  'alternator': 'Electrical Installation Materials, device',
#  'ampli': 'Electrical Installation Materials, device',
#  'amplif': 'Electrical Installation Materials, device',
#  'amplificateur': 'Electrical Installation Materials, device',
#  'amplifier': 'Electrical Installation Materials, device',
#  'analog': 'Electrical Installation Materials, device',
#  'analog input': 'Electrical Installation Materials, device',
#  'analog input module': 'Electrical Installation Materials, device',
#  'analog module': 'Electrical Installation Materials, device',
#  'analog output': 'Electrical Installation Materials, device',
#  'analog output module': 'Electrical Installation Materials, device',
#  'analyzer': 'Electrical Installation Materials, device',
#  'antenna': 'Electrical Installation Materials, device',
#  'anturivahvistin': 'Electrical Installation Materials, device',
#  'aparelho': 'Electrical Installation Materials, device',
#  'assembly bridge': 'Electrical Installation Materials, device',
#  'automatic alternating current machine': 'Electrical Installation Materials, device',
#  'automation': 'Electrical Installation Materials, device',
#  'automaton': 'Electrical Installation Materials, device',
#  'auxiliary contacts': 'Electrical Installation Materials, device',
#  'auxiliary current switch': 'Electrical Installation Materials, device',
#  'auxiliary module': 'Electrical Installation Materials, device',
#  'auxiliary supply module': 'Electrical Installation Materials, device',
#  'auxiliary switch': 'Electrical Installation Materials, device',
#  'auxiliary switch block': 'Electrical Installation Materials, device',
#  'auxiliary switch mounted horizontally on the front side': 'Electrical Installation Materials, device',
#  'auxiliary switch side': 'Electrical Installation Materials, device',
#  'auxillary contactor': 'Electrical Installation Materials, device',
#  'background light': 'Electrical Installation Materials, device',
#  'barcode': 'Electrical Installation Materials, device',
#  'barrier': 'Electrical Installation Materials, device',
#  'barriers': 'Electrical Installation Materials, device',
#  'baseunit': 'Electrical Installation Materials, device',
#  'basic switch': 'Electrical Installation Materials, device',
#  'battery': 'Electrical Installation Materials, device',
#  'binary': 'Electrical Installation Materials, device',
#  'binary input': 'Electrical Installation Materials, device',
#  'binary output': 'Electrical Installation Materials, device',
#  'blinker': 'Electrical Installation Materials, device',
#  'blinking': 'Electrical Installation Materials, device',
#  'booster': 'Electrical Installation Materials, device',
#  'brakecontrolmodul': 'Electrical Installation Materials, device',
#  'braking module': 'Electrical Installation Materials, device',
#  'breaker': 'Electrical Installation Materials, device',
#  'bridge': 'Electrical Installation Materials, device',
#  'buffer battery': 'Electrical Installation Materials, device',
#  'bulb': 'Electrical Installation Materials, device',
#  'bus adapter': 'Electrical Installation Materials, device',
#  'bus bar': 'Electrical Installation Materials, device',
#  'bus base': 'Electrical Installation Materials, device',
#  'bus cable': 'Electrical Installation Materials, device',
#  'bus connection': 'Electrical Installation Materials, device',
#  'bus connection module': 'Electrical Installation Materials, device',
#  'bus connector': 'Electrical Installation Materials, device',
#  'bus controller': 'Electrical Installation Materials, device',
#  'bus coupling': 'Electrical Installation Materials, device',
#  'bus link': 'Electrical Installation Materials, device',
#  'bus module': 'Electrical Installation Materials, device',
#  'bus node': 'Electrical Installation Materials, device',
#  'bus plug': 'Electrical Installation Materials, device',
#  'bus receiver': 'Electrical Installation Materials, device',
#  'busbar': 'Electrical Installation Materials, device',
#  'busbar systems': 'Electrical Installation Materials, device',
#  'button': 'Electrical Installation Materials, device',
#  'button switch': 'Electrical Installation Materials, device',
#  'buzzer': 'Electrical Installation Materials, device',
#  'cabinet': 'Electrical Installation Materials, device',
#  'cable': 'Electrical Installation Materials, device',
#  'câble': 'Electrical Installation Materials, device',
#  'cable box': 'Electrical Installation Materials, device',
#  'cable gland': 'Electrical Installation Materials, device',
#  'cable plug': 'Electrical Installation Materials, device',
#  'cable separation': 'Electrical Installation Materials, device',
#  'cabo': 'Electrical Installation Materials, device',
#  'cam ring': 'Electrical Installation Materials, device',
#  'cam switch': 'Electrical Installation Materials, device',
#  'camera': 'Electrical Installation Materials, device',
#  'camshaft control unit': 'Electrical Installation Materials, device',
#  'capacitive proximity sensors': 'Electrical Installation Materials, device',
#  'capacitive sensor': 'Electrical Installation Materials, device',
#  'capacitor': 'Electrical Installation Materials, device',
#  'capacity sensors': 'Electrical Installation Materials, device',
#  'capteur': 'Electrical Installation Materials, device',
#  'card': 'Electrical Installation Materials, device',
#  'carrier module': 'Electrical Installation Materials, device',
#  'carte': 'Electrical Installation Materials, device',
#  'cassette': 'Electrical Installation Materials, device',
#  'cd rom': 'Electrical Installation Materials, device',
#  'cel': 'Electrical Installation Materials, device',
#  'cell': 'Electrical Installation Materials, device',
#  'cellule': 'Electrical Installation Materials, device',
#  'central module': 'Electrical Installation Materials, device',
#  'central processor': 'Electrical Installation Materials, device',
#  'central unit': 'Electrical Installation Materials, device',
#  'charger': 'Electrical Installation Materials, device',
#  'charging station': 'Electrical Installation Materials, device',
#  'chip': 'Electrical Installation Materials, device',
#  'chipcarten': 'Electrical Installation Materials, device',
#  'circuit': 'Electrical Installation Materials, device',
#  'circuit board': 'Electrical Installation Materials, device',
#  'circuit breaker': 'Electrical Installation Materials, device',
#  'closed switch': 'Electrical Installation Materials, device',
#  'coaxial cable': 'Electrical Installation Materials, device',
#  'coaxial connector': 'Electrical Installation Materials, device',
#  'cold appliance cable': 'Electrical Installation Materials, device',
#  'cold conductor release device': 'Electrical Installation Materials, device',
#  'combination reflector': 'Electrical Installation Materials, device',
#  'comm processor': 'Electrical Installation Materials, device',
#  'communication': 'Electrical Installation Materials, device',
#  'communication module': 'Electrical Installation Materials, device',
#  'communication processor': 'Electrical Installation Materials, device',
#  'compact circuit breaker': 'Electrical Installation Materials, device',
#  'compact controller': 'Electrical Installation Materials, device',
#  'compact cpu': 'Electrical Installation Materials, device',
#  'compact module': 'Electrical Installation Materials, device',
#  'complete device': 'Electrical Installation Materials, device',
#  'conductivity sensor': 'Electrical Installation Materials, device',
#  'conductor': 'Electrical Installation Materials, device',
#  'connecting plug': 'Electrical Installation Materials, device',
#  'connection': 'Electrical Installation Materials, device',
#  'connection box': 'Electrical Installation Materials, device',
#  'connection cable': 'Electrical Installation Materials, device',
#  'connection cover': 'Electrical Installation Materials, device',
#  'connection element': 'Electrical Installation Materials, device',
#  'connection housing': 'Electrical Installation Materials, device',
#  'connection line': 'Electrical Installation Materials, device',
#  'connection module': 'Electrical Installation Materials, device',
#  'connection technology': 'Electrical Installation Materials, device',
#  'connectors and cables': 'Electrical Installation Materials, device',
#  'contacor': 'Electrical Installation Materials, device',
#  'contact': 'Electrical Installation Materials, device',
#  'contact device': 'Electrical Installation Materials, device',
#  'contact kit': 'Electrical Installation Materials, device',
#  'contact module': 'Electrical Installation Materials, device',
#  'contacteur': 'Electrical Installation Materials, device',
#  'contactor': 'Electrical Installation Materials, device',
#  'contacts': 'Electrical Installation Materials, device',
#  'contrast sensor': 'Electrical Installation Materials, device',
#  'contrast sensors': 'Electrical Installation Materials, device',
#  'control': 'Electrical Installation Materials, device',
#  'control assembly': 'Electrical Installation Materials, device',
#  'control board': 'Electrical Installation Materials, device',
#  'control box': 'Electrical Installation Materials, device',
#  'control card': 'Electrical Installation Materials, device',
#  'control circuit': 'Electrical Installation Materials, device',
#  'control device': 'Electrical Installation Materials, device',
#  'control disc': 'Electrical Installation Materials, device',
#  'control line kit': 'Electrical Installation Materials, device',
#  'control panel': 'Electrical Installation Materials, device',
#  'control unit': 'Electrical Installation Materials, device',
#  'controler': 'Electrical Installation Materials, device',
#  'controller': 'Electrical Installation Materials, device',
#  'convert': 'Electrical Installation Materials, device',
#  'converter': 'Electrical Installation Materials, device',
#  'cooling fan': 'Electrical Installation Materials, device',
#  'coordinate switch': 'Electrical Installation Materials, device',
#  'coordination processor': 'Electrical Installation Materials, device',
#  'cordset': 'Electrical Installation Materials, device',
#  'counter': 'Electrical Installation Materials, device',
#  'counter assembly': 'Electrical Installation Materials, device',
#  'coupling auxiliary switch': 'Electrical Installation Materials, device',
#  'coupling construction': 'Electrical Installation Materials, device',
#  'coupling guard': 'Electrical Installation Materials, device',
#  'coupling link': 'Electrical Installation Materials, device',
#  'coupling module': 'Electrical Installation Materials, device',
#  'coupling relay': 'Electrical Installation Materials, device',
#  'cpu': 'Electrical Installation Materials, device',
#  'crimp': 'Electrical Installation Materials, device',
#  'current collector': 'Electrical Installation Materials, device',
#  'current sensing module': 'Electrical Installation Materials, device',
#  'current transformer': 'Electrical Installation Materials, device',
#  'current voltage sensing module': 'Electrical Installation Materials, device',
#  'data storage': 'Electrical Installation Materials, device',
#  'detector': 'Electrical Installation Materials, device',
#  'detector cartridge': 'Electrical Installation Materials, device',
#  'device': 'Electrical Installation Materials, device',
#  'device adapter': 'Electrical Installation Materials, device',
#  'diagnosis': 'Electrical Installation Materials, device',
#  'digital': 'Electrical Installation Materials, device',
#  'digital input': 'Electrical Installation Materials, device',
#  'digital input module': 'Electrical Installation Materials, device',
#  'digital output': 'Electrical Installation Materials, device',
#  'digital output module': 'Electrical Installation Materials, device',
#  'diode': 'Electrical Installation Materials, device',
#  'direct current supply': 'Electrical Installation Materials, device',
#  'directional antenna': 'Electrical Installation Materials, device',
#  'discharge': 'Electrical Installation Materials, device',
#  'display': 'Electrical Installation Materials, device',
#  'distance sensors': 'Electrical Installation Materials, device',
#  'door locking mechanism': 'Electrical Installation Materials, device',
#  'e stop': 'Electrical Installation Materials, device',
#  'elecregulator': 'Electrical Installation Materials, device',
#  'electric adapter': 'Electrical Installation Materials, device',
#  'electric connection': 'Electrical Installation Materials, device',
#  'electrical device': 'Electrical Installation Materials, device',
#  'electrical distributor': 'Electrical Installation Materials, device',
#  'electrical plug': 'Electrical Installation Materials, device',
#  'electro distributor': 'Electrical Installation Materials, device',
#  'electrode': 'Electrical Installation Materials, device',
#  'electrodistributeur': 'Electrical Installation Materials, device',
#  'electrodistributor': 'Electrical Installation Materials, device',
#  'electronic': 'Electrical Installation Materials, device',
#  'electronics': 'Electrical Installation Materials, device',
#  'emergency stop': 'Electrical Installation Materials, device',
#  'emitter': 'Electrical Installation Materials, device',
#  'emmitter': 'Electrical Installation Materials, device',
#  'encoder': 'Electrical Installation Materials, device',
#  'end tester': 'Electrical Installation Materials, device',
#  'ethernet': 'Electrical Installation Materials, device',
#  'extension cable': 'Electrical Installation Materials, device',
#  'extension lead': 'Electrical Installation Materials, device',
#  'external relay': 'Electrical Installation Materials, device',
#  'feedback': 'Electrical Installation Materials, device',
#  'fiber': 'Electrical Installation Materials, device',
#  'fiber optic': 'Electrical Installation Materials, device',
#  'fiber optic cable': 'Electrical Installation Materials, device',
#  'fiber optic sensor': 'Electrical Installation Materials, device',
#  'firewall': 'Electrical Installation Materials, device',
#  'flame fuse': 'Electrical Installation Materials, device',
#  'flash': 'Electrical Installation Materials, device',
#  'floppy disc': 'Electrical Installation Materials, device',
#  'floppy disk': 'Electrical Installation Materials, device',
#  'flopy disk': 'Electrical Installation Materials, device',
#  'force measuring device': 'Electrical Installation Materials, device',
#  'fork light barrier': 'Electrical Installation Materials, device',
#  'frequency': 'Electrical Installation Materials, device',
#  'frequency converter': 'Electrical Installation Materials, device',
#  'frequency counter input': 'Electrical Installation Materials, device',
#  'frequency measurement converter': 'Electrical Installation Materials, device',
#  'frequency transducer': 'Electrical Installation Materials, device',
#  'front connector': 'Electrical Installation Materials, device',
#  'front panel': 'Electrical Installation Materials, device',
#  'fuse': 'Electrical Installation Materials, device',
#  'fuse holder': 'Electrical Installation Materials, device',
#  'fuse insert': 'Electrical Installation Materials, device',
#  'fuse puller': 'Electrical Installation Materials, device',
#  'fuses': 'Electrical Installation Materials, device',
#  'gateway': 'Electrical Installation Materials, device',
#  'generator': 'Electrical Installation Materials, device',
#  'graphics card': 'Electrical Installation Materials, device',
#  'grinding detector': 'Electrical Installation Materials, device',
#  'ground': 'Electrical Installation Materials, device',
#  'ground bar kit': 'Electrical Installation Materials, device',
#  'hand fire alarm': 'Electrical Installation Materials, device',
#  'hand fire alarm housing': 'Electrical Installation Materials, device',
#  'hand scanner': 'Electrical Installation Materials, device',
#  'hard drive': 'Electrical Installation Materials, device',
#  'harmonic power': 'Electrical Installation Materials, device',
#  'hdd': 'Electrical Installation Materials, device',
#  'head transmitter': 'Electrical Installation Materials, device',
#  'high load resistance': 'Electrical Installation Materials, device',
#  'high load resistor': 'Electrical Installation Materials, device',
#  'hmi': 'Electrical Installation Materials, device',
#  'hmi display': 'Electrical Installation Materials, device',
#  'i o card': 'Electrical Installation Materials, device',
#  'i o module': 'Electrical Installation Materials, device',
#  'i o subsystem': 'Electrical Installation Materials, device',
#  'io': 'Electrical Installation Materials, device',
#  'id key': 'Electrical Installation Materials, device',
#  'illuminated push button': 'Electrical Installation Materials, device',
#  'impulse response unit': 'Electrical Installation Materials, device',
#  'incremental encoder': 'Electrical Installation Materials, device',
#  'indicator': 'Electrical Installation Materials, device',
#  'indicator light': 'Electrical Installation Materials, device',
#  'indsensor': 'Electrical Installation Materials, device',
#  'inductive': 'Electrical Installation Materials, device',
#  'inductive proximity sensors': 'Electrical Installation Materials, device',
#  'inductive sensor': 'Electrical Installation Materials, device',
#  'industrial ethernet': 'Electrical Installation Materials, device',
#  'industrial ethernet cable': 'Electrical Installation Materials, device',
#  'industrial ethernet kabel': 'Electrical Installation Materials, device',
#  'industrial pc': 'Electrical Installation Materials, device',
#  'industrial switch': 'Electrical Installation Materials, device',
#  'industrial workstation': 'Electrical Installation Materials, device',
#  'industry monitor': 'Electrical Installation Materials, device',
#  'inkremental encoder': 'Electrical Installation Materials, device',
#  'input': 'Electrical Installation Materials, device',
#  'input and output module': 'Electrical Installation Materials, device',
#  'input card': 'Electrical Installation Materials, device',
#  'input module': 'Electrical Installation Materials, device',
#  'input terminal': 'Electrical Installation Materials, device',
#  'input unit': 'Electrical Installation Materials, device',
#  'input yksikkö': 'Electrical Installation Materials, device',
#  'insert module': 'Electrical Installation Materials, device',
#  'inspection cameras': 'Electrical Installation Materials, device',
#  'inspector': 'Electrical Installation Materials, device',
#  'insta protection': 'Electrical Installation Materials, device',
#  'insulation layer': 'Electrical Installation Materials, device',
#  'interface': 'Electrical Installation Materials, device',
#  'interface modul': 'Electrical Installation Materials, device',
#  'interface module': 'Electrical Installation Materials, device',
#  'interfacemodul': 'Electrical Installation Materials, device',
#  'interfacemodule': 'Electrical Installation Materials, device',
#  'interfase': 'Electrical Installation Materials, device',
#  'interrupteur': 'Electrical Installation Materials, device',
#  'inverter': 'Electrical Installation Materials, device',
#  'inverter module': 'Electrical Installation Materials, device',
#  'io yksikkö': 'Electrical Installation Materials, device',
#  'isolation amplifier': 'Electrical Installation Materials, device',
#  'isolator': 'Electrical Installation Materials, device',
#  'jatkokaapeli': 'Electrical Installation Materials, device',
#  'kaapeli': 'Electrical Installation Materials, device',
#  'käyttöpaneeli': 'Electrical Installation Materials, device',
#  'key plug': 'Electrical Installation Materials, device',
#  'key switch': 'Electrical Installation Materials, device',
#  'keyboard': 'Electrical Installation Materials, device',
#  'keyboard shelf': 'Electrical Installation Materials, device',
#  'keyswitch': 'Electrical Installation Materials, device',
#  'kickstart': 'Electrical Installation Materials, device',
#  'kohdevalokenno': 'Electrical Installation Materials, device',
#  'kosketusnäyttö': 'Electrical Installation Materials, device',
#  'kosketusnäyttöpaneeli': 'Electrical Installation Materials, device',
#  'kytkin': 'Electrical Installation Materials, device',
#  'lähtöyksikkö': 'Electrical Installation Materials, device',
#  'lamp': 'Electrical Installation Materials, device',
#  'lämpötila säädin': 'Electrical Installation Materials, device',
#  'lamps': 'Electrical Installation Materials, device',
#  'laser': 'Electrical Installation Materials, device',
#  'laser distance sensor': 'Electrical Installation Materials, device',
#  'laser scanner': 'Electrical Installation Materials, device',
#  'laser sensor head': 'Electrical Installation Materials, device',
#  'lead switch': 'Electrical Installation Materials, device',
#  'led': 'Electrical Installation Materials, device',
#  'led lamp': 'Electrical Installation Materials, device',
#  'led module': 'Electrical Installation Materials, device',
#  'lens': 'Electrical Installation Materials, device',
#  'light': 'Electrical Installation Materials, device',
#  'light barrier': 'Electrical Installation Materials, device',
#  'light barrier test device': 'Electrical Installation Materials, device',
#  'light barrier tester': 'Electrical Installation Materials, device',
#  'light controller': 'Electrical Installation Materials, device',
#  'light curtain': 'Electrical Installation Materials, device',
#  'light element': 'Electrical Installation Materials, device',
#  'light grid': 'Electrical Installation Materials, device',
#  'light guide': 'Electrical Installation Materials, device',
#  'light guide amplifier': 'Electrical Installation Materials, device',
#  'light guide device': 'Electrical Installation Materials, device',
#  'light guide sensor': 'Electrical Installation Materials, device',
#  'light guide sensors': 'Electrical Installation Materials, device',
#  'light sensor': 'Electrical Installation Materials, device',
#  'light switch': 'Electrical Installation Materials, device',
#  'limit signaller': 'Electrical Installation Materials, device',
#  'limit switch': 'Electrical Installation Materials, device',
#  'line contactor': 'Electrical Installation Materials, device',
#  'line tester': 'Electrical Installation Materials, device',
#  'linear mass sensors': 'Electrical Installation Materials, device',
#  'link': 'Electrical Installation Materials, device',
#  'link module': 'Electrical Installation Materials, device',
#  'load cell': 'Electrical Installation Materials, device',
#  'load disconnect switch': 'Electrical Installation Materials, device',
#  'load power supply': 'Electrical Installation Materials, device',
#  'load protection': 'Electrical Installation Materials, device',
#  'load shut off switch': 'Electrical Installation Materials, device',
#  'logic': 'Electrical Installation Materials, device',
#  'logic card': 'Electrical Installation Materials, device',
#  'logic cpu': 'Electrical Installation Materials, device',
#  'logic module': 'Electrical Installation Materials, device',
#  'logiikka': 'Electrical Installation Materials, device',
#  'loudspeaker box': 'Electrical Installation Materials, device',
#  'luminescence sensors': 'Electrical Installation Materials, device',
#  'magnetic field sensor': 'Electrical Installation Materials, device',
#  'magnetic switch': 'Electrical Installation Materials, device',
#  'main contact': 'Electrical Installation Materials, device',
#  'main emergency switch': 'Electrical Installation Materials, device',
#  'main switch': 'Electrical Installation Materials, device',
#  'main switch element': 'Electrical Installation Materials, device',
#  'measurement probe rod': 'Electrical Installation Materials, device',
#  'measurement transmitter': 'Electrical Installation Materials, device',
#  'measuring transformer supply device': 'Electrical Installation Materials, device',
#  'mechanical safety switch': 'Electrical Installation Materials, device',
#  'media conv': 'Electrical Installation Materials, device',
#  'media converter': 'Electrical Installation Materials, device',
#  'media modul': 'Electrical Installation Materials, device',
#  'media module': 'Electrical Installation Materials, device',
#  'meld switch': 'Electrical Installation Materials, device',
#  'memory': 'Electrical Installation Materials, device',
#  'memory backup': 'Electrical Installation Materials, device',
#  'memory backup battery': 'Electrical Installation Materials, device',
#  'memory card': 'Electrical Installation Materials, device',
#  'memory unit': 'Electrical Installation Materials, device',
#  'memorycard': 'Electrical Installation Materials, device',
#  'meter': 'Electrical Installation Materials, device',
#  'meter entry': 'Electrical Installation Materials, device',
#  'meter module': 'Electrical Installation Materials, device',
#  'microsd': 'Electrical Installation Materials, device',
#  'microsd memory card': 'Electrical Installation Materials, device',
#  'microswitch': 'Electrical Installation Materials, device',
#  'mini light barriers': 'Electrical Installation Materials, device',
#  'mobile panel': 'Electrical Installation Materials, device',
#  'modular': 'Electrical Installation Materials, device',
#  'module': 'Electrical Installation Materials, device',
#  'monitor': 'Electrical Installation Materials, device',
#  'monitor module': 'Electrical Installation Materials, device',
#  'monitoring module': 'Electrical Installation Materials, device',
#  'monitoring relay': 'Electrical Installation Materials, device',
#  'moottorikaapeli': 'Electrical Installation Materials, device',
#  'motor cable': 'Electrical Installation Materials, device',
#  'motor controls': 'Electrical Installation Materials, device',
#  'motor protection relay': 'Electrical Installation Materials, device',
#  'motor protection switch': 'Electrical Installation Materials, device',
#  'motor starter': 'Electrical Installation Materials, device',
#  'motorcontroller': 'Electrical Installation Materials, device',
#  'mouse': 'Electrical Installation Materials, device',
#  'muistikortti': 'Electrical Installation Materials, device',
#  'muistinvarmennus': 'Electrical Installation Materials, device',
#  'muistinvarmennusparisto': 'Electrical Installation Materials, device',
#  'multi media card': 'Electrical Installation Materials, device',
#  'multi paneel': 'Electrical Installation Materials, device',
#  'multi panel': 'Electrical Installation Materials, device',
#  'multi vga': 'Electrical Installation Materials, device',
#  'multifunction terminal': 'Electrical Installation Materials, device',
#  'multiplier': 'Electrical Installation Materials, device',
#  'multisocket outlet': 'Electrical Installation Materials, device',
#  'mushroom button': 'Electrical Installation Materials, device',
#  'mushroom push button': 'Electrical Installation Materials, device',
#  'net device': 'Electrical Installation Materials, device',
#  'network choke': 'Electrical Installation Materials, device',
#  'network transition': 'Electrical Installation Materials, device',
#  'operating panel': 'Electrical Installation Materials, device',
#  'operator panel': 'Electrical Installation Materials, device',
#  'operatorpanel': 'Electrical Installation Materials, device',
#  'optic fiber': 'Electrical Installation Materials, device',
#  'optical fiber': 'Electrical Installation Materials, device',
#  'optical proximity switch': 'Electrical Installation Materials, device',
#  'optical sensor': 'Electrical Installation Materials, device',
#  'outlet': 'Electrical Installation Materials, device',
#  'output': 'Electrical Installation Materials, device',
#  'output card': 'Electrical Installation Materials, device',
#  'output coupler': 'Electrical Installation Materials, device',
#  'output extension': 'Electrical Installation Materials, device',
#  'output isolator': 'Electrical Installation Materials, device',
#  'output module': 'Electrical Installation Materials, device',
#  'output repeater': 'Electrical Installation Materials, device',
#  'output seperator': 'Electrical Installation Materials, device',
#  'output unit': 'Electrical Installation Materials, device',
#  'overcurrent relay': 'Electrical Installation Materials, device',
#  'overload': 'Electrical Installation Materials, device',
#  'overload relay': 'Electrical Installation Materials, device',
#  'overvoltage protection': 'Electrical Installation Materials, device',
#  'partition converter': 'Electrical Installation Materials, device',
#  'patch cable': 'Electrical Installation Materials, device',
#  'performance relay': 'Electrical Installation Materials, device',
#  'periphery adapter': 'Electrical Installation Materials, device',
#  'phase busbar': 'Electrical Installation Materials, device',
#  'phase collection rail': 'Electrical Installation Materials, device',
#  'phase feed terminal': 'Electrical Installation Materials, device',
#  'phase motors': 'Electrical Installation Materials, device',
#  'photo sensor': 'Electrical Installation Materials, device',
#  'photo switch': 'Electrical Installation Materials, device',
#  'photocell': 'Electrical Installation Materials, device',
#  'photocells': 'Electrical Installation Materials, device',
#  'photoelectric cell': 'Electrical Installation Materials, device',
#  'photoelectric sensor': 'Electrical Installation Materials, device',
#  'photoelectric switch': 'Electrical Installation Materials, device',
#  'photosensor': 'Electrical Installation Materials, device',
#  'plc': 'Electrical Installation Materials, device',
#  'plug connection': 'Electrical Installation Materials, device',
#  'plug in relay': 'Electrical Installation Materials, device',
#  'plug relay': 'Electrical Installation Materials, device',
#  'plug socket': 'Electrical Installation Materials, device',
#  'plug socket connection': 'Electrical Installation Materials, device',
#  'plug socket slot': 'Electrical Installation Materials, device',
#  'plug transceiver': 'Electrical Installation Materials, device',
#  'plugin': 'Electrical Installation Materials, device',
#  'plugin power supply': 'Electrical Installation Materials, device',
#  'pneumatic actuator': 'Electrical Installation Materials, device',
#  'polarizer': 'Electrical Installation Materials, device',
#  'ports': 'Electrical Installation Materials, device',
#  'position feedback': 'Electrical Installation Materials, device',
#  'position sensors': 'Electrical Installation Materials, device',
#  'position switch': 'Electrical Installation Materials, device',
#  'position switch accessories': 'Electrical Installation Materials, device',
#  'potentiometer': 'Electrical Installation Materials, device',
#  'potentiometer measuring transducer': 'Electrical Installation Materials, device',
#  'power': 'Electrical Installation Materials, device',
#  'power assly': 'Electrical Installation Materials, device',
#  'power cable': 'Electrical Installation Materials, device',
#  'power connector': 'Electrical Installation Materials, device',
#  'power consumption': 'Electrical Installation Materials, device',
#  'power contactor': 'Electrical Installation Materials, device',
#  'power disturbance': 'Electrical Installation Materials, device',
#  'power feed': 'Electrical Installation Materials, device',
#  'power feed block': 'Electrical Installation Materials, device',
#  'power feed module': 'Electrical Installation Materials, device',
#  'power feed terminal': 'Electrical Installation Materials, device',
#  'power feed unit': 'Electrical Installation Materials, device',
#  'power hub': 'Electrical Installation Materials, device',
#  'power modul': 'Electrical Installation Materials, device',
#  'power module': 'Electrical Installation Materials, device',
#  'power modulo': 'Electrical Installation Materials, device',
#  'power output driver': 'Electrical Installation Materials, device',
#  'power pack': 'Electrical Installation Materials, device',
#  'power panel': 'Electrical Installation Materials, device',
#  'power protection': 'Electrical Installation Materials, device',
#  'power rail': 'Electrical Installation Materials, device',
#  'power source': 'Electrical Installation Materials, device',
#  'power supply': 'Electrical Installation Materials, device',
#  'power supply assembly': 'Electrical Installation Materials, device',
#  'power supply construction group': 'Electrical Installation Materials, device',
#  'power supply module': 'Electrical Installation Materials, device',
#  'power supply panelboard': 'Electrical Installation Materials, device',
#  'power supply unit': 'Electrical Installation Materials, device',
#  'power switch': 'Electrical Installation Materials, device',
#  'powerlink cable': 'Electrical Installation Materials, device',
#  'powermodul': 'Electrical Installation Materials, device',
#  'powersupply': 'Electrical Installation Materials, device',
#  'presostato': 'Electrical Installation Materials, device',
#  'press': 'Electrical Installation Materials, device',
#  'pressure switch': 'Electrical Installation Materials, device',
#  'pressure switches': 'Electrical Installation Materials, device',
#  'print head': 'Electrical Installation Materials, device',
#  'print paper': 'Electrical Installation Materials, device',
#  'probe': 'Electrical Installation Materials, device',
#  'probe insert': 'Electrical Installation Materials, device',
#  'probe rod': 'Electrical Installation Materials, device',
#  'processor': 'Electrical Installation Materials, device',
#  'profibus connection': 'Electrical Installation Materials, device',
#  'profibus connector': 'Electrical Installation Materials, device',
#  'profibus dp as interface link': 'Electrical Installation Materials, device',
#  'profibus interface': 'Electrical Installation Materials, device',
#  'profinet connector': 'Electrical Installation Materials, device',
#  'programmable controller': 'Electrical Installation Materials, device',
#  'programmer': 'Electrical Installation Materials, device',
#  'programming device': 'Electrical Installation Materials, device',
#  'programming line': 'Electrical Installation Materials, device',
#  'protection degree': 'Electrical Installation Materials, device',
#  'protection module': 'Electrical Installation Materials, device',
#  'prox sensor': 'Electrical Installation Materials, device',
#  'proximity': 'Electrical Installation Materials, device',
#  'proximity limit switch': 'Electrical Installation Materials, device',
#  'proximity sensor': 'Electrical Installation Materials, device',
#  'proximity switch': 'Electrical Installation Materials, device',
#  'psu': 'Electrical Installation Materials, device',
#  'pulse sensor': 'Electrical Installation Materials, device',
#  'pulssianturi': 'Electrical Installation Materials, device',
#  'puolijohderele': 'Electrical Installation Materials, device',
#  'push button': 'Electrical Installation Materials, device',
#  'pwr sply': 'Electrical Installation Materials, device',
#  'ram': 'Electrical Installation Materials, device',
#  'rangefinder': 'Electrical Installation Materials, device',
#  'rated power': 'Electrical Installation Materials, device',
#  'read write head': 'Electrical Installation Materials, device',
#  'reader': 'Electrical Installation Materials, device',
#  'readout': 'Electrical Installation Materials, device',
#  'realy': 'Electrical Installation Materials, device',
#  'receiver': 'Electrical Installation Materials, device',
#  'recipient': 'Electrical Installation Materials, device',
#  'recorder': 'Electrical Installation Materials, device',
#  'recording': 'Electrical Installation Materials, device',
#  'rectifier': 'Electrical Installation Materials, device',
#  'rectifier device': 'Electrical Installation Materials, device',
#  'redresseur': 'Electrical Installation Materials, device',
#  'redundancy bundl': 'Electrical Installation Materials, device',
#  'redundancy bundle': 'Electrical Installation Materials, device',
#  'redundancy module': 'Electrical Installation Materials, device',
#  'reed contact': 'Electrical Installation Materials, device',
#  'reed switch': 'Electrical Installation Materials, device',
#  'réflecteur': 'Electrical Installation Materials, device',
#  'reflection barrier': 'Electrical Installation Materials, device',
#  'reflection light barrier': 'Electrical Installation Materials, device',
#  'reflection light sensor': 'Electrical Installation Materials, device',
#  'reflection light switch': 'Electrical Installation Materials, device',
#  'reflections light barrier': 'Electrical Installation Materials, device',
#  'reflections light barriers': 'Electrical Installation Materials, device',
#  'reflective film': 'Electrical Installation Materials, device',
#  'reflective foil': 'Electrical Installation Materials, device',
#  'reflective light barrier': 'Electrical Installation Materials, device',
#  'reflector': 'Electrical Installation Materials, device',
#  'reflector holder': 'Electrical Installation Materials, device',
#  'reflector switch': 'Electrical Installation Materials, device',
#  'reflex light switch': 'Electrical Installation Materials, device',
#  'reflex light tester': 'Electrical Installation Materials, device',
#  'relat': 'Electrical Installation Materials, device',
#  'relationship module': 'Electrical Installation Materials, device',
#  'relay': 'Electrical Installation Materials, device',
#  'relay card': 'Electrical Installation Materials, device',
#  'relay coupler': 'Electrical Installation Materials, device',
#  'relay module': 'Electrical Installation Materials, device',
#  'relay output link': 'Electrical Installation Materials, device',
#  'relay socket': 'Electrical Installation Materials, device',
#  'release output': 'Electrical Installation Materials, device',
#  'repeater': 'Electrical Installation Materials, device',
#  'report checker': 'Electrical Installation Materials, device',
#  'reserve module': 'Electrical Installation Materials, device',
#  'resettable e stop': 'Electrical Installation Materials, device',
#  'resistor': 'Electrical Installation Materials, device',
#  'rfid safety switch': 'Electrical Installation Materials, device',
#  'rfid transponder': 'Electrical Installation Materials, device',
#  'rfid writeread device': 'Electrical Installation Materials, device',
#  'ring sensor': 'Electrical Installation Materials, device',
#  'room sensor': 'Electrical Installation Materials, device',
#  'round light element': 'Electrical Installation Materials, device',
#  'router': 'Electrical Installation Materials, device',
#  'rupture disc monitor': 'Electrical Installation Materials, device',
#  'safe series connection': 'Electrical Installation Materials, device',
#  'safety command devices': 'Electrical Installation Materials, device',
#  'safety control unit': 'Electrical Installation Materials, device',
#  'safety controls': 'Electrical Installation Materials, device',
#  'safety digital input module': 'Electrical Installation Materials, device',
#  'safety discharge field': 'Electrical Installation Materials, device',
#  'safety input controller': 'Electrical Installation Materials, device',
#  'safety isolation switch': 'Electrical Installation Materials, device',
#  'safety light barrier': 'Electrical Installation Materials, device',
#  'safety lock': 'Electrical Installation Materials, device',
#  'safety locks': 'Electrical Installation Materials, device',
#  'safety module': 'Electrical Installation Materials, device',
#  'safety position switch': 'Electrical Installation Materials, device',
#  'safety relay': 'Electrical Installation Materials, device',
#  'safety socket': 'Electrical Installation Materials, device',
#  'safety switch': 'Electrical Installation Materials, device',
#  'safety switch device': 'Electrical Installation Materials, device',
#  'safety switch devices': 'Electrical Installation Materials, device',
#  'safety systems': 'Electrical Installation Materials, device',
#  'sähköimilaite': 'Electrical Installation Materials, device',
#  'scanner': 'Electrical Installation Materials, device',
#  'scanner shell': 'Electrical Installation Materials, device',
#  'screen': 'Electrical Installation Materials, device',
#  'selectivity module': 'Electrical Installation Materials, device',
#  'semiconductor fuse': 'Electrical Installation Materials, device',
#  'semiconductor protection': 'Electrical Installation Materials, device',
#  'semiconductor relay': 'Electrical Installation Materials, device',
#  'sensor': 'Electrical Installation Materials, device',
#  'sensor accessories': 'Electrical Installation Materials, device',
#  'sensor box': 'Electrical Installation Materials, device',
#  'sensor cable': 'Electrical Installation Materials, device',
#  'sensor controller': 'Electrical Installation Materials, device',
#  'sensor holder': 'Electrical Installation Materials, device',
#  'sensor light': 'Electrical Installation Materials, device',
#  'sensor measuring transducer': 'Electrical Installation Materials, device',
#  'sensor module': 'Electrical Installation Materials, device',
#  'sensor reflector': 'Electrical Installation Materials, device',
#  'sensors': 'Electrical Installation Materials, device',
#  'separating amplifier': 'Electrical Installation Materials, device',
#  'separation barrier': 'Electrical Installation Materials, device',
#  'separation switch amplifier': 'Electrical Installation Materials, device',
#  'separator card': 'Electrical Installation Materials, device',
#  'separator switch': 'Electrical Installation Materials, device',
#  'serial': 'Electrical Installation Materials, device',
#  'server': 'Electrical Installation Materials, device',
#  'server module': 'Electrical Installation Materials, device',
#  'service cable': 'Electrical Installation Materials, device',
#  'servo': 'Electrical Installation Materials, device',
#  'servo amplifier': 'Electrical Installation Materials, device',
#  'servo controller': 'Electrical Installation Materials, device',
#  'servo drive': 'Electrical Installation Materials, device',
#  'servo inverter': 'Electrical Installation Materials, device',
#  'servo motor': 'Electrical Installation Materials, device',
#  'servo ohjain': 'Electrical Installation Materials, device',
#  'servo pack': 'Electrical Installation Materials, device',
#  'servo regulator': 'Electrical Installation Materials, device',
#  'servokaapeli': 'Electrical Installation Materials, device',
#  'servomoootor': 'Electrical Installation Materials, device',
#  'servomoottoro': 'Electrical Installation Materials, device',
#  'servomoteur': 'Electrical Installation Materials, device',
#  'servomotor': 'Electrical Installation Materials, device',
#  'setpoint module': 'Electrical Installation Materials, device',
#  'shaft switch': 'Electrical Installation Materials, device',
#  'shutdown': 'Electrical Installation Materials, device',
#  'signal': 'Electrical Installation Materials, device',
#  'signal generator': 'Electrical Installation Materials, device',
#  'signal lamp': 'Electrical Installation Materials, device',
#  'signal separator': 'Electrical Installation Materials, device',
#  'signal technology': 'Electrical Installation Materials, device',
#  'signal transformer': 'Electrical Installation Materials, device',
#  'simulater': 'Electrical Installation Materials, device',
#  'simulator': 'Electrical Installation Materials, device',
#  'siren element': 'Electrical Installation Materials, device',
#  'slave': 'Electrical Installation Materials, device',
#  'slave unit': 'Electrical Installation Materials, device',
#  'slave yksikkö': 'Electrical Installation Materials, device',
#  'soft starter': 'Electrical Installation Materials, device',
#  'solid state relay': 'Electrical Installation Materials, device',
#  'solid state relays': 'Electrical Installation Materials, device',
#  'special reflector': 'Electrical Installation Materials, device',
#  'stabilized power': 'Electrical Installation Materials, device',
#  'stabilized power supply': 'Electrical Installation Materials, device',
#  'standon probe': 'Electrical Installation Materials, device',
#  'starter': 'Electrical Installation Materials, device',
#  'starter combination': 'Electrical Installation Materials, device',
#  'starterkombi': 'Electrical Installation Materials, device',
#  'static relay': 'Electrical Installation Materials, device',
#  'station': 'Electrical Installation Materials, device',
#  'stator': 'Electrical Installation Materials, device',
#  'storage': 'Electrical Installation Materials, device',
#  'sub module': 'Electrical Installation Materials, device',
#  'submodule': 'Electrical Installation Materials, device',
#  'subsystem': 'Electrical Installation Materials, device',
#  'supply module': 'Electrical Installation Materials, device',
#  'suppressor surge': 'Electrical Installation Materials, device',
#  'surge arrester': 'Electrical Installation Materials, device',
#  'surge protection device': 'Electrical Installation Materials, device',
#  'surge protector': 'Electrical Installation Materials, device',
#  'surge suppressor': 'Electrical Installation Materials, device',
#  'surge supressor': 'Electrical Installation Materials, device',
#  'switch': 'Electrical Installation Materials, device',
#  'switch amplifier': 'Electrical Installation Materials, device',
#  'switch block': 'Electrical Installation Materials, device',
#  'switch element': 'Electrical Installation Materials, device',
#  'switch module': 'Electrical Installation Materials, device',
#  'switchbox': 'Electrical Installation Materials, device',
#  'switching amplifier': 'Electrical Installation Materials, device',
#  'switching power supply': 'Electrical Installation Materials, device',
#  'switching relay': 'Electrical Installation Materials, device',
#  'switching unit': 'Electrical Installation Materials, device',
#  'swtch': 'Electrical Installation Materials, device',
#  'synchronization module': 'Electrical Installation Materials, device',
#  'synchronous motor': 'Electrical Installation Materials, device',
#  'synchronous servomotor': 'Electrical Installation Materials, device',
#  'taajuusmuuttaja': 'Electrical Installation Materials, device',
#  'tachogenerator': 'Electrical Installation Materials, device',
#  'tachometer': 'Electrical Installation Materials, device',
#  'télémètre': 'Electrical Installation Materials, device',
#  'temp control': 'Electrical Installation Materials, device',
#  'tempcontroller': 'Electrical Installation Materials, device',
#  'temperature bag': 'Electrical Installation Materials, device',
#  'temperature controller': 'Electrical Installation Materials, device',
#  'temperature display': 'Electrical Installation Materials, device',
#  'temperature indicator': 'Electrical Installation Materials, device',
#  'temperature limit switch': 'Electrical Installation Materials, device',
#  'terminal': 'Electrical Installation Materials, device',
#  'terminal amplifier': 'Electrical Installation Materials, device',
#  'terminal block': 'Electrical Installation Materials, device',
#  'terminal box': 'Electrical Installation Materials, device',
#  'terminal cover': 'Electrical Installation Materials, device',
#  'terminal fitting': 'Electrical Installation Materials, device',
#  'terminal modul': 'Electrical Installation Materials, device',
#  'terminal module': 'Electrical Installation Materials, device',
#  'terminal socket': 'Electrical Installation Materials, device',
#  'terminal support': 'Electrical Installation Materials, device',
#  'terminalblock': 'Electrical Installation Materials, device',
#  'terminalmodule': 'Electrical Installation Materials, device',
#  'terminals': 'Electrical Installation Materials, device',
#  'termination': 'Electrical Installation Materials, device',
#  'termination board': 'Electrical Installation Materials, device',
#  'terminator': 'Electrical Installation Materials, device',
#  'test attachment': 'Electrical Installation Materials, device',
#  'text display': 'Electrical Installation Materials, device',
#  'textdisplay': 'Electrical Installation Materials, device',
#  'thermistor relay': 'Electrical Installation Materials, device',
#  'thermomagnetic': 'Electrical Installation Materials, device',
#  'thermoresistance': 'Electrical Installation Materials, device',
#  'thermostat': 'Electrical Installation Materials, device',
#  'threaded junction box': 'Electrical Installation Materials, device',
#  'threaded plug connector': 'Electrical Installation Materials, device',
#  'time': 'Electrical Installation Materials, device',
#  'time relay': 'Electrical Installation Materials, device',
#  'timer': 'Electrical Installation Materials, device',
#  'timers': 'Electrical Installation Materials, device',
#  'toggle switch': 'Electrical Installation Materials, device',
#  'touch display': 'Electrical Installation Materials, device',
#  'touch finder': 'Electrical Installation Materials, device',
#  'touch multipanel': 'Electrical Installation Materials, device',
#  'touch operation': 'Electrical Installation Materials, device',
#  'touch panel': 'Electrical Installation Materials, device',
#  'touch screen': 'Electrical Installation Materials, device',
#  'touch terminal': 'Electrical Installation Materials, device',
#  'touchpanel': 'Electrical Installation Materials, device',
#  'touchscreen': 'Electrical Installation Materials, device',
#  'touchscreen panel': 'Electrical Installation Materials, device',
#  'transformer': 'Electrical Installation Materials, device',
#  'transmitter': 'Electrical Installation Materials, device',
#  'transmitter feed unit': 'Electrical Installation Materials, device',
#  'transmitter power supplies': 'Electrical Installation Materials, device',
#  'transmitter power supply unit': 'Electrical Installation Materials, device',
#  'transmitters': 'Electrical Installation Materials, device',
#  'triangulation sensor': 'Electrical Installation Materials, device',
#  'trip switch': 'Electrical Installation Materials, device',
#  'turvatuloyksikkö': 'Electrical Installation Materials, device',
#  'ultrasonic probe': 'Electrical Installation Materials, device',
#  'ultrasonic sensor': 'Electrical Installation Materials, device',
#  'ultrasonic sensors': 'Electrical Installation Materials, device',
#  'ultrasound': 'Electrical Installation Materials, device',
#  'ultrathinning': 'Electrical Installation Materials, device',
#  'undervoltage release': 'Electrical Installation Materials, device',
#  'unitary controller': 'Electrical Installation Materials, device',
#  'universal module': 'Electrical Installation Materials, device',
#  'universal terminal module': 'Electrical Installation Materials, device',
#  'ups': 'Electrical Installation Materials, device',
#  'ups battery module': 'Electrical Installation Materials, device',
#  'ups module': 'Electrical Installation Materials, device',
#  'usb': 'Electrical Installation Materials, device',
#  'usb cable': 'Electrical Installation Materials, device',
#  'usb pc cable': 'Electrical Installation Materials, device',
#  'user interface': 'Electrical Installation Materials, device',
#  'vacuum switch': 'Electrical Installation Materials, device',
#  'välirele': 'Electrical Installation Materials, device',
#  'välirelekanta': 'Electrical Installation Materials, device',
#  'valo ohjain': 'Electrical Installation Materials, device',
#  'valokuitu': 'Electrical Installation Materials, device',
#  'valokuituanturi': 'Electrical Installation Materials, device',
#  'vibration limit switch': 'Electrical Installation Materials, device',
#  'viewer': 'Electrical Installation Materials, device',
#  'virransyöttöyksikkö': 'Electrical Installation Materials, device',
#  'vision sensors': 'Electrical Installation Materials, device',
#  'voltage converter': 'Electrical Installation Materials, device',
#  'watchdog': 'Electrical Installation Materials, device',
#  'watchdog plug': 'Electrical Installation Materials, device',
#  'weighing electronics': 'Electrical Installation Materials, device',
#  'whole device': 'Electrical Installation Materials, device',
#  'writing reader': 'Electrical Installation Materials, device',
#  'accessories': 'Equipment OEM Spare Parts',
#  'conversion': 'Equipment OEM Spare Parts',
#  'emergency stop housing': 'Electrical Installation Materials, device',
#  'fan replacement package': 'Equipment OEM Spare Parts',
#  'adapter kit': 'Equipment OEM Spare Parts',
#  'assembly kit': 'Equipment OEM Spare Parts',
#  'kit': 'Equipment OEM Spare Parts',
#  'joint set': 'Equipment OEM Spare Parts',
#  'seal kit': 'Equipment OEM Spare Parts',
#  'seal set': 'Equipment OEM Spare Parts',
#  'end stop set': 'Equipment OEM Spare Parts',
#  'hand lever set': 'Equipment OEM Spare Parts',
#  'assembly set': 'Equipment OEM Spare Parts',
#  'motor assembly kit': 'Equipment OEM Spare Parts',
#  'parallel assembly kit': 'Equipment OEM Spare Parts',
#  'rope kit': 'Equipment OEM Spare Parts',
#  'motor accessories': 'Equipment OEM Spare Parts',
#  'mounting set': 'Equipment OEM Spare Parts',
#  'mounting': 'Equipment OEM Spare Parts',
#  'mounting kit': 'Equipment OEM Spare Parts',
#  'mounting parts': 'Equipment OEM Spare Parts',
#  'o ring kit': 'Equipment OEM Spare Parts',
#  'o ring set': 'Equipment OEM Spare Parts',
#  'palletizer': 'Equipment OEM Spare Parts',
#  'parts': 'Equipment OEM Spare Parts',
#  'bush kit': 'Equipment OEM Spare Parts',
#  'bush set': 'Equipment OEM Spare Parts',
#  'sealed gasket set': 'Equipment OEM Spare Parts',
#  'gasket kit': 'Equipment OEM Spare Parts',
#  'membrane seal kit': 'Equipment OEM Spare Parts',
#  'set': 'Equipment OEM Spare Parts',
#  'spare set': 'Equipment OEM Spare Parts',
#  'spare kit': 'Equipment OEM Spare Parts',
#  'sparekit': 'Equipment OEM Spare Parts',
#  'spare parts': 'Equipment OEM Spare Parts',
#  'spare part set': 'Equipment OEM Spare Parts',
#  'spare': 'Equipment OEM Spare Parts',
#  'spare part': 'Equipment OEM Spare Parts',
#  'spares': 'Equipment OEM Spare Parts',
#  'switch mounting kit': 'Equipment OEM Spare Parts',
#  'wear parts set': 'Equipment OEM Spare Parts',
#  '3 jaw chuck': 'Facility consumables',
#  'air gun': 'Facility consumables',
#  'air sparking gun': 'Facility consumables',
#  'angle cutter': 'Facility consumables',
#  'anorak': 'Facility consumables',
#  'apron': 'Facility consumables',
#  'assembly paste': 'Facility consumables',
#  'assembly platform': 'Facility consumables',
#  'automatic door motor': 'Facility consumables',
#  'bags': 'Facility consumables',
#  'basket': 'Facility consumables',
#  'bearing grease': 'Facility consumables',
#  'blade': 'Facility consumables',
#  'boot': 'Facility consumables',
#  'boots': 'Facility consumables',
#  'bottle': 'Facility consumables',
#  'braiding': 'Facility consumables',
#  'brush': 'Facility consumables',
#  'bucket': 'Facility consumables',
#  'canvas': 'Facility consumables',
#  'cardboard': 'Facility consumables',
#  'catch bottle': 'Facility consumables',
#  'center shaft': 'Facility consumables',
#  'centre punch': 'Facility consumables',
#  'chuck': 'Facility consumables',
#  'clamp lever': 'Facility consumables',
#  'cleaner': 'Facility consumables',
#  'cloth': 'Facility consumables',
#  'coat': 'Facility consumables',
#  'cordless phone': 'Facility consumables',
#  'cushion pad': 'Facility consumables',
#  'hose cutter': 'Facility consumables',
#  'deburrer': 'Facility consumables',
#  'dirt scraper': 'Facility consumables',
#  'dispenser': 'Facility consumables',
#  'door lock': 'Facility consumables',
#  'dowel': 'Facility consumables',
#  'drill': 'Facility consumables',
#  'drip tray': 'Facility consumables',
#  'elastic band': 'Facility consumables',
#  'fabric': 'Facility consumables',
#  'fat': 'Facility consumables',
#  'feeler gauge': 'Facility consumables',
#  'feeler guage': 'Facility consumables',
#  'flame protection': 'Facility consumables',
#  'gaiters': 'Facility consumables',
#  'gaiter': 'Facility consumables',
#  'glove': 'Facility consumables',
#  'gloves': 'Facility consumables',
#  'grease': 'Facility consumables',
#  'griff': 'Facility consumables',
#  'grip': 'Facility consumables',
#  'guns': 'Facility consumables',
#  'hair net': 'Facility consumables',
#  'hairnet': 'Facility consumables',
#  'harness': 'Facility consumables',
#  'heat sealing': 'Facility consumables',
#  'ink': 'Facility consumables',
#  'ink cartridge': 'Facility consumables',
#  'inkjet printer': 'Facility consumables',
#  'insole': 'Facility consumables',
#  'installation software': 'Facility consumables',
#  'jacket': 'Facility consumables',
#  'jeans': 'Facility consumables',
#  'knife': 'Facility consumables',
#  'cutter': 'Facility consumables',
#  'craft tape': 'Facility consumables',
#  'label': 'Facility consumables',
#  'label holder': 'Facility consumables',
#  'laminate': 'Facility consumables',
#  'lamp holder': 'Facility consumables',
#  'level': 'Facility consumables',
#  'licence': 'Facility consumables',
#  'license': 'Facility consumables',
#  'lifting fork': 'Facility consumables',
#  'lowtemperature grease': 'Facility consumables',
#  'mandrel': 'Facility consumables',
#  'mirror': 'Facility consumables',
#  'mixing card': 'Facility consumables',
#  'module labels': 'Facility consumables',
#  'oil': 'Facility consumables',
#  'overall': 'Facility consumables',
#  'overalls': 'Facility consumables',
#  'overshoe': 'Facility consumables',
#  'packaging cord': 'Facility consumables',
#  'packaging cords': 'Facility consumables',
#  'partition wall': 'Facility consumables',
#  'peeling knife': 'Facility consumables',
#  'pestle': 'Facility consumables',
#  'pliers': 'Facility consumables',
#  'polo': 'Facility consumables',
#  'pressing': 'Facility consumables',
#  'printer': 'Facility consumables',
#  'printing plate': 'Facility consumables',
#  'program': 'Facility consumables',
#  'protective cap': 'Facility consumables',
#  'protective film': 'Facility consumables',
#  'protective glove': 'Facility consumables',
#  'protector': 'Facility consumables',
#  'rack': 'Facility consumables',
#  'rebuid kit': 'Facility consumables',
#  'rebuild': 'Facility consumables',
#  'rebuild kit': 'Facility consumables',
#  'refrigerant': 'Facility consumables',
#  'repair': 'Facility consumables',
#  'repair set': 'Facility consumables',
#  'gauge repairer': 'Facility consumables',
#  'gauge repair kit': 'Facility consumables',
#  'gauge repair set': 'Facility consumables',
#  'repair sleeve': 'Facility consumables',
#  'rolling bearing grease': 'Facility consumables',
#  'rough grinding wheel': 'Facility consumables',
#  'rubber strip': 'Facility consumables',
#  'ruler': 'Facility consumables',
#  'safety barrier': 'Facility consumables',
#  'safety cabinet': 'Facility consumables',
#  'safety guard': 'Facility consumables',
#  'sample container': 'Facility consumables',
#  'sealant': 'Facility consumables',
#  'sheet': 'Facility consumables',
#  'shield': 'Facility consumables',
#  'shirt': 'Facility consumables',
#  'shoe': 'Facility consumables',
#  'sign carrier': 'Facility consumables',
#  'small protector': 'Facility consumables',
#  'smoke det': 'Facility consumables',
#  'smoke detector': 'Facility consumables',
#  'sock': 'Facility consumables',
#  'socket wrench': 'Facility consumables',
#  'socks': 'Facility consumables',
#  'sofa': 'Facility consumables',
#  'software': 'Facility consumables',
#  'software license': 'Facility consumables',
#  'stamp': 'Facility consumables',
#  'steel': 'Facility consumables',
#  'step ladder': 'Facility consumables',
#  'storage film roller': 'Facility consumables',
#  'storage lid': 'Facility consumables',
#  'strapping band': 'Facility consumables',
#  'sweatpants': 'Facility consumables',
#  'thermal printing paper': 'Facility consumables',
#  'tool': 'Facility consumables',
#  'towel': 'Facility consumables',
#  'tray': 'Facility consumables',
#  'trousers': 'Facility consumables',
#  'tweezers': 'Facility consumables',
#  'undershirt': 'Facility consumables',
#  'velcro pocket': 'Facility consumables',
#  'vest': 'Facility consumables',
#  'walk in guard': 'Facility consumables',
#  'welding bib pants': 'Facility consumables',
#  'wiper': 'Facility consumables',
#  'wiper blade': 'Facility consumables',
#  ...}

# %%
pattern_dict = {term: re.compile(r'\b' + re.escape(term) + r'\b', flags=re.IGNORECASE) for term in dict}

# Function to find the matching term and assign the category
def match_terms_vectorized(noun, pattern_dict):
    for term, pattern in pattern_dict.items():
        if pattern.search(str(noun)):  
            return dict[term], term
    return None, None 

# Apply the function to the whole column
df_mil_review[['matched_category', 'matched_noun']] = df_mil_review['cleaned_noun'].apply(lambda noun: pd.Series(match_terms_vectorized(noun, pattern_dict)))

# %%
df_mil_review.head()
# Out:
#    Product Id      Quality Status    Manufacturer Name       Manufacturer PID  \
# 0    61959169  SPARROW_PROCESSING                  NaN                  00886
# 1    61999316  SPARROW_PROCESSING                  NaN        BCH16HF07330A5C
# 2    61768659  SPARROW_PROCESSING                  NaN  BREITNER-ABFÜLLANLAGE
# 3    61757206  SPARROW_PROCESSING                  NaN                    NaN
# 4    62069531  SPARROW_PROCESSING  API Schmidt-Bretten               XZ-50114
#
#              model                         Short Description  \
# 0              NaN                 Agitator disc Polyurethan
# 1  BCH16HF07330A5C       Canesten/Servo MotorBCH16HF07330A5C
# 2              NaN                        Motor Antriebsband
# 3              NaN                   TOOL RING SPANNER 8X9MM
# 4         XZ-50114  Dichtung SIGMA M 19 NBR  f.Anfangsplatte
#
#                                     Long Description  \
# 0  Agitator disc Polyurethan; ; Agitator disc Pol...
# 1  Canesten/Servo MotorBCH16HF07330A5C; BCH16HF07...
# 2        Motor Antriebsband; BREITNER-ABFÜLLANLAGE;
# 3                        TOOL RING SPANNER 8X9MM; ;
# 4  Dichtung SIGMA M 19 NBR  f.Anfangsplatte; API ...
#
#                               Additional description score Product family  \
# 0  Agitator disc Polyurethan ( 2 Nos.); Machnine ...   NaN            NaN
# 1                               Canesten Bottel line   NaN            NaN
# 2                                                NaN   NaN            NaN
# 3                                                NaN   NaN            NaN
# 4  Benennung: Dichtung; Typ: SIGMA M 19; Art/Ausf...   NaN            NaN
#
#    ... noun_helper mfr noun result match  qa_group  \
# 0  ...       False   Null result present  22104400
# 1  ...       False   Null result present  27140000
# 2  ...       False   Null result present  23070100
# 3  ...       False   Null result present  99501430
# 4  ...         NaN   Null result present  23070100
#
#                                     qa_label  \
# 0         Gas, water and sewage installation
# 1  Electrical Installation Materials, device
# 2                                  Fasteners
# 3                       Facility consumables
# 4                                  Fasteners
#
#                                          review   cleaned_noun  \
# 0  agitator? Stirring maybe? A kind of turbine?  agitator disc
# 1                                bad extraction          motor
# 2                                bad extraction          motor
# 3                                bad extraction           ring
# 4                              bad string match       dichtung
#
#    max_probability          predicted_category            matched_category  \
# 0             0.94                   Fasteners                   Fasteners
# 1             1.00  Valves, Actuator, Fittings  Valves, Actuator, Fittings
# 2             1.00  Valves, Actuator, Fittings  Valves, Actuator, Fittings
# 3             1.00                   Fasteners                   Fasteners
# 4             0.98                   Fasteners                   Fasteners
#
#   matched_noun
# 0         disc
# 1        motor
# 2        motor
# 3         ring
# 4     dichtung
#
# [5 rows x 33 columns]

# %%
df_mil_review.shape
# Out:
# (987, 33)

# %%
df_mil_review.matched_category.value_counts()
# Out:
# matched_category
# Fasteners                                    404
# Electrical Installation Materials, device    172
# Valves, Actuator, Fittings                   141
# Gas, water and sewage installation           105
# Piping Materials                              58
# Facility consumables                          30
# Equipment OEM Spare Parts                      9
# Name: count, dtype: int64

# %%
# Number of NaN values
column_name = 'matched_category'  
nan_count = df_mil_review[column_name].isna().sum()
print(f"Number of NaN values in '{column_name}': {nan_count}")
# Out:
# Number of NaN values in 'matched_category': 68

# %%
import openai

# %%
openai.api_key = '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'

# %%
X_test.shape
# Out:
# (41213,)

# %%
y_test
# Out:
# 347020           Gas, water and sewage installation
# 29901                                     Fasteners
# 405840                                    Fasteners
# 308164                                    Fasteners
# 217051                             Piping Materials
#                             ...
# 212495                                    Fasteners
# 335522    Electrical Installation Materials, device
# 371074                                    Fasteners
# 193726    Electrical Installation Materials, device
# 476410                   Valves, Actuator, Fittings
# Name: category_noun, Length: 41213, dtype: object

# %%
# Prepare inputs and actual labels from the dataset
inputs = X_test[0:1000].tolist()
actual_labels =y_test[0:1000].tolist()

# Generate predictions using the fine-tuned model
predictions = []

for text in inputs:
    try:
        response = openai.ChatCompletion.create(
            model="ft:gpt-3.5-turbo-0125:sparrow::AnNDUonF",
            messages=[
                {"role": "system", "content": "You are a helpful assistant for product classification."},
                {"role": "user", "content": text}
            ]
        )
        predictions.append(response['choices'][0]['message']['content'].strip())
    except Exception as e:
        predictions.append("Error")  # Handle any errors during API call

# Compute accuracy and classification report
y_test_pred = predictions
accuracy = accuracy_score(actual_labels, predictions)
report = classification_report(actual_labels, predictions, zero_division=0)

# Display results
report_df = pd.DataFrame(classification_report(actual_labels, predictions, output_dict=True)).transpose()
print(f"Accuracy: {accuracy:.2f}")
# Out:
# Accuracy: 0.96

# %%
df_non_matched.head()
# Out:
#     product_id      quality_status manufacturer_name  \
# 13   101050474    SPARROW_APPROVED               CKD
# 14   101050473    SPARROW_APPROVED               CKD
# 15   101050472    SPARROW_APPROVED               CKD
# 34   101050454  SPARROW_PROCESSING               CKD
# 35   101050453  SPARROW_PROCESSING           Habasit
#
#             manufacturer_pid                     model      short_description  \
# 13            STR2-B-10-10-6            STR2-B-10-10-6     ツインロッドair cylinder
# 14  SSD-KL-32C-60-T3H3-D-N-8  SSD-KL-32C-60-T3H3-D-N-8  スーパーコンパクトair cylinder
# 15  SSD-KL-40-250-T3H3-D-N-8  SSD-KL-40-250-T3H3-D-N-8  スーパーコンパクトair cylinder
# 34        SMG-L-20-25-K3V3-D        SMG-L-20-25-K3V3-D   スーパーマウントair cylinder
# 35                   H-4EMDT                       NaN          ベルト（450×1860）
#
#    long_description additional_description      noun norm scope        site  \
# 13              NaN                    NaN  Höinrodd  NaN    In  YA2Z Shiga
# 14              NaN                    NaN   スüßbürz  NaN    In  YA2Z Shiga
# 15              NaN                    NaN   スüßbürz  NaN    In  YA2Z Shiga
# 34              NaN                    NaN   スüßbema  NaN    In  YA2Z Shiga
# 35              NaN                    NaN     Белрт  NaN    In  YA2Z Shiga
#
#    cleaned_noun category_noun matched_noun  word_count  max_probability  \
# 13     höinrodd          None         None           1             0.24
# 14      スüßbürz          None         None           1             0.30
# 15      スüßbürz          None         None           1             0.23
# 34      スüßbema          None         None           1             0.24
# 35        белрт          None         None           1             0.24
#
#                            predicted_category
# 13                                  Fasteners
# 14  Electrical Installation Materials, device
# 15                                  Fasteners
# 34                                  Fasteners
# 35                                  Fasteners

# %%
# Prepare inputs and actual labels from the dataset
inputs = df_non_matched['cleaned_noun'][0:1000].tolist()
# actual_labels =y_test[0:1000].tolist()

# Generate predictions using the fine-tuned model
predictions_non_match = []

for text in inputs:
    try:
        response = openai.ChatCompletion.create(
            model="ft:gpt-3.5-turbo-0125:sparrow::AnNDUonF",
            messages=[
                {"role": "system", "content": "You are a helpful assistant for product classification."},
                {"role": "user", "content": text}
            ]
        )
        predictions_non_match.append(response['choices'][0]['message']['content'].strip())
    except Exception as e:
        predictions_non_match.append("Error")  # Handle any errors during API call

# Compute accuracy and classification report
y_test_pred_non_matched = predictions_non_match
# accuracy = accuracy_score(actual_labels, predictions)
# report = classification_report(actual_labels, predictions, zero_division=0)

# # Display results
# report_df = pd.DataFrame(classification_report(actual_labels, predictions, output_dict=True)).transpose()
# print(f"Accuracy: {accuracy:.2f}")

# %% [markdown]
# Check comparing matched nouns and unmatched

# %%
predicted = df_mil_review['predicted_category']
matched = df_mil_review['matched_category']
qa_label = df_mil_review['qa_label']

valid_matched = ~matched.isna()

report = classification_report(matched[valid_matched], predicted[valid_matched])
print(f"Accuracy: {accuracy:.2f}")
print("\nClassification Report:")
print(report)
# Out:
# Accuracy: 0.60
#
# Classification Report:
#                                            precision    recall  f1-score   support
#
# Electrical Installation Materials, device       0.66      0.64      0.65       172
#                 Equipment OEM Spare Parts       0.38      0.33      0.35         9
#                      Facility consumables       0.50      0.43      0.46        30
#                                 Fasteners       0.78      0.84      0.81       404
#        Gas, water and sewage installation       0.63      0.58      0.60       105
#                          Piping Materials       0.72      0.62      0.67        58
#                Valves, Actuator, Fittings       0.66      0.65      0.65       141
#
#                                  accuracy                           0.71       919
#                                 macro avg       0.62      0.58      0.60       919
#                              weighted avg       0.71      0.71      0.71       919

# %%
df_mil_review[df_mil_review['matched_noun'] == 'anillo']
# Out:
#     Product Id      Quality Status Manufacturer Name Manufacturer PID model  \
# 15    61782339  SPARROW_PROCESSING            Kilian           213813   NaN
# 84    61935909  SPARROW_PROCESSING               NaN              NaN   NaN
#
#          Short Description                                   Long Description  \
# 15  ANILLO OPRESOR;;213813  ANILLO OPRESOR;;213813; KILIAN_213813; Anillo ...
# 84      ANILLO UNICONO 4MM                             ANILLO UNICONO 4MM; ;
#
#        Additional description score Product family  ... noun_helper  \
# 15  Anillo opresor para disco   NaN            NaN  ...       False
# 84                        NaN   NaN            NaN  ...       False
#
#    mfr noun result match  qa_group                   qa_label  \
# 15   Null result present  99501340  Equipment OEM Spare Parts
# 84   Null result present  23070100                  Fasteners
#
#                           review cleaned_noun  max_probability  \
# 15  Engine device - piston clamp       anillo             0.95
# 84                           NaN       anillo             0.72
#
#                            predicted_category  matched_category matched_noun
# 15                                  Fasteners         Fasteners       anillo
# 84  Electrical Installation Materials, device         Fasteners       anillo
#
# [2 rows x 33 columns]

# %%
df_mismatch = df_mil_review[df_mil_review['predicted_category'] != df_mil_review['matched_category']]
# df_mismatch = df_mismatch.dropna(subset=['predicted_category'])
# Remove rows where 'predicted_category' is None or NaN
df_mismatch = df_mismatch[df_mismatch['matched_category'].notna()]
df_mismatch.shape
# Out:
# (266, 33)

# %% [markdown]
# Check with Adams categories

# %%
report = classification_report(qa_label[valid_matched], predicted[valid_matched])
print(f"Accuracy: {accuracy:.2f}")
print("\nClassification Report:")
print(report)
# Out:
# Accuracy: 0.60
#
# Classification Report:
#                                            precision    recall  f1-score   support
#
# Electrical Installation Materials, device       0.62      0.59      0.60       174
#                 Equipment OEM Spare Parts       0.62      0.05      0.09        99
#                      Facility consumables       0.42      0.46      0.44        24
#                                 Fasteners       0.65      0.88      0.75       319
#        Gas, water and sewage installation       0.49      0.55      0.52        87
#                          Piping Materials       0.72      0.55      0.63        65
#                Valves, Actuator, Fittings       0.62      0.56      0.59       151
#
#                                  accuracy                           0.62       919
#                                 macro avg       0.59      0.52      0.52       919
#                              weighted avg       0.62      0.62      0.59       919

# %% [markdown]
# Check for the unmatched nouns

# %%
nan_matched = matched.isna()
report = classification_report(qa_label[nan_matched], predicted[nan_matched])
print(f"Accuracy: {accuracy:.2f}")
print("\nClassification Report:")
print(report)
# Out:
# Accuracy: 0.60
#
# Classification Report:
#                                            precision    recall  f1-score   support
#
# Electrical Installation Materials, device       0.31      0.31      0.31        16
#                 Equipment OEM Spare Parts       0.00      0.00      0.00        22
#                      Facility consumables       0.00      0.00      0.00         3
#                                 Fasteners       0.11      0.20      0.14        10
#        Gas, water and sewage installation       0.25      0.44      0.32         9
#                          Piping Materials       0.00      0.00      0.00         2
#                Valves, Actuator, Fittings       0.25      0.33      0.29         6
#
#                                  accuracy                           0.19        68
#                                 macro avg       0.13      0.18      0.15        68
#                              weighted avg       0.15      0.19      0.16        68

# %% [markdown]
# Adam reviews and matched

# %%
report = classification_report(qa_label[valid_matched], matched[valid_matched])
print(f"Accuracy: {accuracy:.2f}")
print("\nClassification Report:")
print(report)
# Out:
# Accuracy: 0.60
#
# Classification Report:
#                                            precision    recall  f1-score   support
#
# Electrical Installation Materials, device       0.88      0.87      0.88       174
#                 Equipment OEM Spare Parts       0.89      0.08      0.15        99
#                      Facility consumables       0.60      0.75      0.67        24
#                                 Fasteners       0.78      0.98      0.87       319
#        Gas, water and sewage installation       0.68      0.82      0.74        87
#                          Piping Materials       0.95      0.85      0.89        65
#                Valves, Actuator, Fittings       0.89      0.83      0.86       151
#
#                                  accuracy                           0.81       919
#                                 macro avg       0.81      0.74      0.72       919
#                              weighted avg       0.83      0.81      0.78       919
