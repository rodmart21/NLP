# %%
import pickle
import pandas as pd

from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.svm import LinearSVC
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score
from sklearn.pipeline import make_pipeline
import matplotlib.pyplot as plt
import numpy as np
import joblib
import re
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline  # Important for combining SMOTE with other steps
from xgboost import XGBClassifier
from sklearn.preprocessing import LabelEncoder

# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import Dense, Dropout
# from tensorflow.keras.preprocessing.text import Tokenizer
# from tensorflow.keras.preprocessing.sequence import pad_sequences
# from sklearn.preprocessing import LabelEncoder

import spacy
# from tqdm import tq

from src.utils import *

# %% [markdown]
# ## 1) Data

# %%
df_mil=pd.read_csv('data/1k_Parts/BAYER_mat_group_flags_20241206_1k‑verified_20241210.csv')
df_mil.head(3)
df_mil['cleaned_noun'] = df_mil['noun'].apply(clean_category_text)

# %% [markdown]
# #### Training data with the matched values

# %%
matched_nouns=pd.read_pickle('data/results/matched_values.pkl')

# %%
matched_nouns.head(120)
# Out:
#                cleaned_noun                       category_noun
# 0                  cylinder          Valves, Actuator, Fittings
# 1                  cylinder          Valves, Actuator, Fittings
# 2                  cylinder          Valves, Actuator, Fittings
# 3                  cylinder          Valves, Actuator, Fittings
# 4                  cylinder          Valves, Actuator, Fittings
# ...                     ...                                 ...
# 2630         pressure gauge  Gas, water and sewage installation
# 2633  pressure safety valve  Gas, water and sewage installation
# 2634             repair kit           Equipment OEM Spare Parts
# 2636                   ring                           Fasteners
# 2637              set screw           Equipment OEM Spare Parts
#
# [120 rows x 2 columns]

# %%
matched_nouns.shape
# Out:
# (274752, 2)

# %%
non_matched_df= pd.read_pickle('data/results/non_matched_nouns.pkl')

# %% [markdown]
# ## 2) Models

# %% [markdown]
# #### 2.1) Naive Bayes model

# %%
# filtered_df['cleaned_noun'] = filtered_df['cleaned_noun'].str.lower()
X = matched_nouns['cleaned_noun']  # Features (cleaned nouns)
y = matched_nouns['category_noun']  # Labels (categories)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=42)

# %%
model_nb = make_pipeline(TfidfVectorizer(stop_words='english', max_features=5000, ngram_range=(1, 2), min_df=2, max_df=0.95), MultinomialNB())
model_nb.fit(X_train, y_train)
y_pred_nb = model_nb.predict(X_test)
print(classification_report(y_test, y_pred_nb))
# Out:
#                                            precision    recall  f1-score   support
#
# Electrical Installation Materials, device       0.99      0.98      0.99      6834
#                 Equipment OEM Spare Parts       0.98      0.94      0.96       765
#                      Facility consumables       1.00      0.97      0.98      1677
#                                 Fasteners       0.99      1.00      0.99     19434
#        Gas, water and sewage installation       0.99      0.98      0.99      3893
#                          Piping Materials       1.00      0.99      0.99      3033
#                Valves, Actuator, Fittings       0.99      0.99      0.99      5577
#
#                                  accuracy                           0.99     41213
#                                 macro avg       0.99      0.98      0.98     41213
#                              weighted avg       0.99      0.99      0.99     41213

# %%
# For the 1k Adams parts
new_data = df_mil['cleaned_noun'].tolist()
probabilities = model_nb.predict_proba(new_data)
probabilities_df = pd.DataFrame(probabilities, columns=model_nb.classes_)
probabilities_df = probabilities_df.round(2)
df_mil['max_probability'] = probabilities_df.max(axis=1)
df_mil['predicted_category'] = probabilities_df.idxmax(axis=1)

# Performance metrics
df_mil['qa_label'] = df_mil['qa_label'].astype(str)  # or 'int' depending on your data type
df_mil['predicted_category'] = df_mil['predicted_category'].astype(str)  # or 'int'
accuracy = accuracy_score(df_mil['qa_label'], df_mil['predicted_category'])
report = classification_report(df_mil['qa_label'], df_mil['predicted_category'])
print(f"Accuracy: {accuracy:.2f}")
print("\nClassification Report:")
print(report)
# Out:
# Accuracy: 0.76
#
# Classification Report:
#                                            precision    recall  f1-score   support
#
# Electrical Installation Materials, device       0.89      0.77      0.83       195
#                 Equipment OEM Spare Parts       1.00      0.07      0.14       121
#                      Facility consumables       0.63      0.63      0.63        27
#                                 Fasteners       0.69      0.99      0.81       335
#        Gas, water and sewage installation       0.65      0.75      0.70        97
#                          Piping Materials       0.95      0.81      0.87        67
#                Valves, Actuator, Fittings       0.88      0.78      0.83       158
#
#                                  accuracy                           0.76      1000
#                                 macro avg       0.81      0.69      0.69      1000
#                              weighted avg       0.81      0.76      0.72      1000

# %%
# Apply it to the unmatched values
# loaded_model = joblib.load('models/text_classification_model_full_catalog.joblib')
new_data = non_matched_df['cleaned_noun'].tolist()  # Replace with your actual new data
probabilities = model_nb.predict_proba(new_data)
probabilities_df = pd.DataFrame(probabilities, columns=model_nb.classes_)
probabilities_df = probabilities_df.round(2)
probabilities_df['max_probability'] = probabilities_df.max(axis=1)
probabilities_df['predicted_category'] = probabilities_df.idxmax(axis=1)
probabilities_df['cleaned_noun'] = new_data

# %%
probabilities_df.max_probability.describe()  # Very low values for the maximum probability
# Out:
# count    108067.000000
# mean          0.469675
# std           0.096240
# min           0.170000
# 25%           0.470000
# 50%           0.470000
# 75%           0.470000
# max           0.980000
# Name: max_probability, dtype: float64

# %%
probabilities_df   # Again biased to the biggest category
# Out:
#         Electrical Installation Materials, device  Equipment OEM Spare Parts  \
# 0                                            0.16                       0.02
# 1                                            0.16                       0.02
# 2                                            0.16                       0.02
# 3                                            0.16                       0.02
# 4                                            0.16                       0.02
# ...                                           ...                        ...
# 108062                                       0.16                       0.02
# 108063                                       0.16                       0.02
# 108064                                       0.16                       0.02
# 108065                                       0.16                       0.02
# 108066                                       0.16                       0.02
#
#         Facility consumables  Fasteners  Gas, water and sewage installation  \
# 0                       0.04       0.47                                0.09
# 1                       0.04       0.47                                0.09
# 2                       0.04       0.47                                0.09
# 3                       0.04       0.47                                0.09
# 4                       0.04       0.47                                0.09
# ...                      ...        ...                                 ...
# 108062                  0.04       0.47                                0.09
# 108063                  0.04       0.47                                0.09
# 108064                  0.04       0.47                                0.09
# 108065                  0.04       0.47                                0.09
# 108066                  0.04       0.47                                0.09
#
#         Piping Materials  Valves, Actuator, Fittings  max_probability  \
# 0                   0.07                        0.13             0.47
# 1                   0.07                        0.13             0.47
# 2                   0.07                        0.13             0.47
# 3                   0.07                        0.13             0.47
# 4                   0.07                        0.13             0.47
# ...                  ...                         ...              ...
# 108062              0.07                        0.13             0.47
# 108063              0.07                        0.13             0.47
# 108064              0.07                        0.13             0.47
# 108065              0.07                        0.13             0.47
# 108066              0.07                        0.13             0.47
#
#        predicted_category cleaned_noun
# 0               Fasteners     höinrodd
# 1               Fasteners      スüßbürz
# 2               Fasteners      スüßbürz
# 3               Fasteners      スüßbema
# 4               Fasteners        белрт
# ...                   ...          ...
# 108062          Fasteners    carrilera
# 108063          Fasteners        tapas
# 108064          Fasteners      columna
# 108065          Fasteners        rollo
# 108066          Fasteners       cierre
#
# [108067 rows x 10 columns]

# %% [markdown]
# #### 2.2) Support Vector Machine

# %%
model_svm = make_pipeline(TfidfVectorizer(stop_words='english', max_features=5000, ngram_range=(1, 2), min_df=2, max_df=0.95),LinearSVC())
model_svm.fit(X_train, y_train)
y_pred_svm = model_svm.predict(X_test)
print(classification_report(y_test, y_pred_svm))
# Out:
#                                            precision    recall  f1-score   support
#
# Electrical Installation Materials, device       0.97      1.00      0.98      6834
#                 Equipment OEM Spare Parts       0.99      0.99      0.99       765
#                      Facility consumables       1.00      0.98      0.99      1677
#                                 Fasteners       1.00      1.00      1.00     19434
#        Gas, water and sewage installation       1.00      0.99      0.99      3893
#                          Piping Materials       1.00      1.00      1.00      3033
#                Valves, Actuator, Fittings       1.00      0.99      1.00      5577
#
#                                  accuracy                           0.99     41213
#                                 macro avg       0.99      0.99      0.99     41213
#                              weighted avg       0.99      0.99      0.99     41213

# %%
# For the 1k parts
new_data = df_mil['cleaned_noun'].tolist()
probabilities = model_svm.predict_proba(new_data)
probabilities_df = pd.DataFrame(probabilities, columns=model_svm.classes_)
probabilities_df = probabilities_df.round(2)
df_mil['max_probability'] = probabilities_df.max(axis=1)
df_mil['predicted_category'] = probabilities_df.idxmax(axis=1)

df_mil['qa_label'] = df_mil['qa_label'].astype(str)  # or 'int' depending on your data type
df_mil['predicted_category'] = df_mil['predicted_category'].astype(str)  # or 'int'
accuracy = accuracy_score(df_mil['qa_label'], df_mil['predicted_category'])
report = classification_report(df_mil['qa_label'], df_mil['predicted_category'])
print(f"Accuracy: {accuracy:.2f}")
print("\nClassification Report:")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File c:\Users\RodrigoMartínezAlons\anaconda3\Lib\site-packages\sklearn\utils\_available_if.py:29, in _AvailableIfDescriptor._check(self, obj, owner)
#      28 try:
# ---> 29     check_result = self.check(obj)
#      30 except Exception as e:
#
# File c:\Users\RodrigoMartínezAlons\anaconda3\Lib\site-packages\sklearn\pipeline.py:51, in _final_estimator_has.<locals>.check(self)
#      49 def check(self):
#      50     # raise original `AttributeError` if `attr` does not exist
# ---> 51     getattr(self._final_estimator, attr)
#      52     return True
#
# AttributeError: 'LinearSVC' object has no attribute 'predict_proba'
#
# The above exception was the direct cause of the following exception:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 3
#       1 # For the 1k parts
#       2 new_data = df_mil['cleaned_noun'].tolist()
# ----> 3 probabilities = model_svm.predict_proba(new_data)
#       4 probabilities_df = pd.DataFrame(probabilities, columns=model_svm.classes_)
#       5 probabilities_df = probabilities_df.round(2)
#
# File c:\Users\RodrigoMartínezAlons\anaconda3\Lib\site-packages\sklearn\utils\_available_if.py:40, in _AvailableIfDescriptor.__get__(self, obj, owner)
#      36 def __get__(self, obj, owner=None):
#      37     if obj is not None:
#      38         # delegate only on instances, not the classes.
#      39         # this is to allow access to the docstrings.
# ---> 40         self._check(obj, owner=owner)
#      41         out = MethodType(self.fn, obj)
#      43     else:
#      44         # This makes it possible to use the decorated method as an unbound method,
#      45         # for instance when monkeypatching.
#
# File c:\Users\RodrigoMartínezAlons\anaconda3\Lib\site-packages\sklearn\utils\_available_if.py:31, in _AvailableIfDescriptor._check(self, obj, owner)
#      29     check_result = self.check(obj)
#      30 except Exception as e:
# ---> 31     raise AttributeError(attr_err_msg) from e
#      33 if not check_result:
#      34     raise AttributeError(attr_err_msg)
#
# AttributeError: This 'Pipeline' has no attribute 'predict_proba'

# %%
# For the unmatched values
new_data = non_matched_df['cleaned_noun'].tolist()  # Replace with your actual new data
probabilities = model_svm.predict_proba(new_data)
probabilities_df = pd.DataFrame(probabilities, columns=model_svm.classes_)
probabilities_df = probabilities_df.round(2)
probabilities_df['max_probability'] = probabilities_df.max(axis=1)
probabilities_df['predicted_category'] = probabilities_df.idxmax(axis=1)
probabilities_df['cleaned_noun'] = new_data
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File c:\Users\RodrigoMartínezAlons\anaconda3\Lib\site-packages\sklearn\utils\_available_if.py:29, in _AvailableIfDescriptor._check(self, obj, owner)
#      28 try:
# ---> 29     check_result = self.check(obj)
#      30 except Exception as e:
#
# File c:\Users\RodrigoMartínezAlons\anaconda3\Lib\site-packages\sklearn\pipeline.py:51, in _final_estimator_has.<locals>.check(self)
#      49 def check(self):
#      50     # raise original `AttributeError` if `attr` does not exist
# ---> 51     getattr(self._final_estimator, attr)
#      52     return True
#
# AttributeError: 'LinearSVC' object has no attribute 'predict_proba'
#
# The above exception was the direct cause of the following exception:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 3
#       1 # For the unmatched values
#       2 new_data = non_matched_df['cleaned_noun'].tolist()  # Replace with your actual new data
# ----> 3 probabilities = model_svm.predict_proba(new_data)
#       4 probabilities_df = pd.DataFrame(probabilities, columns=model_svm.classes_)
#       5 probabilities_df = probabilities_df.round(2)
#
# File c:\Users\RodrigoMartínezAlons\anaconda3\Lib\site-packages\sklearn\utils\_available_if.py:40, in _AvailableIfDescriptor.__get__(self, obj, owner)
#      36 def __get__(self, obj, owner=None):
#      37     if obj is not None:
#      38         # delegate only on instances, not the classes.
#      39         # this is to allow access to the docstrings.
# ---> 40         self._check(obj, owner=owner)
#      41         out = MethodType(self.fn, obj)
#      43     else:
#      44         # This makes it possible to use the decorated method as an unbound method,
#      45         # for instance when monkeypatching.
#
# File c:\Users\RodrigoMartínezAlons\anaconda3\Lib\site-packages\sklearn\utils\_available_if.py:31, in _AvailableIfDescriptor._check(self, obj, owner)
#      29     check_result = self.check(obj)
#      30 except Exception as e:
# ---> 31     raise AttributeError(attr_err_msg) from e
#      33 if not check_result:
#      34     raise AttributeError(attr_err_msg)
#
# AttributeError: This 'Pipeline' has no attribute 'predict_proba'

# %% [markdown]
# #### 2.3) Random Forest

# %%
model_rf = make_pipeline(TfidfVectorizer(stop_words='english', max_features=5000, ngram_range=(1, 2), min_df=2, max_df=0.95),
                         RandomForestClassifier(n_estimators=100, random_state=42))
model_rf.fit(X_train, y_train)
y_pred_rf = model_rf.predict(X_test)
print(classification_report(y_test, y_pred_rf))
# Out:
#                                            precision    recall  f1-score   support
#
# Electrical Installation Materials, device       0.97      0.99      0.98      6834
#                 Equipment OEM Spare Parts       0.98      0.98      0.98       765
#                      Facility consumables       1.00      0.97      0.98      1677
#                                 Fasteners       1.00      1.00      1.00     19434
#        Gas, water and sewage installation       1.00      0.99      0.99      3893
#                          Piping Materials       1.00      1.00      1.00      3033
#                Valves, Actuator, Fittings       1.00      0.99      1.00      5577
#
#                                  accuracy                           0.99     41213
#                                 macro avg       0.99      0.99      0.99     41213
#                              weighted avg       0.99      0.99      0.99     41213

# %%
# 1k parts
new_data = df_mil['cleaned_noun'].tolist()
probabilities = model_rf.predict_proba(new_data)
probabilities_df = pd.DataFrame(probabilities, columns=model_rf.classes_)
probabilities_df = probabilities_df.round(2)
df_mil['max_probability'] = probabilities_df.max(axis=1)
df_mil['predicted_category'] = probabilities_df.idxmax(axis=1)

df_mil['qa_label'] = df_mil['qa_label'].astype(str)  # or 'int' depending on your data type
df_mil['predicted_category'] = df_mil['predicted_category'].astype(str)  # or 'int'
accuracy = accuracy_score(df_mil['qa_label'], df_mil['predicted_category'])
report = classification_report(df_mil['qa_label'], df_mil['predicted_category'])
print(f"Accuracy: {accuracy:.2f}")
print("\nClassification Report:")
print(report)
# Out:
# Accuracy: 0.76
#
# Classification Report:
#                                            precision    recall  f1-score   support
#
# Electrical Installation Materials, device       0.66      0.89      0.76       195
#                 Equipment OEM Spare Parts       1.00      0.07      0.12       121
#                      Facility consumables       0.64      0.67      0.65        27
#                                 Fasteners       0.78      0.93      0.85       335
#        Gas, water and sewage installation       0.68      0.72      0.70        97
#                          Piping Materials       0.96      0.81      0.88        67
#                Valves, Actuator, Fittings       0.87      0.78      0.82       158
#
#                                  accuracy                           0.76      1000
#                                 macro avg       0.80      0.70      0.68      1000
#                              weighted avg       0.80      0.76      0.72      1000

# %%
# For the unmatched values
new_data = non_matched_df['cleaned_noun'].tolist()  # Replace with your actual new data
probabilities = model_rf.predict_proba(new_data)
probabilities_df = pd.DataFrame(probabilities, columns=model_rf.classes_)
probabilities_df = probabilities_df.round(2)
probabilities_df['max_probability'] = probabilities_df.max(axis=1)
probabilities_df['predicted_category'] = probabilities_df.idxmax(axis=1)
probabilities_df['cleaned_noun'] = new_data
probabilities_df

# %%
probabilities_df    # Again same probabilities
# Out:
#         Electrical Installation Materials, device  Equipment OEM Spare Parts  \
# 0                                            0.39                       0.02
# 1                                            0.39                       0.02
# 2                                            0.39                       0.02
# 3                                            0.39                       0.02
# 4                                            0.39                       0.02
# ...                                           ...                        ...
# 108062                                       0.39                       0.02
# 108063                                       0.39                       0.02
# 108064                                       0.39                       0.02
# 108065                                       0.39                       0.02
# 108066                                       0.39                       0.02
#
#         Facility consumables  Fasteners  Gas, water and sewage installation  \
# 0                       0.09        0.2                                0.14
# 1                       0.09        0.2                                0.14
# 2                       0.09        0.2                                0.14
# 3                       0.09        0.2                                0.14
# 4                       0.09        0.2                                0.14
# ...                      ...        ...                                 ...
# 108062                  0.09        0.2                                0.14
# 108063                  0.09        0.2                                0.14
# 108064                  0.09        0.2                                0.14
# 108065                  0.09        0.2                                0.14
# 108066                  0.09        0.2                                0.14
#
#         Piping Materials  Valves, Actuator, Fittings  max_probability  \
# 0                   0.03                        0.14             0.39
# 1                   0.03                        0.14             0.39
# 2                   0.03                        0.14             0.39
# 3                   0.03                        0.14             0.39
# 4                   0.03                        0.14             0.39
# ...                  ...                         ...              ...
# 108062              0.03                        0.14             0.39
# 108063              0.03                        0.14             0.39
# 108064              0.03                        0.14             0.39
# 108065              0.03                        0.14             0.39
# 108066              0.03                        0.14             0.39
#
#                                predicted_category cleaned_noun
# 0       Electrical Installation Materials, device     höinrodd
# 1       Electrical Installation Materials, device      スüßbürz
# 2       Electrical Installation Materials, device      スüßbürz
# 3       Electrical Installation Materials, device      スüßbema
# 4       Electrical Installation Materials, device        белрт
# ...                                           ...          ...
# 108062  Electrical Installation Materials, device    carrilera
# 108063  Electrical Installation Materials, device        tapas
# 108064  Electrical Installation Materials, device      columna
# 108065  Electrical Installation Materials, device        rollo
# 108066  Electrical Installation Materials, device       cierre
#
# [108067 rows x 10 columns]

# %% [markdown]
# #### 2.4) XGBoost model

# %%
encoder = LabelEncoder()
y_train_enc = encoder.fit_transform(y_train)
y_test_enc = encoder.transform(y_test)

# Define the model pipeline
model_xgb = make_pipeline(
    TfidfVectorizer(stop_words='english', max_features=5000, ngram_range=(1, 2), min_df=2, max_df=0.95),
    XGBClassifier(use_label_encoder=False, eval_metric='logloss', random_state=42)
)

# Train the model
model_xgb.fit(X_train, y_train_enc)

# Predict and evaluate
y_pred_xgb = model_xgb.predict(X_test)
print(classification_report(y_test_enc, y_pred_xgb, target_names=encoder.classes_))
# Out:
# c:\Users\RodrigoMartínezAlons\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [11:07:21] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
#                                            precision    recall  f1-score   support
#
# Electrical Installation Materials, device       1.00      0.80      0.89      6834
#                 Equipment OEM Spare Parts       0.98      0.98      0.98       765
#                      Facility consumables       1.00      0.87      0.93      1677
#                                 Fasteners       0.90      1.00      0.94     19434
#        Gas, water and sewage installation       1.00      0.92      0.96      3893
#                          Piping Materials       1.00      0.98      0.99      3033
#                Valves, Actuator, Fittings       0.99      0.94      0.97      5577
#
#                                  accuracy                           0.94     41213
#                                 macro avg       0.98      0.93      0.95     41213
#                              weighted avg       0.95      0.94      0.94     41213

# %%
new_data = df_mil['cleaned_noun'].tolist()
probabilities = model_xgb.predict_proba(new_data)
probabilities_df = pd.DataFrame(probabilities, columns=model_xgb.classes_)
probabilities_df = probabilities_df.round(2)
df_mil['max_probability'] = probabilities_df.max(axis=1)
df_mil['predicted_category'] = probabilities_df.idxmax(axis=1)

# %%
df_mil['qa_label'] = df_mil['qa_label'].astype(str)  # or 'int' depending on your data type
df_mil['predicted_category'] = df_mil['predicted_category'].astype(str)  # or 'int'
accuracy = accuracy_score(df_mil['qa_label'], df_mil['predicted_category'])
report = classification_report(df_mil['qa_label'], df_mil['predicted_category'])
print(f"Accuracy: {accuracy:.2f}")
print("\nClassification Report:")
print(report)
# Out:
# Accuracy: 0.00
#
# Classification Report:
#                                            precision    recall  f1-score   support
#
#                                         0       0.00      0.00      0.00       0.0
#                                         1       0.00      0.00      0.00       0.0
#                                         2       0.00      0.00      0.00       0.0
#                                         3       0.00      0.00      0.00       0.0
#                                         4       0.00      0.00      0.00       0.0
#                                         5       0.00      0.00      0.00       0.0
#                                         6       0.00      0.00      0.00       0.0
# Electrical Installation Materials, device       0.00      0.00      0.00     195.0
#                 Equipment OEM Spare Parts       0.00      0.00      0.00     121.0
#                      Facility consumables       0.00      0.00      0.00      27.0
#                                 Fasteners       0.00      0.00      0.00     335.0
#        Gas, water and sewage installation       0.00      0.00      0.00      97.0
#                          Piping Materials       0.00      0.00      0.00      67.0
#                Valves, Actuator, Fittings       0.00      0.00      0.00     158.0
#
#                                  accuracy                           0.00    1000.0
#                                 macro avg       0.00      0.00      0.00    1000.0
#                              weighted avg       0.00      0.00      0.00    1000.0
# c:\Users\RodrigoMartínezAlons\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\RodrigoMartínezAlons\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\RodrigoMartínezAlons\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\RodrigoMartínezAlons\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\RodrigoMartínezAlons\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\RodrigoMartínezAlons\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.preprocessing import LabelEncoder

# Tokenization
tokenizer = Tokenizer(num_words=5000)
tokenizer.fit_on_texts(X_train)
X_train_seq = pad_sequences(tokenizer.texts_to_sequences(X_train), maxlen=100)
X_test_seq = pad_sequences(tokenizer.texts_to_sequences(X_test), maxlen=100)

# Encode labels
encoder = LabelEncoder()
y_train_enc = encoder.fit_transform(y_train)
y_test_enc = encoder.transform(y_test)

# Model
model_nn = Sequential()
model_nn.add(Dense(128, activation='relu', input_dim=100))
model_nn.add(Dropout(0.5))
model_nn.add(Dense(64, activation='relu'))
model_nn.add(Dropout(0.5))
model_nn.add(Dense(len(encoder.classes_), activation='softmax'))

model_nn.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model_nn.fit(X_train_seq, y_train_enc, epochs=10, batch_size=32, validation_data=(X_test_seq, y_test_enc))

# Evaluation
y_pred_nn = model_nn.predict(X_test_seq).argmax(axis=1)
print(classification_report(y_test_enc, y_pred_nn, target_names=encoder.classes_))
# Out:
# Epoch 1/10
# c:\Users\RodrigoMartínezAlons\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 7299/7299 ━━━━━━━━━━━━━━━━━━━━ 15s 2ms/step - accuracy: 0.4459 - loss: 4.6745 - val_accuracy: 0.5064 - val_loss: 1.3965
# Epoch 2/10
# 7299/7299 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - accuracy: 0.5059 - loss: 1.3913 - val_accuracy: 0.5182 - val_loss: 1.3543
# Epoch 3/10
# 7299/7299 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - accuracy: 0.5141 - loss: 1.3576 - val_accuracy: 0.5315 - val_loss: 1.3411
# Epoch 4/10
# 7299/7299 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - accuracy: 0.5223 - loss: 1.3416 - val_accuracy: 0.5310 - val_loss: 1.3318
# Epoch 5/10
# 7299/7299 ━━━━━━━━━━━━━━━━━━━━ 24s 3ms/step - accuracy: 0.5259 - loss: 1.3349 - val_accuracy: 0.5315 - val_loss: 1.3264
# Epoch 6/10
# 7299/7299 ━━━━━━━━━━━━━━━━━━━━ 29s 4ms/step - accuracy: 0.5261 - loss: 1.3335 - val_accuracy: 0.5315 - val_loss: 1.3249
# Epoch 7/10
# 7299/7299 ━━━━━━━━━━━━━━━━━━━━ 17s 2ms/step - accuracy: 0.5273 - loss: 1.3336 - val_accuracy: 0.5310 - val_loss: 1.3257
# Epoch 8/10
# 7299/7299 ━━━━━━━━━━━━━━━━━━━━ 29s 4ms/step - accuracy: 0.5281 - loss: 1.3321 - val_accuracy: 0.5310 - val_loss: 1.3241
# Epoch 9/10
# 7299/7299 ━━━━━━━━━━━━━━━━━━━━ 10s 1ms/step - accuracy: 0.5300 - loss: 1.3274 - val_accuracy: 0.5310 - val_loss: 1.3224
# Epoch 10/10
# 7299/7299 ━━━━━━━━━━━━━━━━━━━━ 15s 2ms/step - accuracy: 0.5295 - loss: 1.3267 - val_accuracy: 0.5310 - val_loss: 1.3210
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 1s 602us/step
#                                            precision    recall  f1-score   support
#
# Electrical Installation Materials, device       1.00      0.08      0.14      6834
#                 Equipment OEM Spare Parts       0.00      0.00      0.00       765
#                      Facility consumables       0.00      0.00      0.00      1677
#                                 Fasteners       0.50      1.00      0.67     19434
#        Gas, water and sewage installation       1.00      0.12      0.22      3893
#                          Piping Materials       0.00      0.00      0.00      3033
#                Valves, Actuator, Fittings       1.00      0.26      0.41      5577
#
#                                  accuracy                           0.53     41213
#                                 macro avg       0.50      0.21      0.21     41213
#                              weighted avg       0.63      0.53      0.41     41213
# c:\Users\RodrigoMartínezAlons\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\RodrigoMartínezAlons\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\RodrigoMartínezAlons\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
df_mil=pd.read_csv('data/1k_Parts/BAYER_mat_group_flags_20241206_1k‑verified_20241210.csv')

# %%
df_mil.head(3)
# Out:
#    Product Id      Quality Status Manufacturer Name       Manufacturer PID  \
# 0    61959169  SPARROW_PROCESSING               NaN                  00886
# 1    61999316  SPARROW_PROCESSING               NaN        BCH16HF07330A5C
# 2    61768659  SPARROW_PROCESSING               NaN  BREITNER-ABFÜLLANLAGE
#
#              model                    Short Description  \
# 0              NaN            Agitator disc Polyurethan
# 1  BCH16HF07330A5C  Canesten/Servo MotorBCH16HF07330A5C
# 2              NaN                   Motor Antriebsband
#
#                                     Long Description  \
# 0  Agitator disc Polyurethan; ; Agitator disc Pol...
# 1  Canesten/Servo MotorBCH16HF07330A5C; BCH16HF07...
# 2        Motor Antriebsband; BREITNER-ABFÜLLANLAGE;
#
#                               Additional description score Product family  \
# 0  Agitator disc Polyurethan ( 2 Nos.); Machnine ...   NaN            NaN
# 1                               Canesten Bottel line   NaN            NaN
# 2                                                NaN   NaN            NaN
#
#    ... mfr_match_group mfr_match_label                     script_decision  \
# 0  ...             NaN             NaN                    Piping Materials
# 1  ...             NaN             NaN  Gas, water and sewage installation
# 2  ...             NaN             NaN  Gas, water and sewage installation
#
#    script_helper mfr_helper noun_helper  mfr noun result match  qa_group  \
# 0          False        NaN       False    Null result present  22104400
# 1          False        NaN       False    Null result present  27140000
# 2          False        NaN       False    Null result present  23070100
#
#                                     qa_label  \
# 0         Gas, water and sewage installation
# 1  Electrical Installation Materials, device
# 2                                  Fasteners
#
#                                          review
# 0  agitator? Stirring maybe? A kind of turbine?
# 1                                bad extraction
# 2                                bad extraction
#
# [3 rows x 28 columns]

# %%
# Cleaning function to standardize the category text format
def clean_category_text(text):
    cleaned_text = str(text).strip().lower()  
    cleaned_text = re.sub(r'[^\w\s]', '', cleaned_text) 
    cleaned_text = re.sub(r'\s+', ' ', cleaned_text)
    return cleaned_text

df_mil['cleaned_noun'] = df_mil['noun'].apply(clean_category_text)

# %%
loaded_model = joblib.load('models/text_classification_model_full_catalog.joblib')
new_data = df_mil['cleaned_noun'].tolist()
probabilities = loaded_model.predict_proba(new_data)
probabilities_df = pd.DataFrame(probabilities, columns=loaded_model.classes_)
probabilities_df = probabilities_df.round(2)
df_mil['max_probability'] = probabilities_df.max(axis=1)
df_mil['predicted_category'] = probabilities_df.idxmax(axis=1)

# %%
df_mil.qa_label.value_counts()
# Out:
# qa_label
# Fasteners                                    335
# Electrical Installation Materials, device    195
# Valves, Actuator, Fittings                   158
# Equipment OEM Spare Parts                    121
# Gas, water and sewage installation            97
# Piping Materials                              67
# Facility consumables                          27
# Name: count, dtype: int64

# %%
df_mil[df_mil['qa_label']=='Equipment OEM Spare Parts']
# Out:
#      Product Id       Quality Status       Manufacturer Name Manufacturer PID  \
# 7     101039312   SPARROW_PROCESSING   ATS sortimat USA, LLC           662539
# 14     61869560   SPARROW_PROCESSING                Tectrion              NaN
# 15     61782339   SPARROW_PROCESSING                  Kilian           213813
# 45     61900833  SPARROW_IN_PROGRESS                     NaN           120014
# 46     62056024   SPARROW_PROCESSING                     NaN              NaN
# ..          ...                  ...                     ...              ...
# 974    61861741   SPARROW_PROCESSING  Breitner Abfüllanlagen           129318
# 975    62038732   SPARROW_PROCESSING                  Amixon         10000126
# 977    62048164   SPARROW_PROCESSING                  Pester           115820
# 978    62048030   SPARROW_PROCESSING             amixon GmbH              NaN
# 985    61843238   SPARROW_PROCESSING              Marchesini       A30G690023
#
#           model                         Short Description  \
# 7           NaN                        RAIL, GUIDE, RAIL,
# 14          NaN               ausl.Becherbodenzentrierung
# 15          NaN                    ANILLO OPRESOR;;213813
# 45       120014                     KIT:MOTOR SEAL,120014
# 46          NaN       ANF hydraulic operated motor of SDV
# ..          ...                                       ...
# 974         NaN  Wellenverlängerung V2A            129318
# 975        LT24   Widerstandsthermometer LT24 Pt100 170mm
# 977         NaN     Pester Wrapping machine/washer/373999
# 978         NaN  Zahnkranz                         Pos.77
# 985  A30G690023  Zange                         A30G690023
#
#                                       Long Description  \
# 7                                                  NaN
# 14   ausl.Becherbodenzentrierung; TECTRION; Benennu...
# 15   ANILLO OPRESOR;;213813; KILIAN_213813; Anillo ...
# 45   KIT:MOTOR SEAL,120014; ; KIT: MOTOR SEAL TYPE,...
# 46             ANF hydraulic operated motor of SDV; ;
# ..                                                 ...
# 974  Wellenverlängerung V2A            129318; BREI...
# 975  Widerstandsthermometer LT24 Pt100 170mm; AMIXO...
# 977    Pester Wrapping machine/washer/373999; 115820;
# 978  Zahnkranz                         Pos.77; AMIX...
# 985  Zange                         A30G690023; MARC...
#
#                                 Additional description score Product family  \
# 7                                                  NaN   NaN            NaN
# 14   Benennung: Becherbodenzentrierung; Hersteller:...   NaN            NaN
# 15                           Anillo opresor para disco   NaN            NaN
# 45   KIT: MOTOR SEAL TYPE, 120014 MFG P/N; WHERE AP...     6            NaN
# 46                                                 NaN   NaN            NaN
# ..                                                 ...   ...            ...
# 974  Benennung: Wellenverlängerung; Werkstoff: V2A;...   NaN            NaN
# 975  Benennung: Widerstandsthermometer; Typ: LT24; ...   NaN            NaN
# 977                                                NaN   NaN            NaN
# 978  Benennung: Zahnkranz; für: Getriebe KS 6000.3-...   NaN            NaN
# 985  Benennung: Zange; Hersteller: Marchesini; Iden...   NaN            NaN
#
#      ... script_helper mfr_helper noun_helper  mfr noun result match  \
# 7    ...          True       True         NaN    Null result present
# 14   ...         False      False         NaN    Null result present
# 15   ...         False        NaN       False    Null result present
# 45   ...         False        NaN       False    Null result present
# 46   ...         False        NaN       False    Null result present
# ..   ...           ...        ...         ...                    ...
# 974  ...          True       True         NaN    Null result present
# 975  ...          True       True         NaN    Null result present
# 977  ...          True       True         NaN    Null result present
# 978  ...          True       True         NaN    Null result present
# 985  ...          True       True         NaN    Null result present
#
#      qa_group                   qa_label  \
# 7    99501340  Equipment OEM Spare Parts
# 14   99501340  Equipment OEM Spare Parts
# 15   99501340  Equipment OEM Spare Parts
# 45   99501340  Equipment OEM Spare Parts
# 46   99501340  Equipment OEM Spare Parts
# ..        ...                        ...
# 974  99501340  Equipment OEM Spare Parts
# 975  99501340  Equipment OEM Spare Parts
# 977  99501340  Equipment OEM Spare Parts
# 978  99501340  Equipment OEM Spare Parts
# 985  99501340  Equipment OEM Spare Parts
#
#                                                review            cleaned_noun  \
# 7                                    bad string match                    rail
# 14   cup centering device? Part of a chemical device?  becherbodenzentrierung
# 15                       Engine device - piston clamp                  anillo
# 45                                             Motor?           kitmotor seal
# 46                                             Motor?                   motor
# ..                                                ...                     ...
# 974                                               NaN      wellenverlängerung
# 975                                               NaN  widerstandsthermometer
# 977                                               NaN  wrapping machinewasher
# 978                                               NaN               zahnkranz
# 985                                               NaN                   zange
#
#      max_probability                  predicted_category
# 7               0.96                           Fasteners
# 14              0.35                           Fasteners
# 15              0.98                           Fasteners
# 45              0.95                           Fasteners
# 46              1.00          Valves, Actuator, Fittings
# ..               ...                                 ...
# 974             0.35                           Fasteners
# 975             0.95  Gas, water and sewage installation
# 977             0.35                           Fasteners
# 978             0.35                           Fasteners
# 985             0.76                Facility consumables
#
# [121 rows x 31 columns]

# %%
df_mil['qa_label'] = df_mil['qa_label'].astype(str)  # or 'int' depending on your data type
df_mil['predicted_category'] = df_mil['predicted_category'].astype(str)  # or 'int'
accuracy = accuracy_score(df_mil['qa_label'], df_mil['predicted_category'])
report = classification_report(df_mil['qa_label'], df_mil['predicted_category'])
print(f"Accuracy: {accuracy:.2f}")
print("\nClassification Report:")
print(report)
